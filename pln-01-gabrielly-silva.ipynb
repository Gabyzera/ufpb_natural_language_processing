# %% [markdown]
# # 🔡 Modelo de linguagem com o método de visualização de Shannon para geração de texto

# %% [markdown]
# ## 📚 Importação das bibliotecas

# %%
import nltk
import random
import pandas as pd
from collections import defaultdict, Counter
from sklearn.feature_extraction.text import CountVectorizer

nltk.download('punkt')
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gabri\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gabri\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## 🪮 Leitura e organização dos dados
# 1. Leitura do arquivo csv.

# %%
df_prompts = pd.read_csv('prompts.csv')
df_prompts
# Out:
#                                  act  \
# 0              An Ethereum Developer
# 1                         SEO Prompt
# 2                     Linux Terminal
# 3    English Translator and Improver
# 4             `position` Interviewer
# ..                               ...
# 198                    study planner
# 199                   SEO specialist
# 200            Note-Taking Assistant
# 201                     Nutritionist
# 202                 Yes or No answer
#
#                                                 prompt
# 0    Imagine you are an experienced Ethereum develo...
# 1    Using WebPilot, create an outline for an artic...
# 2    I want you to act as a linux terminal. I will ...
# 3    I want you to act as an English translator, sp...
# 4    I want you to act as an interviewer. I will be...
# ..                                                 ...
# 198  I want you to act as an advanced study plan ge...
# 199  Contributed by [@suhailroushan13](https://gith...
# 200  I want you to act as a note-taking assistant f...
# 201  Act as a nutritionist and create a healthy rec...
# 202  I want you to reply to questions. You reply on...
#
# [203 rows x 2 columns]

# %% [markdown]
# 2. Filtração para remoção de linhas nulas no campo "prompt" e apresentação apenas desse campo.

# %%
df_prompts = df_prompts.dropna(subset=['prompt'])
df_prompts = df_prompts['prompt']
df_prompts
# Out:
# 0      Imagine you are an experienced Ethereum develo...
# 1      Using WebPilot, create an outline for an artic...
# 2      I want you to act as a linux terminal. I will ...
# 3      I want you to act as an English translator, sp...
# 4      I want you to act as an interviewer. I will be...
#                              ...
# 198    I want you to act as an advanced study plan ge...
# 199    Contributed by [@suhailroushan13](https://gith...
# 200    I want you to act as a note-taking assistant f...
# 201    Act as a nutritionist and create a healthy rec...
# 202    I want you to reply to questions. You reply on...
# Name: prompt, Length: 203, dtype: object

# %% [markdown]
# 3. Junção das linhas formando assim um único texto.

# %%
df_prompt_text = " ".join(df_prompts.astype(str).tolist())
df_prompt_text
# Out:
# 'Imagine you are an experienced Ethereum developer tasked with creating a smart contract for a blockchain messenger. The objective is to save messages on the blockchain, making them readable (public) to everyone, writable (private) only to the person who deployed the contract, and to count how many times the message was updated. Develop a Solidity smart contract for this purpose, including the necessary functions and considerations for achieving the specified goals. Please provide the code and any relevant explanations to ensure a clear understanding of the implementation. Using WebPilot, create an outline for an article that will be 2,000 words on the keyword \'Best SEO prompts\' based on the top 10 results from Google. Include every relevant heading possible. Keep the keyword density of the headings high. For each section of the outline, include the word count. Include FAQs section in the outline too, based on people also ask section from Google for the keyword. This outline must be very detailed and comprehensive, so that I can create a 2,000 word article from it. Generate a long list of LSI and NLP keywords related to my keyword. Also include any other words related to the keyword. Give me a list of 3 relevant external links to include and the recommended anchor text. Make sure they’re not competing articles. Split the outline into part 1 and part 2. I want you to act as a linux terminal. I will type commands and you will reply with what the terminal should show. I want you to only reply with the terminal output inside one unique code block, and nothing else. do not write explanations. do not type commands unless I instruct you to do so. when i need to tell you something in english, i will do so by putting text inside curly brackets {like this}. my first command is pwd I want you to act as an English translator, spelling corrector and improver. I will speak to you in any language and you will detect the language, translate it and answer in the corrected and improved version of my text, in English. I want you to replace my simplified A0-level words and sentences with more beautiful and elegant, upper level English words and sentences. Keep the meaning same, but make them more literary. I want you to only reply the correction, the improvements and nothing else, do not write explanations. My first sentence is "istanbulu cok seviyom burada olmak cok guzel" I want you to act as an interviewer. I will be the candidate and you will ask me the interview questions for the `position` position. I want you to only reply as the interviewer. Do not write all the conversation at once. I want you to only do the interview with me. Ask me the questions and wait for my answers. Do not write explanations. Ask me the questions one by one like an interviewer does and wait for my answers. My first sentence is "Hi" I want you to act as a javascript console. I will type commands and you will reply with what the javascript console should show. I want you to only reply with the terminal output inside one unique code block, and nothing else. do not write explanations. do not type commands unless I instruct you to do so. when i need to tell you something in english, i will do so by putting text inside curly brackets {like this}. my first command is console.log("Hello World"); I want you to act as a text based excel. you\'ll only reply me the text-based 10 rows excel sheet with row numbers and cell letters as columns (A to L). First column header should be empty to reference row number. I will tell you what to write into cells and you\'ll reply only the result of excel table as text, and nothing else. Do not write explanations. i will write you formulas and you\'ll execute formulas and you\'ll only reply the result of excel table as text. First, reply me the empty sheet. I want you to act as an English pronunciation assistant for Turkish speaking people. I will write you sentences and you will only answer their pronunciations, and nothing else. The rep ...

# %% [markdown]
# ## 📑 Preparação do texto
# 1. Realização da tokenização e remoção de stopwords.

# %%
count_vectorizer = CountVectorizer(token_pattern=r'\b\w+\b', stop_words=stopwords)
word_analyzer = count_vectorizer.build_analyzer()
df_prompt_text = word_analyzer(df_prompt_text)
df_prompt_text
# Out:
# ['imagine',
#  'experienced',
#  'ethereum',
#  'developer',
#  'tasked',
#  'creating',
#  'smart',
#  'contract',
#  'blockchain',
#  'messenger',
#  'objective',
#  'save',
#  'messages',
#  'blockchain',
#  'making',
#  'readable',
#  'public',
#  'everyone',
#  'writable',
#  'private',
#  'person',
#  'deployed',
#  'contract',
#  'count',
#  'many',
#  'times',
#  'message',
#  'updated',
#  'develop',
#  'solidity',
#  'smart',
#  'contract',
#  'purpose',
#  'including',
#  'necessary',
#  'functions',
#  'considerations',
#  'achieving',
#  'specified',
#  'goals',
#  'please',
#  'provide',
#  'code',
#  'relevant',
#  'explanations',
#  'ensure',
#  'clear',
#  'understanding',
#  'implementation',
#  'using',
#  'webpilot',
#  'create',
#  'outline',
#  'article',
#  '2',
#  '000',
#  'words',
#  'keyword',
#  'best',
#  'seo',
#  'prompts',
#  'based',
#  'top',
#  '10',
#  'results',
#  'google',
#  'include',
#  'every',
#  'relevant',
#  'heading',
#  'possible',
#  'keep',
#  'keyword',
#  'density',
#  'headings',
#  'high',
#  'section',
#  'outline',
#  'include',
#  'word',
#  'count',
#  'include',
#  'faqs',
#  'section',
#  'outline',
#  'based',
#  'people',
#  'also',
#  'ask',
#  'section',
#  'google',
#  'keyword',
#  'outline',
#  'must',
#  'detailed',
#  'comprehensive',
#  'create',
#  '2',
#  '000',
#  'word',
#  'article',
#  'generate',
#  'long',
#  'list',
#  'lsi',
#  'nlp',
#  'keywords',
#  'related',
#  'keyword',
#  'also',
#  'include',
#  'words',
#  'related',
#  'keyword',
#  'give',
#  'list',
#  '3',
#  'relevant',
#  'external',
#  'links',
#  'include',
#  'recommended',
#  'anchor',
#  'text',
#  'make',
#  'sure',
#  'competing',
#  'articles',
#  'split',
#  'outline',
#  'part',
#  '1',
#  'part',
#  '2',
#  'want',
#  'act',
#  'linux',
#  'terminal',
#  'type',
#  'commands',
#  'reply',
#  'terminal',
#  'show',
#  'want',
#  'reply',
#  'terminal',
#  'output',
#  'inside',
#  'one',
#  'unique',
#  'code',
#  'block',
#  'nothing',
#  'else',
#  'write',
#  'explanations',
#  'type',
#  'commands',
#  'unless',
#  'instruct',
#  'need',
#  'tell',
#  'something',
#  'english',
#  'putting',
#  'text',
#  'inside',
#  'curly',
#  'brackets',
#  'like',
#  'first',
#  'command',
#  'pwd',
#  'want',
#  'act',
#  'english',
#  'translator',
#  'spelling',
#  'corrector',
#  'improver',
#  'speak',
#  'language',
#  'detect',
#  'language',
#  'translate',
#  'answer',
#  'corrected',
#  'improved',
#  'version',
#  'text',
#  'english',
#  'want',
#  'replace',
#  'simplified',
#  'a0',
#  'level',
#  'words',
#  'sentences',
#  'beautiful',
#  'elegant',
#  'upper',
#  'level',
#  'english',
#  'words',
#  'sentences',
#  'keep',
#  'meaning',
#  'make',
#  'literary',
#  'want',
#  'reply',
#  'correction',
#  'improvements',
#  'nothing',
#  'else',
#  'write',
#  'explanations',
#  'first',
#  'sentence',
#  'istanbulu',
#  'cok',
#  'seviyom',
#  'burada',
#  'olmak',
#  'cok',
#  'guzel',
#  'want',
#  'act',
#  'interviewer',
#  'candidate',
#  'ask',
#  'interview',
#  'questions',
#  'position',
#  'position',
#  'want',
#  'reply',
#  'interviewer',
#  'write',
#  'conversation',
#  'want',
#  'interview',
#  'ask',
#  'questions',
#  'wait',
#  'answers',
#  'write',
#  'explanations',
#  'ask',
#  'questions',
#  'one',
#  'one',
#  'like',
#  'interviewer',
#  'wait',
#  'answers',
#  'first',
#  'sentence',
#  'hi',
#  'want',
#  'act',
#  'javascript',
#  'console',
#  'type',
#  'commands',
#  'reply',
#  'javascript',
#  'console',
#  'show',
#  'want',
#  'reply',
#  'terminal',
#  'output',
#  'inside',
#  'one',
#  'unique',
#  'code',
#  'block',
#  'nothing',
#  'else',
#  'write',
#  'explanations',
#  'type',
#  'commands',
#  'unless',
#  'instruct',
#  'need',
#  'tell',
#  'something',
#  'english',
#  'putting',
#  'text',
#  'inside',
#  'curly',
#  'brackets',
#  'like',
#  'first',
#  'command',
#  'console',
#  'log',
#  'hello',
#  'world',
#  'want',
#  'act',
#  'text',
#  'based',
#  'excel',
#  'reply',
#  'text',
#  'based',
#  '10',
#  'rows',
#  'excel',
#  'sheet',
#  'row',
#  'numbers',
#  'cell',
#  'letters',
#  'columns',
#  'l',
#  'first',
#  'column',
#  'header',
#  'empty',
#  'reference',
#  'row',
#  'number',
#  'tell',
#  'write',
#  'cells',
#  'reply',
#  'result',
#  'excel',
#  'table',
#  'text',
#  'nothing',
#  'else',
#  'write',
#  'explanations',
#  'write',
#  'formulas',
#  'execute',
#  'formulas',
#  'reply',
#  'result',
#  'excel',
#  'table',
#  'text',
#  'first',
#  'reply',
#  'empty',
#  'sheet',
#  'want',
#  'act',
#  'english',
#  'pronunciation',
#  'assistant',
#  'turkish',
#  'speaking',
#  'people',
#  'write',
#  'sentences',
#  'answer',
#  'pronunciations',
#  'nothing',
#  'else',
#  'replies',
#  'must',
#  'translations',
#  'sentence',
#  'pronunciations',
#  'pronunciations',
#  'use',
#  'turkish',
#  'latin',
#  'letters',
#  'phonetics',
#  'write',
#  'explanations',
#  'replies',
#  'first',
#  'sentence',
#  'weather',
#  'istanbul',
#  'want',
#  'act',
#  'spoken',
#  'english',
#  'teacher',
#  'improver',
#  'speak',
#  'english',
#  'reply',
#  'english',
#  'practice',
#  'spoken',
#  'english',
#  'want',
#  'keep',
#  'reply',
#  'neat',
#  'limiting',
#  'reply',
#  '100',
#  'words',
#  'want',
#  'strictly',
#  'correct',
#  'grammar',
#  'mistakes',
#  'typos',
#  'factual',
#  'errors',
#  'want',
#  'ask',
#  'question',
#  'reply',
#  'let',
#  'start',
#  'practicing',
#  'could',
#  'ask',
#  'question',
#  'first',
#  'remember',
#  'want',
#  'strictly',
#  'correct',
#  'grammar',
#  'mistakes',
#  'typos',
#  'factual',
#  'errors',
#  'want',
#  'act',
#  'travel',
#  'guide',
#  'write',
#  'location',
#  'suggest',
#  'place',
#  'visit',
#  'near',
#  'location',
#  'cases',
#  'also',
#  'give',
#  'type',
#  'places',
#  'visit',
#  'also',
#  'suggest',
#  'places',
#  'similar',
#  'type',
#  'close',
#  'first',
#  'location',
#  'first',
#  'suggestion',
#  'request',
#  'istanbul',
#  'beyoğlu',
#  'want',
#  'visit',
#  'museums',
#  'want',
#  'act',
#  'plagiarism',
#  'checker',
#  'write',
#  'sentences',
#  'reply',
#  'undetected',
#  'plagiarism',
#  'checks',
#  'language',
#  'given',
#  'sentence',
#  'nothing',
#  'else',
#  'write',
#  'explanations',
#  'replies',
#  'first',
#  'sentence',
#  'computers',
#  'behave',
#  'like',
#  'humans',
#  'speech',
#  'recognition',
#  'systems',
#  'must',
#  'able',
#  'process',
#  'nonverbal',
#  'information',
#  'emotional',
#  'state',
#  'speaker',
#  'want',
#  'act',
#  'like',
#  'character',
#  'series',
#  'want',
#  'respond',
#  'answer',
#  'like',
#  'character',
#  'using',
#  'tone',
#  'manner',
#  'vocabulary',
#  'character',
#  'would',
#  'use',
#  'write',
#  'explanations',
#  'answer',
#  'like',
#  'character',
#  'must',
#  'know',
#  'knowledge',
#  'character',
#  'first',
#  'sentence',
#  'hi',
#  'character',
#  'want',
#  'act',
#  'advertiser',
#  'create',
#  'campaign',
#  'promote',
#  'product',
#  'service',
#  'choice',
#  'choose',
#  'target',
#  'audience',
#  'develop',
#  'key',
#  'messages',
#  'slogans',
#  'select',
#  'media',
#  'channels',
#  'promotion',
#  'decide',
#  'additional',
#  'activities',
#  'needed',
#  'reach',
#  'goals',
#  'first',
#  'suggestion',
#  'request',
#  'need',
#  'help',
#  'creating',
#  'advertising',
#  'campaign',
#  'new',
#  'type',
#  'energy',
#  'drink',
#  'targeting',
#  'young',
#  'adults',
#  'aged',
#  '18',
#  '30',
#  'want',
#  'act',
#  'storyteller',
#  'come',
#  'entertaining',
#  'stories',
#  'engaging',
#  'imaginative',
#  'captivating',
#  'audience',
#  'fairy',
#  'tales',
#  'educational',
#  'stories',
#  'type',
#  'stories',
#  'potential',
#  'capture',
#  'people',
#  'attention',
#  'imagination',
#  'depending',
#  'target',
#  'audience',
#  'may',
#  'choose',
#  'specific',
#  'themes',
#  'topics',
#  'storytelling',
#  'session',
#  'e',
#  'g',
#  'children',
#  'talk',
#  'animals',
#  'adults',
#  'history',
#  'based',
#  'tales',
#  'might',
#  'engage',
#  'better',
#  'etc',
#  'first',
#  'request',
#  'need',
#  'interesting',
#  'story',
#  'perseverance',
#  'want',
#  'act',
#  'football',
#  'commentator',
#  'give',
#  'descriptions',
#  'football',
#  'matches',
#  'progress',
#  'commentate',
#  'match',
#  'providing',
#  'analysis',
#  'happened',
#  'thus',
#  'far',
#  'predicting',
#  'game',
#  'may',
#  'end',
#  'knowledgeable',
#  'football',
#  'terminology',
#  'tactics',
#  'players',
#  'teams',
#  'involved',
#  'match',
#  'focus',
#  'primarily',
#  'providing',
#  'intelligent',
#  'commentary',
#  'rather',
#  'narrating',
#  'play',
#  'play',
#  'first',
#  'request',
#  'watching',
#  'manchester',
#  'united',
#  'vs',
#  'chelsea',
#  'provide',
#  'commentary',
#  'match',
#  'want',
#  'act',
#  'stand',
#  'comedian',
#  'provide',
#  'topics',
#  'related',
#  'current',
#  'events',
#  'use',
#  'wit',
#  'creativity',
#  'observational',
#  'skills',
#  'create',
#  'routine',
#  'based',
#  'topics',
#  'also',
#  'sure',
#  'incorporate',
#  'personal',
#  'anecdotes',
#  'experiences',
#  'routine',
#  'order',
#  'make',
#  'relatable',
#  'engaging',
#  'audience',
#  'first',
#  'request',
#  'want',
#  'humorous',
#  'take',
#  'politics',
#  'want',
#  'act',
#  'motivational',
#  'coach',
#  'provide',
#  'information',
#  'someone',
#  'goals',
#  'challenges',
#  'job',
#  'come',
#  'strategies',
#  'help',
#  'person',
#  'achieve',
#  'goals',
#  'could',
#  'involve',
#  'providing',
#  'positive',
#  'affirmations',
#  'giving',
#  'helpful',
#  'advice',
#  'suggesting',
#  'activities',
#  'reach',
#  'end',
#  'goal',
#  'first',
#  'request',
#  'need',
#  'help',
#  'motivating',
#  'stay',
#  'disciplined',
#  'studying',
#  'upcoming',
#  'exam',
#  'want',
#  'act',
#  'composer',
#  'provide',
#  'lyrics',
#  'song',
#  'create',
#  'music',
#  'could',
#  'include',
#  'using',
#  'various',
#  'instruments',
#  'tools',
#  'synthesizers',
#  'samplers',
#  'order',
#  'create',
#  'melodies',
#  'harmonies',
#  'bring',
#  'lyrics',
#  'life',
#  'first',
#  'request',
#  'written',
#  'poem',
#  'named',
#  'hayalet',
#  'sevgilim',
#  'need',
#  'music',
#  'go',
#  'want',
#  'act',
#  'debater',
#  'provide',
#  'topics',
#  'related',
#  'current',
#  'events',
#  'task',
#  'research',
#  'sides',
#  'debates',
#  'present',
#  'valid',
#  'arguments',
#  'side',
#  'refute',
#  'opposing',
#  'points',
#  'view',
#  'draw',
#  'persuasive',
#  'conclusions',
#  'based',
#  'evidence',
#  'goal',
#  'help',
#  'people',
#  'come',
#  'away',
#  'discussion',
#  'increased',
#  'knowledge',
#  'insight',
#  'topic',
#  'hand',
#  'first',
#  'request',
#  'want',
#  'opinion',
#  'piece',
#  'deno',
#  'want',
#  'act',
#  'debate',
#  'coach',
#  'provide',
#  'team',
#  'debaters',
#  'motion',
#  'upcoming',
#  'debate',
#  'goal',
#  'prepare',
#  'team',
#  'success',
#  'organizing',
#  'practice',
#  'rounds',
#  'focus',
#  'persuasive',
#  'speech',
#  'effective',
#  'timing',
#  'strategies',
#  'refuting',
#  'opposing',
#  'arguments',
#  'drawing',
#  'depth',
#  'conclusions',
#  'evidence',
#  'provided',
#  'first',
#  'request',
#  'want',
#  'team',
#  'prepared',
#  'upcoming',
#  'debate',
#  'whether',
#  'front',
#  'end',
#  'development',
#  'easy',
#  'want',
#  'act',
#  'screenwriter',
#  'develop',
#  'engaging',
#  'creative',
#  'script',
#  'either',
#  'feature',
#  'length',
#  'film',
#  'web',
#  'series',
#  'captivate',
#  'viewers',
#  'start',
#  'coming',
#  'interesting',
#  'characters',
#  'setting',
#  'story',
#  'dialogues',
#  'characters',
#  'etc',
#  'character',
#  'development',
#  'complete',
#  'create',
#  'exciting',
#  'storyline',
#  'filled',
#  'twists',
#  'turns',
#  'keeps',
#  'viewers',
#  'suspense',
#  'end',
#  'first',
#  'request',
#  'need',
#  'write',
#  'romantic',
#  'drama',
#  'movie',
#  'set',
#  'paris',
#  'want',
#  'act',
#  'novelist',
#  'come',
#  'creative',
#  'captivating',
#  'stories',
#  'engage',
#  'readers',
#  'long',
#  'periods',
#  'time',
#  'may',
#  'choose',
#  'genre',
#  'fantasy',
#  'romance',
#  'historical',
#  'fiction',
#  'aim',
#  'write',
#  'something',
#  'outstanding',
#  'plotline',
#  'engaging',
#  'characters',
#  'unexpected',
#  'climaxes',
#  'first',
#  'request',
#  'need',
#  'write',
#  'science',
#  'fiction',
#  'novel',
#  'set',
#  'future',
#  'want',
#  'act',
#  'movie',
#  'critic',
#  'develop',
#  'engaging',
#  'creative',
#  'movie',
#  'review',
#  'cover',
#  'topics',
#  'like',
#  'plot',
#  'themes',
#  'tone',
#  'acting',
#  'characters',
#  'direction',
#  'score',
#  'cinematography',
#  'production',
#  'design',
#  'special',
#  'effects',
#  'editing',
#  'pace',
#  'dialog',
#  'important',
#  'aspect',
#  'though',
#  'emphasize',
#  'movie',
#  'made',
#  'feel',
#  'really',
#  'resonated',
#  'also',
#  'critical',
#  'movie',
#  'please',
#  'avoid',
#  'spoilers',
#  'first',
#  'request',
#  'need',
#  'write',
#  'movie',
#  'review',
#  'movie',
#  'interstellar',
#  'want',
#  'act',
#  ...]

# %% [markdown]
# 2. Realização do stemming.

# %%
stemmer = nltk.stem.PorterStemmer()
stemmer = [stemmer.stem(word) for word in df_prompt_text]
stemmer
# Out:
# ['imagin',
#  'experienc',
#  'ethereum',
#  'develop',
#  'task',
#  'creat',
#  'smart',
#  'contract',
#  'blockchain',
#  'messeng',
#  'object',
#  'save',
#  'messag',
#  'blockchain',
#  'make',
#  'readabl',
#  'public',
#  'everyon',
#  'writabl',
#  'privat',
#  'person',
#  'deploy',
#  'contract',
#  'count',
#  'mani',
#  'time',
#  'messag',
#  'updat',
#  'develop',
#  'solid',
#  'smart',
#  'contract',
#  'purpos',
#  'includ',
#  'necessari',
#  'function',
#  'consider',
#  'achiev',
#  'specifi',
#  'goal',
#  'pleas',
#  'provid',
#  'code',
#  'relev',
#  'explan',
#  'ensur',
#  'clear',
#  'understand',
#  'implement',
#  'use',
#  'webpilot',
#  'creat',
#  'outlin',
#  'articl',
#  '2',
#  '000',
#  'word',
#  'keyword',
#  'best',
#  'seo',
#  'prompt',
#  'base',
#  'top',
#  '10',
#  'result',
#  'googl',
#  'includ',
#  'everi',
#  'relev',
#  'head',
#  'possibl',
#  'keep',
#  'keyword',
#  'densiti',
#  'head',
#  'high',
#  'section',
#  'outlin',
#  'includ',
#  'word',
#  'count',
#  'includ',
#  'faq',
#  'section',
#  'outlin',
#  'base',
#  'peopl',
#  'also',
#  'ask',
#  'section',
#  'googl',
#  'keyword',
#  'outlin',
#  'must',
#  'detail',
#  'comprehens',
#  'creat',
#  '2',
#  '000',
#  'word',
#  'articl',
#  'gener',
#  'long',
#  'list',
#  'lsi',
#  'nlp',
#  'keyword',
#  'relat',
#  'keyword',
#  'also',
#  'includ',
#  'word',
#  'relat',
#  'keyword',
#  'give',
#  'list',
#  '3',
#  'relev',
#  'extern',
#  'link',
#  'includ',
#  'recommend',
#  'anchor',
#  'text',
#  'make',
#  'sure',
#  'compet',
#  'articl',
#  'split',
#  'outlin',
#  'part',
#  '1',
#  'part',
#  '2',
#  'want',
#  'act',
#  'linux',
#  'termin',
#  'type',
#  'command',
#  'repli',
#  'termin',
#  'show',
#  'want',
#  'repli',
#  'termin',
#  'output',
#  'insid',
#  'one',
#  'uniqu',
#  'code',
#  'block',
#  'noth',
#  'els',
#  'write',
#  'explan',
#  'type',
#  'command',
#  'unless',
#  'instruct',
#  'need',
#  'tell',
#  'someth',
#  'english',
#  'put',
#  'text',
#  'insid',
#  'curli',
#  'bracket',
#  'like',
#  'first',
#  'command',
#  'pwd',
#  'want',
#  'act',
#  'english',
#  'translat',
#  'spell',
#  'corrector',
#  'improv',
#  'speak',
#  'languag',
#  'detect',
#  'languag',
#  'translat',
#  'answer',
#  'correct',
#  'improv',
#  'version',
#  'text',
#  'english',
#  'want',
#  'replac',
#  'simplifi',
#  'a0',
#  'level',
#  'word',
#  'sentenc',
#  'beauti',
#  'eleg',
#  'upper',
#  'level',
#  'english',
#  'word',
#  'sentenc',
#  'keep',
#  'mean',
#  'make',
#  'literari',
#  'want',
#  'repli',
#  'correct',
#  'improv',
#  'noth',
#  'els',
#  'write',
#  'explan',
#  'first',
#  'sentenc',
#  'istanbulu',
#  'cok',
#  'seviyom',
#  'burada',
#  'olmak',
#  'cok',
#  'guzel',
#  'want',
#  'act',
#  'interview',
#  'candid',
#  'ask',
#  'interview',
#  'question',
#  'posit',
#  'posit',
#  'want',
#  'repli',
#  'interview',
#  'write',
#  'convers',
#  'want',
#  'interview',
#  'ask',
#  'question',
#  'wait',
#  'answer',
#  'write',
#  'explan',
#  'ask',
#  'question',
#  'one',
#  'one',
#  'like',
#  'interview',
#  'wait',
#  'answer',
#  'first',
#  'sentenc',
#  'hi',
#  'want',
#  'act',
#  'javascript',
#  'consol',
#  'type',
#  'command',
#  'repli',
#  'javascript',
#  'consol',
#  'show',
#  'want',
#  'repli',
#  'termin',
#  'output',
#  'insid',
#  'one',
#  'uniqu',
#  'code',
#  'block',
#  'noth',
#  'els',
#  'write',
#  'explan',
#  'type',
#  'command',
#  'unless',
#  'instruct',
#  'need',
#  'tell',
#  'someth',
#  'english',
#  'put',
#  'text',
#  'insid',
#  'curli',
#  'bracket',
#  'like',
#  'first',
#  'command',
#  'consol',
#  'log',
#  'hello',
#  'world',
#  'want',
#  'act',
#  'text',
#  'base',
#  'excel',
#  'repli',
#  'text',
#  'base',
#  '10',
#  'row',
#  'excel',
#  'sheet',
#  'row',
#  'number',
#  'cell',
#  'letter',
#  'column',
#  'l',
#  'first',
#  'column',
#  'header',
#  'empti',
#  'refer',
#  'row',
#  'number',
#  'tell',
#  'write',
#  'cell',
#  'repli',
#  'result',
#  'excel',
#  'tabl',
#  'text',
#  'noth',
#  'els',
#  'write',
#  'explan',
#  'write',
#  'formula',
#  'execut',
#  'formula',
#  'repli',
#  'result',
#  'excel',
#  'tabl',
#  'text',
#  'first',
#  'repli',
#  'empti',
#  'sheet',
#  'want',
#  'act',
#  'english',
#  'pronunci',
#  'assist',
#  'turkish',
#  'speak',
#  'peopl',
#  'write',
#  'sentenc',
#  'answer',
#  'pronunci',
#  'noth',
#  'els',
#  'repli',
#  'must',
#  'translat',
#  'sentenc',
#  'pronunci',
#  'pronunci',
#  'use',
#  'turkish',
#  'latin',
#  'letter',
#  'phonet',
#  'write',
#  'explan',
#  'repli',
#  'first',
#  'sentenc',
#  'weather',
#  'istanbul',
#  'want',
#  'act',
#  'spoken',
#  'english',
#  'teacher',
#  'improv',
#  'speak',
#  'english',
#  'repli',
#  'english',
#  'practic',
#  'spoken',
#  'english',
#  'want',
#  'keep',
#  'repli',
#  'neat',
#  'limit',
#  'repli',
#  '100',
#  'word',
#  'want',
#  'strictli',
#  'correct',
#  'grammar',
#  'mistak',
#  'typo',
#  'factual',
#  'error',
#  'want',
#  'ask',
#  'question',
#  'repli',
#  'let',
#  'start',
#  'practic',
#  'could',
#  'ask',
#  'question',
#  'first',
#  'rememb',
#  'want',
#  'strictli',
#  'correct',
#  'grammar',
#  'mistak',
#  'typo',
#  'factual',
#  'error',
#  'want',
#  'act',
#  'travel',
#  'guid',
#  'write',
#  'locat',
#  'suggest',
#  'place',
#  'visit',
#  'near',
#  'locat',
#  'case',
#  'also',
#  'give',
#  'type',
#  'place',
#  'visit',
#  'also',
#  'suggest',
#  'place',
#  'similar',
#  'type',
#  'close',
#  'first',
#  'locat',
#  'first',
#  'suggest',
#  'request',
#  'istanbul',
#  'beyoğlu',
#  'want',
#  'visit',
#  'museum',
#  'want',
#  'act',
#  'plagiar',
#  'checker',
#  'write',
#  'sentenc',
#  'repli',
#  'undetect',
#  'plagiar',
#  'check',
#  'languag',
#  'given',
#  'sentenc',
#  'noth',
#  'els',
#  'write',
#  'explan',
#  'repli',
#  'first',
#  'sentenc',
#  'comput',
#  'behav',
#  'like',
#  'human',
#  'speech',
#  'recognit',
#  'system',
#  'must',
#  'abl',
#  'process',
#  'nonverb',
#  'inform',
#  'emot',
#  'state',
#  'speaker',
#  'want',
#  'act',
#  'like',
#  'charact',
#  'seri',
#  'want',
#  'respond',
#  'answer',
#  'like',
#  'charact',
#  'use',
#  'tone',
#  'manner',
#  'vocabulari',
#  'charact',
#  'would',
#  'use',
#  'write',
#  'explan',
#  'answer',
#  'like',
#  'charact',
#  'must',
#  'know',
#  'knowledg',
#  'charact',
#  'first',
#  'sentenc',
#  'hi',
#  'charact',
#  'want',
#  'act',
#  'advertis',
#  'creat',
#  'campaign',
#  'promot',
#  'product',
#  'servic',
#  'choic',
#  'choos',
#  'target',
#  'audienc',
#  'develop',
#  'key',
#  'messag',
#  'slogan',
#  'select',
#  'media',
#  'channel',
#  'promot',
#  'decid',
#  'addit',
#  'activ',
#  'need',
#  'reach',
#  'goal',
#  'first',
#  'suggest',
#  'request',
#  'need',
#  'help',
#  'creat',
#  'advertis',
#  'campaign',
#  'new',
#  'type',
#  'energi',
#  'drink',
#  'target',
#  'young',
#  'adult',
#  'age',
#  '18',
#  '30',
#  'want',
#  'act',
#  'storytel',
#  'come',
#  'entertain',
#  'stori',
#  'engag',
#  'imagin',
#  'captiv',
#  'audienc',
#  'fairi',
#  'tale',
#  'educ',
#  'stori',
#  'type',
#  'stori',
#  'potenti',
#  'captur',
#  'peopl',
#  'attent',
#  'imagin',
#  'depend',
#  'target',
#  'audienc',
#  'may',
#  'choos',
#  'specif',
#  'theme',
#  'topic',
#  'storytel',
#  'session',
#  'e',
#  'g',
#  'children',
#  'talk',
#  'anim',
#  'adult',
#  'histori',
#  'base',
#  'tale',
#  'might',
#  'engag',
#  'better',
#  'etc',
#  'first',
#  'request',
#  'need',
#  'interest',
#  'stori',
#  'persever',
#  'want',
#  'act',
#  'footbal',
#  'comment',
#  'give',
#  'descript',
#  'footbal',
#  'match',
#  'progress',
#  'comment',
#  'match',
#  'provid',
#  'analysi',
#  'happen',
#  'thu',
#  'far',
#  'predict',
#  'game',
#  'may',
#  'end',
#  'knowledg',
#  'footbal',
#  'terminolog',
#  'tactic',
#  'player',
#  'team',
#  'involv',
#  'match',
#  'focu',
#  'primarili',
#  'provid',
#  'intellig',
#  'commentari',
#  'rather',
#  'narrat',
#  'play',
#  'play',
#  'first',
#  'request',
#  'watch',
#  'manchest',
#  'unit',
#  'vs',
#  'chelsea',
#  'provid',
#  'commentari',
#  'match',
#  'want',
#  'act',
#  'stand',
#  'comedian',
#  'provid',
#  'topic',
#  'relat',
#  'current',
#  'event',
#  'use',
#  'wit',
#  'creativ',
#  'observ',
#  'skill',
#  'creat',
#  'routin',
#  'base',
#  'topic',
#  'also',
#  'sure',
#  'incorpor',
#  'person',
#  'anecdot',
#  'experi',
#  'routin',
#  'order',
#  'make',
#  'relat',
#  'engag',
#  'audienc',
#  'first',
#  'request',
#  'want',
#  'humor',
#  'take',
#  'polit',
#  'want',
#  'act',
#  'motiv',
#  'coach',
#  'provid',
#  'inform',
#  'someon',
#  'goal',
#  'challeng',
#  'job',
#  'come',
#  'strategi',
#  'help',
#  'person',
#  'achiev',
#  'goal',
#  'could',
#  'involv',
#  'provid',
#  'posit',
#  'affirm',
#  'give',
#  'help',
#  'advic',
#  'suggest',
#  'activ',
#  'reach',
#  'end',
#  'goal',
#  'first',
#  'request',
#  'need',
#  'help',
#  'motiv',
#  'stay',
#  'disciplin',
#  'studi',
#  'upcom',
#  'exam',
#  'want',
#  'act',
#  'compos',
#  'provid',
#  'lyric',
#  'song',
#  'creat',
#  'music',
#  'could',
#  'includ',
#  'use',
#  'variou',
#  'instrument',
#  'tool',
#  'synthes',
#  'sampler',
#  'order',
#  'creat',
#  'melodi',
#  'harmoni',
#  'bring',
#  'lyric',
#  'life',
#  'first',
#  'request',
#  'written',
#  'poem',
#  'name',
#  'hayalet',
#  'sevgilim',
#  'need',
#  'music',
#  'go',
#  'want',
#  'act',
#  'debat',
#  'provid',
#  'topic',
#  'relat',
#  'current',
#  'event',
#  'task',
#  'research',
#  'side',
#  'debat',
#  'present',
#  'valid',
#  'argument',
#  'side',
#  'refut',
#  'oppos',
#  'point',
#  'view',
#  'draw',
#  'persuas',
#  'conclus',
#  'base',
#  'evid',
#  'goal',
#  'help',
#  'peopl',
#  'come',
#  'away',
#  'discuss',
#  'increas',
#  'knowledg',
#  'insight',
#  'topic',
#  'hand',
#  'first',
#  'request',
#  'want',
#  'opinion',
#  'piec',
#  'deno',
#  'want',
#  'act',
#  'debat',
#  'coach',
#  'provid',
#  'team',
#  'debat',
#  'motion',
#  'upcom',
#  'debat',
#  'goal',
#  'prepar',
#  'team',
#  'success',
#  'organ',
#  'practic',
#  'round',
#  'focu',
#  'persuas',
#  'speech',
#  'effect',
#  'time',
#  'strategi',
#  'refut',
#  'oppos',
#  'argument',
#  'draw',
#  'depth',
#  'conclus',
#  'evid',
#  'provid',
#  'first',
#  'request',
#  'want',
#  'team',
#  'prepar',
#  'upcom',
#  'debat',
#  'whether',
#  'front',
#  'end',
#  'develop',
#  'easi',
#  'want',
#  'act',
#  'screenwrit',
#  'develop',
#  'engag',
#  'creativ',
#  'script',
#  'either',
#  'featur',
#  'length',
#  'film',
#  'web',
#  'seri',
#  'captiv',
#  'viewer',
#  'start',
#  'come',
#  'interest',
#  'charact',
#  'set',
#  'stori',
#  'dialogu',
#  'charact',
#  'etc',
#  'charact',
#  'develop',
#  'complet',
#  'creat',
#  'excit',
#  'storylin',
#  'fill',
#  'twist',
#  'turn',
#  'keep',
#  'viewer',
#  'suspens',
#  'end',
#  'first',
#  'request',
#  'need',
#  'write',
#  'romant',
#  'drama',
#  'movi',
#  'set',
#  'pari',
#  'want',
#  'act',
#  'novelist',
#  'come',
#  'creativ',
#  'captiv',
#  'stori',
#  'engag',
#  'reader',
#  'long',
#  'period',
#  'time',
#  'may',
#  'choos',
#  'genr',
#  'fantasi',
#  'romanc',
#  'histor',
#  'fiction',
#  'aim',
#  'write',
#  'someth',
#  'outstand',
#  'plotlin',
#  'engag',
#  'charact',
#  'unexpect',
#  'climax',
#  'first',
#  'request',
#  'need',
#  'write',
#  'scienc',
#  'fiction',
#  'novel',
#  'set',
#  'futur',
#  'want',
#  'act',
#  'movi',
#  'critic',
#  'develop',
#  'engag',
#  'creativ',
#  'movi',
#  'review',
#  'cover',
#  'topic',
#  'like',
#  'plot',
#  'theme',
#  'tone',
#  'act',
#  'charact',
#  'direct',
#  'score',
#  'cinematographi',
#  'product',
#  'design',
#  'special',
#  'effect',
#  'edit',
#  'pace',
#  'dialog',
#  'import',
#  'aspect',
#  'though',
#  'emphas',
#  'movi',
#  'made',
#  'feel',
#  'realli',
#  'reson',
#  'also',
#  'critic',
#  'movi',
#  'pleas',
#  'avoid',
#  'spoiler',
#  'first',
#  'request',
#  'need',
#  'write',
#  'movi',
#  'review',
#  'movi',
#  'interstellar',
#  'want',
#  'act',
#  ...]

# %% [markdown]
# ## 🔎 Extração de trigramas
# 1. Criação de uma lista com três palavras consecutivas do texto.

# %%
trigrams = [(stemmer[i], stemmer[i+1], stemmer[i+2]) for i in range(len(stemmer)-2)]
trigrams
# Out:
# [('imagin', 'experienc', 'ethereum'),
#  ('experienc', 'ethereum', 'develop'),
#  ('ethereum', 'develop', 'task'),
#  ('develop', 'task', 'creat'),
#  ('task', 'creat', 'smart'),
#  ('creat', 'smart', 'contract'),
#  ('smart', 'contract', 'blockchain'),
#  ('contract', 'blockchain', 'messeng'),
#  ('blockchain', 'messeng', 'object'),
#  ('messeng', 'object', 'save'),
#  ('object', 'save', 'messag'),
#  ('save', 'messag', 'blockchain'),
#  ('messag', 'blockchain', 'make'),
#  ('blockchain', 'make', 'readabl'),
#  ('make', 'readabl', 'public'),
#  ('readabl', 'public', 'everyon'),
#  ('public', 'everyon', 'writabl'),
#  ('everyon', 'writabl', 'privat'),
#  ('writabl', 'privat', 'person'),
#  ('privat', 'person', 'deploy'),
#  ('person', 'deploy', 'contract'),
#  ('deploy', 'contract', 'count'),
#  ('contract', 'count', 'mani'),
#  ('count', 'mani', 'time'),
#  ('mani', 'time', 'messag'),
#  ('time', 'messag', 'updat'),
#  ('messag', 'updat', 'develop'),
#  ('updat', 'develop', 'solid'),
#  ('develop', 'solid', 'smart'),
#  ('solid', 'smart', 'contract'),
#  ('smart', 'contract', 'purpos'),
#  ('contract', 'purpos', 'includ'),
#  ('purpos', 'includ', 'necessari'),
#  ('includ', 'necessari', 'function'),
#  ('necessari', 'function', 'consider'),
#  ('function', 'consider', 'achiev'),
#  ('consider', 'achiev', 'specifi'),
#  ('achiev', 'specifi', 'goal'),
#  ('specifi', 'goal', 'pleas'),
#  ('goal', 'pleas', 'provid'),
#  ('pleas', 'provid', 'code'),
#  ('provid', 'code', 'relev'),
#  ('code', 'relev', 'explan'),
#  ('relev', 'explan', 'ensur'),
#  ('explan', 'ensur', 'clear'),
#  ('ensur', 'clear', 'understand'),
#  ('clear', 'understand', 'implement'),
#  ('understand', 'implement', 'use'),
#  ('implement', 'use', 'webpilot'),
#  ('use', 'webpilot', 'creat'),
#  ('webpilot', 'creat', 'outlin'),
#  ('creat', 'outlin', 'articl'),
#  ('outlin', 'articl', '2'),
#  ('articl', '2', '000'),
#  ('2', '000', 'word'),
#  ('000', 'word', 'keyword'),
#  ('word', 'keyword', 'best'),
#  ('keyword', 'best', 'seo'),
#  ('best', 'seo', 'prompt'),
#  ('seo', 'prompt', 'base'),
#  ('prompt', 'base', 'top'),
#  ('base', 'top', '10'),
#  ('top', '10', 'result'),
#  ('10', 'result', 'googl'),
#  ('result', 'googl', 'includ'),
#  ('googl', 'includ', 'everi'),
#  ('includ', 'everi', 'relev'),
#  ('everi', 'relev', 'head'),
#  ('relev', 'head', 'possibl'),
#  ('head', 'possibl', 'keep'),
#  ('possibl', 'keep', 'keyword'),
#  ('keep', 'keyword', 'densiti'),
#  ('keyword', 'densiti', 'head'),
#  ('densiti', 'head', 'high'),
#  ('head', 'high', 'section'),
#  ('high', 'section', 'outlin'),
#  ('section', 'outlin', 'includ'),
#  ('outlin', 'includ', 'word'),
#  ('includ', 'word', 'count'),
#  ('word', 'count', 'includ'),
#  ('count', 'includ', 'faq'),
#  ('includ', 'faq', 'section'),
#  ('faq', 'section', 'outlin'),
#  ('section', 'outlin', 'base'),
#  ('outlin', 'base', 'peopl'),
#  ('base', 'peopl', 'also'),
#  ('peopl', 'also', 'ask'),
#  ('also', 'ask', 'section'),
#  ('ask', 'section', 'googl'),
#  ('section', 'googl', 'keyword'),
#  ('googl', 'keyword', 'outlin'),
#  ('keyword', 'outlin', 'must'),
#  ('outlin', 'must', 'detail'),
#  ('must', 'detail', 'comprehens'),
#  ('detail', 'comprehens', 'creat'),
#  ('comprehens', 'creat', '2'),
#  ('creat', '2', '000'),
#  ('2', '000', 'word'),
#  ('000', 'word', 'articl'),
#  ('word', 'articl', 'gener'),
#  ('articl', 'gener', 'long'),
#  ('gener', 'long', 'list'),
#  ('long', 'list', 'lsi'),
#  ('list', 'lsi', 'nlp'),
#  ('lsi', 'nlp', 'keyword'),
#  ('nlp', 'keyword', 'relat'),
#  ('keyword', 'relat', 'keyword'),
#  ('relat', 'keyword', 'also'),
#  ('keyword', 'also', 'includ'),
#  ('also', 'includ', 'word'),
#  ('includ', 'word', 'relat'),
#  ('word', 'relat', 'keyword'),
#  ('relat', 'keyword', 'give'),
#  ('keyword', 'give', 'list'),
#  ('give', 'list', '3'),
#  ('list', '3', 'relev'),
#  ('3', 'relev', 'extern'),
#  ('relev', 'extern', 'link'),
#  ('extern', 'link', 'includ'),
#  ('link', 'includ', 'recommend'),
#  ('includ', 'recommend', 'anchor'),
#  ('recommend', 'anchor', 'text'),
#  ('anchor', 'text', 'make'),
#  ('text', 'make', 'sure'),
#  ('make', 'sure', 'compet'),
#  ('sure', 'compet', 'articl'),
#  ('compet', 'articl', 'split'),
#  ('articl', 'split', 'outlin'),
#  ('split', 'outlin', 'part'),
#  ('outlin', 'part', '1'),
#  ('part', '1', 'part'),
#  ('1', 'part', '2'),
#  ('part', '2', 'want'),
#  ('2', 'want', 'act'),
#  ('want', 'act', 'linux'),
#  ('act', 'linux', 'termin'),
#  ('linux', 'termin', 'type'),
#  ('termin', 'type', 'command'),
#  ('type', 'command', 'repli'),
#  ('command', 'repli', 'termin'),
#  ('repli', 'termin', 'show'),
#  ('termin', 'show', 'want'),
#  ('show', 'want', 'repli'),
#  ('want', 'repli', 'termin'),
#  ('repli', 'termin', 'output'),
#  ('termin', 'output', 'insid'),
#  ('output', 'insid', 'one'),
#  ('insid', 'one', 'uniqu'),
#  ('one', 'uniqu', 'code'),
#  ('uniqu', 'code', 'block'),
#  ('code', 'block', 'noth'),
#  ('block', 'noth', 'els'),
#  ('noth', 'els', 'write'),
#  ('els', 'write', 'explan'),
#  ('write', 'explan', 'type'),
#  ('explan', 'type', 'command'),
#  ('type', 'command', 'unless'),
#  ('command', 'unless', 'instruct'),
#  ('unless', 'instruct', 'need'),
#  ('instruct', 'need', 'tell'),
#  ('need', 'tell', 'someth'),
#  ('tell', 'someth', 'english'),
#  ('someth', 'english', 'put'),
#  ('english', 'put', 'text'),
#  ('put', 'text', 'insid'),
#  ('text', 'insid', 'curli'),
#  ('insid', 'curli', 'bracket'),
#  ('curli', 'bracket', 'like'),
#  ('bracket', 'like', 'first'),
#  ('like', 'first', 'command'),
#  ('first', 'command', 'pwd'),
#  ('command', 'pwd', 'want'),
#  ('pwd', 'want', 'act'),
#  ('want', 'act', 'english'),
#  ('act', 'english', 'translat'),
#  ('english', 'translat', 'spell'),
#  ('translat', 'spell', 'corrector'),
#  ('spell', 'corrector', 'improv'),
#  ('corrector', 'improv', 'speak'),
#  ('improv', 'speak', 'languag'),
#  ('speak', 'languag', 'detect'),
#  ('languag', 'detect', 'languag'),
#  ('detect', 'languag', 'translat'),
#  ('languag', 'translat', 'answer'),
#  ('translat', 'answer', 'correct'),
#  ('answer', 'correct', 'improv'),
#  ('correct', 'improv', 'version'),
#  ('improv', 'version', 'text'),
#  ('version', 'text', 'english'),
#  ('text', 'english', 'want'),
#  ('english', 'want', 'replac'),
#  ('want', 'replac', 'simplifi'),
#  ('replac', 'simplifi', 'a0'),
#  ('simplifi', 'a0', 'level'),
#  ('a0', 'level', 'word'),
#  ('level', 'word', 'sentenc'),
#  ('word', 'sentenc', 'beauti'),
#  ('sentenc', 'beauti', 'eleg'),
#  ('beauti', 'eleg', 'upper'),
#  ('eleg', 'upper', 'level'),
#  ('upper', 'level', 'english'),
#  ('level', 'english', 'word'),
#  ('english', 'word', 'sentenc'),
#  ('word', 'sentenc', 'keep'),
#  ('sentenc', 'keep', 'mean'),
#  ('keep', 'mean', 'make'),
#  ('mean', 'make', 'literari'),
#  ('make', 'literari', 'want'),
#  ('literari', 'want', 'repli'),
#  ('want', 'repli', 'correct'),
#  ('repli', 'correct', 'improv'),
#  ('correct', 'improv', 'noth'),
#  ('improv', 'noth', 'els'),
#  ('noth', 'els', 'write'),
#  ('els', 'write', 'explan'),
#  ('write', 'explan', 'first'),
#  ('explan', 'first', 'sentenc'),
#  ('first', 'sentenc', 'istanbulu'),
#  ('sentenc', 'istanbulu', 'cok'),
#  ('istanbulu', 'cok', 'seviyom'),
#  ('cok', 'seviyom', 'burada'),
#  ('seviyom', 'burada', 'olmak'),
#  ('burada', 'olmak', 'cok'),
#  ('olmak', 'cok', 'guzel'),
#  ('cok', 'guzel', 'want'),
#  ('guzel', 'want', 'act'),
#  ('want', 'act', 'interview'),
#  ('act', 'interview', 'candid'),
#  ('interview', 'candid', 'ask'),
#  ('candid', 'ask', 'interview'),
#  ('ask', 'interview', 'question'),
#  ('interview', 'question', 'posit'),
#  ('question', 'posit', 'posit'),
#  ('posit', 'posit', 'want'),
#  ('posit', 'want', 'repli'),
#  ('want', 'repli', 'interview'),
#  ('repli', 'interview', 'write'),
#  ('interview', 'write', 'convers'),
#  ('write', 'convers', 'want'),
#  ('convers', 'want', 'interview'),
#  ('want', 'interview', 'ask'),
#  ('interview', 'ask', 'question'),
#  ('ask', 'question', 'wait'),
#  ('question', 'wait', 'answer'),
#  ('wait', 'answer', 'write'),
#  ('answer', 'write', 'explan'),
#  ('write', 'explan', 'ask'),
#  ('explan', 'ask', 'question'),
#  ('ask', 'question', 'one'),
#  ('question', 'one', 'one'),
#  ('one', 'one', 'like'),
#  ('one', 'like', 'interview'),
#  ('like', 'interview', 'wait'),
#  ('interview', 'wait', 'answer'),
#  ('wait', 'answer', 'first'),
#  ('answer', 'first', 'sentenc'),
#  ('first', 'sentenc', 'hi'),
#  ('sentenc', 'hi', 'want'),
#  ('hi', 'want', 'act'),
#  ('want', 'act', 'javascript'),
#  ('act', 'javascript', 'consol'),
#  ('javascript', 'consol', 'type'),
#  ('consol', 'type', 'command'),
#  ('type', 'command', 'repli'),
#  ('command', 'repli', 'javascript'),
#  ('repli', 'javascript', 'consol'),
#  ('javascript', 'consol', 'show'),
#  ('consol', 'show', 'want'),
#  ('show', 'want', 'repli'),
#  ('want', 'repli', 'termin'),
#  ('repli', 'termin', 'output'),
#  ('termin', 'output', 'insid'),
#  ('output', 'insid', 'one'),
#  ('insid', 'one', 'uniqu'),
#  ('one', 'uniqu', 'code'),
#  ('uniqu', 'code', 'block'),
#  ('code', 'block', 'noth'),
#  ('block', 'noth', 'els'),
#  ('noth', 'els', 'write'),
#  ('els', 'write', 'explan'),
#  ('write', 'explan', 'type'),
#  ('explan', 'type', 'command'),
#  ('type', 'command', 'unless'),
#  ('command', 'unless', 'instruct'),
#  ('unless', 'instruct', 'need'),
#  ('instruct', 'need', 'tell'),
#  ('need', 'tell', 'someth'),
#  ('tell', 'someth', 'english'),
#  ('someth', 'english', 'put'),
#  ('english', 'put', 'text'),
#  ('put', 'text', 'insid'),
#  ('text', 'insid', 'curli'),
#  ('insid', 'curli', 'bracket'),
#  ('curli', 'bracket', 'like'),
#  ('bracket', 'like', 'first'),
#  ('like', 'first', 'command'),
#  ('first', 'command', 'consol'),
#  ('command', 'consol', 'log'),
#  ('consol', 'log', 'hello'),
#  ('log', 'hello', 'world'),
#  ('hello', 'world', 'want'),
#  ('world', 'want', 'act'),
#  ('want', 'act', 'text'),
#  ('act', 'text', 'base'),
#  ('text', 'base', 'excel'),
#  ('base', 'excel', 'repli'),
#  ('excel', 'repli', 'text'),
#  ('repli', 'text', 'base'),
#  ('text', 'base', '10'),
#  ('base', '10', 'row'),
#  ('10', 'row', 'excel'),
#  ('row', 'excel', 'sheet'),
#  ('excel', 'sheet', 'row'),
#  ('sheet', 'row', 'number'),
#  ('row', 'number', 'cell'),
#  ('number', 'cell', 'letter'),
#  ('cell', 'letter', 'column'),
#  ('letter', 'column', 'l'),
#  ('column', 'l', 'first'),
#  ('l', 'first', 'column'),
#  ('first', 'column', 'header'),
#  ('column', 'header', 'empti'),
#  ('header', 'empti', 'refer'),
#  ('empti', 'refer', 'row'),
#  ('refer', 'row', 'number'),
#  ('row', 'number', 'tell'),
#  ('number', 'tell', 'write'),
#  ('tell', 'write', 'cell'),
#  ('write', 'cell', 'repli'),
#  ('cell', 'repli', 'result'),
#  ('repli', 'result', 'excel'),
#  ('result', 'excel', 'tabl'),
#  ('excel', 'tabl', 'text'),
#  ('tabl', 'text', 'noth'),
#  ('text', 'noth', 'els'),
#  ('noth', 'els', 'write'),
#  ('els', 'write', 'explan'),
#  ('write', 'explan', 'write'),
#  ('explan', 'write', 'formula'),
#  ('write', 'formula', 'execut'),
#  ('formula', 'execut', 'formula'),
#  ('execut', 'formula', 'repli'),
#  ('formula', 'repli', 'result'),
#  ('repli', 'result', 'excel'),
#  ('result', 'excel', 'tabl'),
#  ('excel', 'tabl', 'text'),
#  ('tabl', 'text', 'first'),
#  ('text', 'first', 'repli'),
#  ('first', 'repli', 'empti'),
#  ('repli', 'empti', 'sheet'),
#  ('empti', 'sheet', 'want'),
#  ('sheet', 'want', 'act'),
#  ('want', 'act', 'english'),
#  ('act', 'english', 'pronunci'),
#  ('english', 'pronunci', 'assist'),
#  ('pronunci', 'assist', 'turkish'),
#  ('assist', 'turkish', 'speak'),
#  ('turkish', 'speak', 'peopl'),
#  ('speak', 'peopl', 'write'),
#  ('peopl', 'write', 'sentenc'),
#  ('write', 'sentenc', 'answer'),
#  ('sentenc', 'answer', 'pronunci'),
#  ('answer', 'pronunci', 'noth'),
#  ('pronunci', 'noth', 'els'),
#  ('noth', 'els', 'repli'),
#  ('els', 'repli', 'must'),
#  ('repli', 'must', 'translat'),
#  ('must', 'translat', 'sentenc'),
#  ('translat', 'sentenc', 'pronunci'),
#  ('sentenc', 'pronunci', 'pronunci'),
#  ('pronunci', 'pronunci', 'use'),
#  ('pronunci', 'use', 'turkish'),
#  ('use', 'turkish', 'latin'),
#  ('turkish', 'latin', 'letter'),
#  ('latin', 'letter', 'phonet'),
#  ('letter', 'phonet', 'write'),
#  ('phonet', 'write', 'explan'),
#  ('write', 'explan', 'repli'),
#  ('explan', 'repli', 'first'),
#  ('repli', 'first', 'sentenc'),
#  ('first', 'sentenc', 'weather'),
#  ('sentenc', 'weather', 'istanbul'),
#  ('weather', 'istanbul', 'want'),
#  ('istanbul', 'want', 'act'),
#  ('want', 'act', 'spoken'),
#  ('act', 'spoken', 'english'),
#  ('spoken', 'english', 'teacher'),
#  ('english', 'teacher', 'improv'),
#  ('teacher', 'improv', 'speak'),
#  ('improv', 'speak', 'english'),
#  ('speak', 'english', 'repli'),
#  ('english', 'repli', 'english'),
#  ('repli', 'english', 'practic'),
#  ('english', 'practic', 'spoken'),
#  ('practic', 'spoken', 'english'),
#  ('spoken', 'english', 'want'),
#  ('english', 'want', 'keep'),
#  ('want', 'keep', 'repli'),
#  ('keep', 'repli', 'neat'),
#  ('repli', 'neat', 'limit'),
#  ('neat', 'limit', 'repli'),
#  ('limit', 'repli', '100'),
#  ('repli', '100', 'word'),
#  ('100', 'word', 'want'),
#  ('word', 'want', 'strictli'),
#  ('want', 'strictli', 'correct'),
#  ('strictli', 'correct', 'grammar'),
#  ('correct', 'grammar', 'mistak'),
#  ('grammar', 'mistak', 'typo'),
#  ('mistak', 'typo', 'factual'),
#  ('typo', 'factual', 'error'),
#  ('factual', 'error', 'want'),
#  ('error', 'want', 'ask'),
#  ('want', 'ask', 'question'),
#  ('ask', 'question', 'repli'),
#  ('question', 'repli', 'let'),
#  ('repli', 'let', 'start'),
#  ('let', 'start', 'practic'),
#  ('start', 'practic', 'could'),
#  ('practic', 'could', 'ask'),
#  ('could', 'ask', 'question'),
#  ('ask', 'question', 'first'),
#  ('question', 'first', 'rememb'),
#  ('first', 'rememb', 'want'),
#  ('rememb', 'want', 'strictli'),
#  ('want', 'strictli', 'correct'),
#  ('strictli', 'correct', 'grammar'),
#  ('correct', 'grammar', 'mistak'),
#  ('grammar', 'mistak', 'typo'),
#  ('mistak', 'typo', 'factual'),
#  ('typo', 'factual', 'error'),
#  ('factual', 'error', 'want'),
#  ('error', 'want', 'act'),
#  ('want', 'act', 'travel'),
#  ('act', 'travel', 'guid'),
#  ('travel', 'guid', 'write'),
#  ('guid', 'write', 'locat'),
#  ('write', 'locat', 'suggest'),
#  ('locat', 'suggest', 'place'),
#  ('suggest', 'place', 'visit'),
#  ('place', 'visit', 'near'),
#  ('visit', 'near', 'locat'),
#  ('near', 'locat', 'case'),
#  ('locat', 'case', 'also'),
#  ('case', 'also', 'give'),
#  ('also', 'give', 'type'),
#  ('give', 'type', 'place'),
#  ('type', 'place', 'visit'),
#  ('place', 'visit', 'also'),
#  ('visit', 'also', 'suggest'),
#  ('also', 'suggest', 'place'),
#  ('suggest', 'place', 'similar'),
#  ('place', 'similar', 'type'),
#  ('similar', 'type', 'close'),
#  ('type', 'close', 'first'),
#  ('close', 'first', 'locat'),
#  ('first', 'locat', 'first'),
#  ('locat', 'first', 'suggest'),
#  ('first', 'suggest', 'request'),
#  ('suggest', 'request', 'istanbul'),
#  ('request', 'istanbul', 'beyoğlu'),
#  ('istanbul', 'beyoğlu', 'want'),
#  ('beyoğlu', 'want', 'visit'),
#  ('want', 'visit', 'museum'),
#  ('visit', 'museum', 'want'),
#  ('museum', 'want', 'act'),
#  ('want', 'act', 'plagiar'),
#  ('act', 'plagiar', 'checker'),
#  ('plagiar', 'checker', 'write'),
#  ('checker', 'write', 'sentenc'),
#  ('write', 'sentenc', 'repli'),
#  ('sentenc', 'repli', 'undetect'),
#  ('repli', 'undetect', 'plagiar'),
#  ('undetect', 'plagiar', 'check'),
#  ('plagiar', 'check', 'languag'),
#  ('check', 'languag', 'given'),
#  ('languag', 'given', 'sentenc'),
#  ('given', 'sentenc', 'noth'),
#  ('sentenc', 'noth', 'els'),
#  ('noth', 'els', 'write'),
#  ('els', 'write', 'explan'),
#  ('write', 'explan', 'repli'),
#  ('explan', 'repli', 'first'),
#  ('repli', 'first', 'sentenc'),
#  ('first', 'sentenc', 'comput'),
#  ('sentenc', 'comput', 'behav'),
#  ('comput', 'behav', 'like'),
#  ('behav', 'like', 'human'),
#  ('like', 'human', 'speech'),
#  ('human', 'speech', 'recognit'),
#  ('speech', 'recognit', 'system'),
#  ('recognit', 'system', 'must'),
#  ('system', 'must', 'abl'),
#  ('must', 'abl', 'process'),
#  ('abl', 'process', 'nonverb'),
#  ('process', 'nonverb', 'inform'),
#  ('nonverb', 'inform', 'emot'),
#  ('inform', 'emot', 'state'),
#  ('emot', 'state', 'speaker'),
#  ('state', 'speaker', 'want'),
#  ('speaker', 'want', 'act'),
#  ('want', 'act', 'like'),
#  ('act', 'like', 'charact'),
#  ('like', 'charact', 'seri'),
#  ('charact', 'seri', 'want'),
#  ('seri', 'want', 'respond'),
#  ('want', 'respond', 'answer'),
#  ('respond', 'answer', 'like'),
#  ('answer', 'like', 'charact'),
#  ('like', 'charact', 'use'),
#  ('charact', 'use', 'tone'),
#  ('use', 'tone', 'manner'),
#  ('tone', 'manner', 'vocabulari'),
#  ('manner', 'vocabulari', 'charact'),
#  ('vocabulari', 'charact', 'would'),
#  ('charact', 'would', 'use'),
#  ('would', 'use', 'write'),
#  ('use', 'write', 'explan'),
#  ('write', 'explan', 'answer'),
#  ('explan', 'answer', 'like'),
#  ('answer', 'like', 'charact'),
#  ('like', 'charact', 'must'),
#  ('charact', 'must', 'know'),
#  ('must', 'know', 'knowledg'),
#  ('know', 'knowledg', 'charact'),
#  ('knowledg', 'charact', 'first'),
#  ('charact', 'first', 'sentenc'),
#  ('first', 'sentenc', 'hi'),
#  ('sentenc', 'hi', 'charact'),
#  ('hi', 'charact', 'want'),
#  ('charact', 'want', 'act'),
#  ('want', 'act', 'advertis'),
#  ('act', 'advertis', 'creat'),
#  ('advertis', 'creat', 'campaign'),
#  ('creat', 'campaign', 'promot'),
#  ('campaign', 'promot', 'product'),
#  ('promot', 'product', 'servic'),
#  ('product', 'servic', 'choic'),
#  ('servic', 'choic', 'choos'),
#  ('choic', 'choos', 'target'),
#  ('choos', 'target', 'audienc'),
#  ('target', 'audienc', 'develop'),
#  ('audienc', 'develop', 'key'),
#  ('develop', 'key', 'messag'),
#  ('key', 'messag', 'slogan'),
#  ('messag', 'slogan', 'select'),
#  ('slogan', 'select', 'media'),
#  ('select', 'media', 'channel'),
#  ('media', 'channel', 'promot'),
#  ('channel', 'promot', 'decid'),
#  ('promot', 'decid', 'addit'),
#  ('decid', 'addit', 'activ'),
#  ('addit', 'activ', 'need'),
#  ('activ', 'need', 'reach'),
#  ('need', 'reach', 'goal'),
#  ('reach', 'goal', 'first'),
#  ('goal', 'first', 'suggest'),
#  ('first', 'suggest', 'request'),
#  ('suggest', 'request', 'need'),
#  ('request', 'need', 'help'),
#  ('need', 'help', 'creat'),
#  ('help', 'creat', 'advertis'),
#  ('creat', 'advertis', 'campaign'),
#  ('advertis', 'campaign', 'new'),
#  ('campaign', 'new', 'type'),
#  ('new', 'type', 'energi'),
#  ('type', 'energi', 'drink'),
#  ('energi', 'drink', 'target'),
#  ('drink', 'target', 'young'),
#  ('target', 'young', 'adult'),
#  ('young', 'adult', 'age'),
#  ('adult', 'age', '18'),
#  ('age', '18', '30'),
#  ('18', '30', 'want'),
#  ('30', 'want', 'act'),
#  ('want', 'act', 'storytel'),
#  ('act', 'storytel', 'come'),
#  ('storytel', 'come', 'entertain'),
#  ('come', 'entertain', 'stori'),
#  ('entertain', 'stori', 'engag'),
#  ('stori', 'engag', 'imagin'),
#  ('engag', 'imagin', 'captiv'),
#  ('imagin', 'captiv', 'audienc'),
#  ('captiv', 'audienc', 'fairi'),
#  ('audienc', 'fairi', 'tale'),
#  ('fairi', 'tale', 'educ'),
#  ('tale', 'educ', 'stori'),
#  ('educ', 'stori', 'type'),
#  ('stori', 'type', 'stori'),
#  ('type', 'stori', 'potenti'),
#  ('stori', 'potenti', 'captur'),
#  ('potenti', 'captur', 'peopl'),
#  ('captur', 'peopl', 'attent'),
#  ('peopl', 'attent', 'imagin'),
#  ('attent', 'imagin', 'depend'),
#  ('imagin', 'depend', 'target'),
#  ('depend', 'target', 'audienc'),
#  ('target', 'audienc', 'may'),
#  ('audienc', 'may', 'choos'),
#  ('may', 'choos', 'specif'),
#  ('choos', 'specif', 'theme'),
#  ('specif', 'theme', 'topic'),
#  ('theme', 'topic', 'storytel'),
#  ('topic', 'storytel', 'session'),
#  ('storytel', 'session', 'e'),
#  ('session', 'e', 'g'),
#  ('e', 'g', 'children'),
#  ('g', 'children', 'talk'),
#  ('children', 'talk', 'anim'),
#  ('talk', 'anim', 'adult'),
#  ('anim', 'adult', 'histori'),
#  ('adult', 'histori', 'base'),
#  ('histori', 'base', 'tale'),
#  ('base', 'tale', 'might'),
#  ('tale', 'might', 'engag'),
#  ('might', 'engag', 'better'),
#  ('engag', 'better', 'etc'),
#  ('better', 'etc', 'first'),
#  ('etc', 'first', 'request'),
#  ('first', 'request', 'need'),
#  ('request', 'need', 'interest'),
#  ('need', 'interest', 'stori'),
#  ('interest', 'stori', 'persever'),
#  ('stori', 'persever', 'want'),
#  ('persever', 'want', 'act'),
#  ('want', 'act', 'footbal'),
#  ('act', 'footbal', 'comment'),
#  ('footbal', 'comment', 'give'),
#  ('comment', 'give', 'descript'),
#  ('give', 'descript', 'footbal'),
#  ('descript', 'footbal', 'match'),
#  ('footbal', 'match', 'progress'),
#  ('match', 'progress', 'comment'),
#  ('progress', 'comment', 'match'),
#  ('comment', 'match', 'provid'),
#  ('match', 'provid', 'analysi'),
#  ('provid', 'analysi', 'happen'),
#  ('analysi', 'happen', 'thu'),
#  ('happen', 'thu', 'far'),
#  ('thu', 'far', 'predict'),
#  ('far', 'predict', 'game'),
#  ('predict', 'game', 'may'),
#  ('game', 'may', 'end'),
#  ('may', 'end', 'knowledg'),
#  ('end', 'knowledg', 'footbal'),
#  ('knowledg', 'footbal', 'terminolog'),
#  ('footbal', 'terminolog', 'tactic'),
#  ('terminolog', 'tactic', 'player'),
#  ('tactic', 'player', 'team'),
#  ('player', 'team', 'involv'),
#  ('team', 'involv', 'match'),
#  ('involv', 'match', 'focu'),
#  ('match', 'focu', 'primarili'),
#  ('focu', 'primarili', 'provid'),
#  ('primarili', 'provid', 'intellig'),
#  ('provid', 'intellig', 'commentari'),
#  ('intellig', 'commentari', 'rather'),
#  ('commentari', 'rather', 'narrat'),
#  ('rather', 'narrat', 'play'),
#  ('narrat', 'play', 'play'),
#  ('play', 'play', 'first'),
#  ('play', 'first', 'request'),
#  ('first', 'request', 'watch'),
#  ('request', 'watch', 'manchest'),
#  ('watch', 'manchest', 'unit'),
#  ('manchest', 'unit', 'vs'),
#  ('unit', 'vs', 'chelsea'),
#  ('vs', 'chelsea', 'provid'),
#  ('chelsea', 'provid', 'commentari'),
#  ('provid', 'commentari', 'match'),
#  ('commentari', 'match', 'want'),
#  ('match', 'want', 'act'),
#  ('want', 'act', 'stand'),
#  ('act', 'stand', 'comedian'),
#  ('stand', 'comedian', 'provid'),
#  ('comedian', 'provid', 'topic'),
#  ('provid', 'topic', 'relat'),
#  ('topic', 'relat', 'current'),
#  ('relat', 'current', 'event'),
#  ('current', 'event', 'use'),
#  ('event', 'use', 'wit'),
#  ('use', 'wit', 'creativ'),
#  ('wit', 'creativ', 'observ'),
#  ('creativ', 'observ', 'skill'),
#  ('observ', 'skill', 'creat'),
#  ('skill', 'creat', 'routin'),
#  ('creat', 'routin', 'base'),
#  ('routin', 'base', 'topic'),
#  ('base', 'topic', 'also'),
#  ('topic', 'also', 'sure'),
#  ('also', 'sure', 'incorpor'),
#  ('sure', 'incorpor', 'person'),
#  ('incorpor', 'person', 'anecdot'),
#  ('person', 'anecdot', 'experi'),
#  ('anecdot', 'experi', 'routin'),
#  ('experi', 'routin', 'order'),
#  ('routin', 'order', 'make'),
#  ('order', 'make', 'relat'),
#  ('make', 'relat', 'engag'),
#  ('relat', 'engag', 'audienc'),
#  ('engag', 'audienc', 'first'),
#  ('audienc', 'first', 'request'),
#  ('first', 'request', 'want'),
#  ('request', 'want', 'humor'),
#  ('want', 'humor', 'take'),
#  ('humor', 'take', 'polit'),
#  ('take', 'polit', 'want'),
#  ('polit', 'want', 'act'),
#  ('want', 'act', 'motiv'),
#  ('act', 'motiv', 'coach'),
#  ('motiv', 'coach', 'provid'),
#  ('coach', 'provid', 'inform'),
#  ('provid', 'inform', 'someon'),
#  ('inform', 'someon', 'goal'),
#  ('someon', 'goal', 'challeng'),
#  ('goal', 'challeng', 'job'),
#  ('challeng', 'job', 'come'),
#  ('job', 'come', 'strategi'),
#  ('come', 'strategi', 'help'),
#  ('strategi', 'help', 'person'),
#  ('help', 'person', 'achiev'),
#  ('person', 'achiev', 'goal'),
#  ('achiev', 'goal', 'could'),
#  ('goal', 'could', 'involv'),
#  ('could', 'involv', 'provid'),
#  ('involv', 'provid', 'posit'),
#  ('provid', 'posit', 'affirm'),
#  ('posit', 'affirm', 'give'),
#  ('affirm', 'give', 'help'),
#  ('give', 'help', 'advic'),
#  ('help', 'advic', 'suggest'),
#  ('advic', 'suggest', 'activ'),
#  ('suggest', 'activ', 'reach'),
#  ('activ', 'reach', 'end'),
#  ('reach', 'end', 'goal'),
#  ('end', 'goal', 'first'),
#  ('goal', 'first', 'request'),
#  ('first', 'request', 'need'),
#  ('request', 'need', 'help'),
#  ('need', 'help', 'motiv'),
#  ('help', 'motiv', 'stay'),
#  ('motiv', 'stay', 'disciplin'),
#  ('stay', 'disciplin', 'studi'),
#  ('disciplin', 'studi', 'upcom'),
#  ('studi', 'upcom', 'exam'),
#  ('upcom', 'exam', 'want'),
#  ('exam', 'want', 'act'),
#  ('want', 'act', 'compos'),
#  ('act', 'compos', 'provid'),
#  ('compos', 'provid', 'lyric'),
#  ('provid', 'lyric', 'song'),
#  ('lyric', 'song', 'creat'),
#  ('song', 'creat', 'music'),
#  ('creat', 'music', 'could'),
#  ('music', 'could', 'includ'),
#  ('could', 'includ', 'use'),
#  ('includ', 'use', 'variou'),
#  ('use', 'variou', 'instrument'),
#  ('variou', 'instrument', 'tool'),
#  ('instrument', 'tool', 'synthes'),
#  ('tool', 'synthes', 'sampler'),
#  ('synthes', 'sampler', 'order'),
#  ('sampler', 'order', 'creat'),
#  ('order', 'creat', 'melodi'),
#  ('creat', 'melodi', 'harmoni'),
#  ('melodi', 'harmoni', 'bring'),
#  ('harmoni', 'bring', 'lyric'),
#  ('bring', 'lyric', 'life'),
#  ('lyric', 'life', 'first'),
#  ('life', 'first', 'request'),
#  ('first', 'request', 'written'),
#  ('request', 'written', 'poem'),
#  ('written', 'poem', 'name'),
#  ('poem', 'name', 'hayalet'),
#  ('name', 'hayalet', 'sevgilim'),
#  ('hayalet', 'sevgilim', 'need'),
#  ('sevgilim', 'need', 'music'),
#  ('need', 'music', 'go'),
#  ('music', 'go', 'want'),
#  ('go', 'want', 'act'),
#  ('want', 'act', 'debat'),
#  ('act', 'debat', 'provid'),
#  ('debat', 'provid', 'topic'),
#  ('provid', 'topic', 'relat'),
#  ('topic', 'relat', 'current'),
#  ('relat', 'current', 'event'),
#  ('current', 'event', 'task'),
#  ('event', 'task', 'research'),
#  ('task', 'research', 'side'),
#  ('research', 'side', 'debat'),
#  ('side', 'debat', 'present'),
#  ('debat', 'present', 'valid'),
#  ('present', 'valid', 'argument'),
#  ('valid', 'argument', 'side'),
#  ('argument', 'side', 'refut'),
#  ('side', 'refut', 'oppos'),
#  ('refut', 'oppos', 'point'),
#  ('oppos', 'point', 'view'),
#  ('point', 'view', 'draw'),
#  ('view', 'draw', 'persuas'),
#  ('draw', 'persuas', 'conclus'),
#  ('persuas', 'conclus', 'base'),
#  ('conclus', 'base', 'evid'),
#  ('base', 'evid', 'goal'),
#  ('evid', 'goal', 'help'),
#  ('goal', 'help', 'peopl'),
#  ('help', 'peopl', 'come'),
#  ('peopl', 'come', 'away'),
#  ('come', 'away', 'discuss'),
#  ('away', 'discuss', 'increas'),
#  ('discuss', 'increas', 'knowledg'),
#  ('increas', 'knowledg', 'insight'),
#  ('knowledg', 'insight', 'topic'),
#  ('insight', 'topic', 'hand'),
#  ('topic', 'hand', 'first'),
#  ('hand', 'first', 'request'),
#  ('first', 'request', 'want'),
#  ('request', 'want', 'opinion'),
#  ('want', 'opinion', 'piec'),
#  ('opinion', 'piec', 'deno'),
#  ('piec', 'deno', 'want'),
#  ('deno', 'want', 'act'),
#  ('want', 'act', 'debat'),
#  ('act', 'debat', 'coach'),
#  ('debat', 'coach', 'provid'),
#  ('coach', 'provid', 'team'),
#  ('provid', 'team', 'debat'),
#  ('team', 'debat', 'motion'),
#  ('debat', 'motion', 'upcom'),
#  ('motion', 'upcom', 'debat'),
#  ('upcom', 'debat', 'goal'),
#  ('debat', 'goal', 'prepar'),
#  ('goal', 'prepar', 'team'),
#  ('prepar', 'team', 'success'),
#  ('team', 'success', 'organ'),
#  ('success', 'organ', 'practic'),
#  ('organ', 'practic', 'round'),
#  ('practic', 'round', 'focu'),
#  ('round', 'focu', 'persuas'),
#  ('focu', 'persuas', 'speech'),
#  ('persuas', 'speech', 'effect'),
#  ('speech', 'effect', 'time'),
#  ('effect', 'time', 'strategi'),
#  ('time', 'strategi', 'refut'),
#  ('strategi', 'refut', 'oppos'),
#  ('refut', 'oppos', 'argument'),
#  ('oppos', 'argument', 'draw'),
#  ('argument', 'draw', 'depth'),
#  ('draw', 'depth', 'conclus'),
#  ('depth', 'conclus', 'evid'),
#  ('conclus', 'evid', 'provid'),
#  ('evid', 'provid', 'first'),
#  ('provid', 'first', 'request'),
#  ('first', 'request', 'want'),
#  ('request', 'want', 'team'),
#  ('want', 'team', 'prepar'),
#  ('team', 'prepar', 'upcom'),
#  ('prepar', 'upcom', 'debat'),
#  ('upcom', 'debat', 'whether'),
#  ('debat', 'whether', 'front'),
#  ('whether', 'front', 'end'),
#  ('front', 'end', 'develop'),
#  ('end', 'develop', 'easi'),
#  ('develop', 'easi', 'want'),
#  ('easi', 'want', 'act'),
#  ('want', 'act', 'screenwrit'),
#  ('act', 'screenwrit', 'develop'),
#  ('screenwrit', 'develop', 'engag'),
#  ('develop', 'engag', 'creativ'),
#  ('engag', 'creativ', 'script'),
#  ('creativ', 'script', 'either'),
#  ('script', 'either', 'featur'),
#  ('either', 'featur', 'length'),
#  ('featur', 'length', 'film'),
#  ('length', 'film', 'web'),
#  ('film', 'web', 'seri'),
#  ('web', 'seri', 'captiv'),
#  ('seri', 'captiv', 'viewer'),
#  ('captiv', 'viewer', 'start'),
#  ('viewer', 'start', 'come'),
#  ('start', 'come', 'interest'),
#  ('come', 'interest', 'charact'),
#  ('interest', 'charact', 'set'),
#  ('charact', 'set', 'stori'),
#  ('set', 'stori', 'dialogu'),
#  ('stori', 'dialogu', 'charact'),
#  ('dialogu', 'charact', 'etc'),
#  ('charact', 'etc', 'charact'),
#  ('etc', 'charact', 'develop'),
#  ('charact', 'develop', 'complet'),
#  ('develop', 'complet', 'creat'),
#  ('complet', 'creat', 'excit'),
#  ('creat', 'excit', 'storylin'),
#  ('excit', 'storylin', 'fill'),
#  ('storylin', 'fill', 'twist'),
#  ('fill', 'twist', 'turn'),
#  ('twist', 'turn', 'keep'),
#  ('turn', 'keep', 'viewer'),
#  ('keep', 'viewer', 'suspens'),
#  ('viewer', 'suspens', 'end'),
#  ('suspens', 'end', 'first'),
#  ('end', 'first', 'request'),
#  ('first', 'request', 'need'),
#  ('request', 'need', 'write'),
#  ('need', 'write', 'romant'),
#  ('write', 'romant', 'drama'),
#  ('romant', 'drama', 'movi'),
#  ('drama', 'movi', 'set'),
#  ('movi', 'set', 'pari'),
#  ('set', 'pari', 'want'),
#  ('pari', 'want', 'act'),
#  ('want', 'act', 'novelist'),
#  ('act', 'novelist', 'come'),
#  ('novelist', 'come', 'creativ'),
#  ('come', 'creativ', 'captiv'),
#  ('creativ', 'captiv', 'stori'),
#  ('captiv', 'stori', 'engag'),
#  ('stori', 'engag', 'reader'),
#  ('engag', 'reader', 'long'),
#  ('reader', 'long', 'period'),
#  ('long', 'period', 'time'),
#  ('period', 'time', 'may'),
#  ('time', 'may', 'choos'),
#  ('may', 'choos', 'genr'),
#  ('choos', 'genr', 'fantasi'),
#  ('genr', 'fantasi', 'romanc'),
#  ('fantasi', 'romanc', 'histor'),
#  ('romanc', 'histor', 'fiction'),
#  ('histor', 'fiction', 'aim'),
#  ('fiction', 'aim', 'write'),
#  ('aim', 'write', 'someth'),
#  ('write', 'someth', 'outstand'),
#  ('someth', 'outstand', 'plotlin'),
#  ('outstand', 'plotlin', 'engag'),
#  ('plotlin', 'engag', 'charact'),
#  ('engag', 'charact', 'unexpect'),
#  ('charact', 'unexpect', 'climax'),
#  ('unexpect', 'climax', 'first'),
#  ('climax', 'first', 'request'),
#  ('first', 'request', 'need'),
#  ('request', 'need', 'write'),
#  ('need', 'write', 'scienc'),
#  ('write', 'scienc', 'fiction'),
#  ('scienc', 'fiction', 'novel'),
#  ('fiction', 'novel', 'set'),
#  ('novel', 'set', 'futur'),
#  ('set', 'futur', 'want'),
#  ('futur', 'want', 'act'),
#  ('want', 'act', 'movi'),
#  ('act', 'movi', 'critic'),
#  ('movi', 'critic', 'develop'),
#  ('critic', 'develop', 'engag'),
#  ('develop', 'engag', 'creativ'),
#  ('engag', 'creativ', 'movi'),
#  ('creativ', 'movi', 'review'),
#  ('movi', 'review', 'cover'),
#  ('review', 'cover', 'topic'),
#  ('cover', 'topic', 'like'),
#  ('topic', 'like', 'plot'),
#  ('like', 'plot', 'theme'),
#  ('plot', 'theme', 'tone'),
#  ('theme', 'tone', 'act'),
#  ('tone', 'act', 'charact'),
#  ('act', 'charact', 'direct'),
#  ('charact', 'direct', 'score'),
#  ('direct', 'score', 'cinematographi'),
#  ('score', 'cinematographi', 'product'),
#  ('cinematographi', 'product', 'design'),
#  ('product', 'design', 'special'),
#  ('design', 'special', 'effect'),
#  ('special', 'effect', 'edit'),
#  ('effect', 'edit', 'pace'),
#  ('edit', 'pace', 'dialog'),
#  ('pace', 'dialog', 'import'),
#  ('dialog', 'import', 'aspect'),
#  ('import', 'aspect', 'though'),
#  ('aspect', 'though', 'emphas'),
#  ('though', 'emphas', 'movi'),
#  ('emphas', 'movi', 'made'),
#  ('movi', 'made', 'feel'),
#  ('made', 'feel', 'realli'),
#  ('feel', 'realli', 'reson'),
#  ('realli', 'reson', 'also'),
#  ('reson', 'also', 'critic'),
#  ('also', 'critic', 'movi'),
#  ('critic', 'movi', 'pleas'),
#  ('movi', 'pleas', 'avoid'),
#  ('pleas', 'avoid', 'spoiler'),
#  ('avoid', 'spoiler', 'first'),
#  ('spoiler', 'first', 'request'),
#  ('first', 'request', 'need'),
#  ('request', 'need', 'write'),
#  ('need', 'write', 'movi'),
#  ('write', 'movi', 'review'),
#  ('movi', 'review', 'movi'),
#  ('review', 'movi', 'interstellar'),
#  ('movi', 'interstellar', 'want'),
#  ('interstellar', 'want', 'act'),
#  ('want', 'act', 'relationship'),
#  ('act', 'relationship', 'coach'),
#  ...]

# %% [markdown]
# ## 🧮 Cálculo de frequências e probabilidades condicionais
# 1. Cálculo de quantas vezes cada trigrama aparece no texto.

# %%
frequency_trigrams = Counter(trigrams)
frequency_trigrams
# Out:
# Counter({('request', 'need', 'help'): 43,
#          ('first', 'suggest', 'request'): 32,
#          ('first', 'request', 'need'): 28,
#          ('suggest', 'request', 'need'): 25,
#          ('noth', 'els', 'write'): 19,
#          ('els', 'write', 'explan'): 19,
#          ('write', 'explan', 'first'): 13,
#          ('need', 'tell', 'someth'): 11,
#          ('tell', 'someth', 'english'): 11,
#          ('first', 'request', 'want'): 10,
#          ('curli', 'bracket', 'like'): 8,
#          ('need', 'help', 'creat'): 8,
#          ('explan', 'first', 'request'): 8,
#          ('one', 'uniqu', 'code'): 7,
#          ('uniqu', 'code', 'block'): 7,
#          ('code', 'block', 'noth'): 7,
#          ('block', 'noth', 'els'): 7,
#          ('unless', 'instruct', 'need'): 7,
#          ('someth', 'english', 'put'): 7,
#          ('english', 'put', 'text'): 7,
#          ('put', 'text', 'insid'): 7,
#          ('bracket', 'like', 'first'): 7,
#          ('write', 'explan', 'repli'): 7,
#          ('insid', 'one', 'uniqu'): 6,
#          ('write', 'explan', 'type'): 6,
#          ('explan', 'type', 'command'): 6,
#          ('type', 'command', 'unless'): 6,
#          ('command', 'unless', 'instruct'): 6,
#          ('instruct', 'need', 'tell'): 6,
#          ('text', 'insid', 'curli'): 6,
#          ('insid', 'curli', 'bracket'): 6,
#          ('like', 'first', 'command'): 6,
#          ('world', 'want', 'act'): 6,
#          ('type', 'command', 'repli'): 5,
#          ('output', 'insid', 'one'): 5,
#          ('want', 'act', 'like'): 5,
#          ('want', 'act', 'person'): 5,
#          ('show', 'want', 'repli'): 4,
#          ('want', 'repli', 'termin'): 4,
#          ('repli', 'termin', 'output'): 4,
#          ('termin', 'output', 'insid'): 4,
#          ('explan', 'repli', 'first'): 4,
#          ('repli', 'first', 'sentenc'): 4,
#          ('job', 'come', 'strategi'): 4,
#          ('need', 'help', 'develop'): 4,
#          ('new', 'made', 'languag'): 4,
#          ('command', 'repli', 'termin'): 3,
#          ('want', 'act', 'english'): 3,
#          ('hello', 'world', 'want'): 3,
#          ('want', 'act', 'text'): 3,
#          ('act', 'text', 'base'): 3,
#          ('act', 'english', 'pronunci'): 3,
#          ('istanbul', 'want', 'act'): 3,
#          ('provid', 'topic', 'relat'): 3,
#          ('come', 'strategi', 'help'): 3,
#          ('request', 'need', 'write'): 3,
#          ('coach', 'provid', 'detail'): 3,
#          ('step', 'step', 'instruct'): 3,
#          ('need', 'help', 'design'): 3,
#          ('provid', 'individu', 'look'): 3,
#          ('individu', 'look', 'guidanc'): 3,
#          ('need', 'help', 'write'): 3,
#          ('recommend', 'noth', 'els'): 3,
#          ('use', 'want', 'act'): 3,
#          ('first', 'sentenc', 'hello'): 3,
#          ('want', 'act', 'expert'): 3,
#          ('write', 'explan', 'word'): 3,
#          ('explan', 'word', 'repli'): 3,
#          ('map', 'bullet', 'point'): 3,
#          ('dan', 'none', 'respons'): 3,
#          ('2', '000', 'word'): 2,
#          ('word', 'articl', 'gener'): 2,
#          ('act', 'linux', 'termin'): 2,
#          ('repli', 'termin', 'show'): 2,
#          ('termin', 'show', 'want'): 2,
#          ('translat', 'answer', 'correct'): 2,
#          ('answer', 'correct', 'improv'): 2,
#          ('correct', 'improv', 'version'): 2,
#          ('improv', 'version', 'text'): 2,
#          ('want', 'replac', 'simplifi'): 2,
#          ('replac', 'simplifi', 'a0'): 2,
#          ('simplifi', 'a0', 'level'): 2,
#          ('a0', 'level', 'word'): 2,
#          ('level', 'word', 'sentenc'): 2,
#          ('word', 'sentenc', 'beauti'): 2,
#          ('sentenc', 'beauti', 'eleg'): 2,
#          ('word', 'sentenc', 'keep'): 2,
#          ('sentenc', 'keep', 'mean'): 2,
#          ('want', 'repli', 'correct'): 2,
#          ('repli', 'correct', 'improv'): 2,
#          ('correct', 'improv', 'noth'): 2,
#          ('improv', 'noth', 'els'): 2,
#          ('explan', 'first', 'sentenc'): 2,
#          ('answer', 'write', 'explan'): 2,
#          ('first', 'sentenc', 'hi'): 2,
#          ('repli', 'result', 'excel'): 2,
#          ('result', 'excel', 'tabl'): 2,
#          ('excel', 'tabl', 'text'): 2,
#          ('text', 'noth', 'els'): 2,
#          ('english', 'pronunci', 'assist'): 2,
#          ('pronunci', 'assist', 'turkish'): 2,
#          ('assist', 'turkish', 'speak'): 2,
#          ('turkish', 'speak', 'peopl'): 2,
#          ('speak', 'peopl', 'write'): 2,
#          ('peopl', 'write', 'sentenc'): 2,
#          ('write', 'sentenc', 'answer'): 2,
#          ('sentenc', 'answer', 'pronunci'): 2,
#          ('answer', 'pronunci', 'noth'): 2,
#          ('pronunci', 'noth', 'els'): 2,
#          ('noth', 'els', 'repli'): 2,
#          ('els', 'repli', 'must'): 2,
#          ('repli', 'must', 'translat'): 2,
#          ('must', 'translat', 'sentenc'): 2,
#          ('translat', 'sentenc', 'pronunci'): 2,
#          ('sentenc', 'pronunci', 'pronunci'): 2,
#          ('pronunci', 'pronunci', 'use'): 2,
#          ('pronunci', 'use', 'turkish'): 2,
#          ('use', 'turkish', 'latin'): 2,
#          ('turkish', 'latin', 'letter'): 2,
#          ('latin', 'letter', 'phonet'): 2,
#          ('letter', 'phonet', 'write'): 2,
#          ('phonet', 'write', 'explan'): 2,
#          ('first', 'sentenc', 'weather'): 2,
#          ('sentenc', 'weather', 'istanbul'): 2,
#          ('want', 'strictli', 'correct'): 2,
#          ('strictli', 'correct', 'grammar'): 2,
#          ('correct', 'grammar', 'mistak'): 2,
#          ('grammar', 'mistak', 'typo'): 2,
#          ('mistak', 'typo', 'factual'): 2,
#          ('typo', 'factual', 'error'): 2,
#          ('factual', 'error', 'want'): 2,
#          ('ask', 'question', 'repli'): 2,
#          ('answer', 'like', 'charact'): 2,
#          ('promot', 'product', 'servic'): 2,
#          ('topic', 'relat', 'current'): 2,
#          ('relat', 'current', 'event'): 2,
#          ('want', 'act', 'motiv'): 2,
#          ('want', 'act', 'debat'): 2,
#          ('front', 'end', 'develop'): 2,
#          ('develop', 'engag', 'creativ'): 2,
#          ('relat', 'studi', 'philosophi'): 2,
#          ('studi', 'philosophi', 'job'): 2,
#          ('could', 'includ', 'provid'): 2,
#          ('break', 'complex', 'idea'): 2,
#          ('complex', 'idea', 'smaller'): 2,
#          ('need', 'help', 'understand'): 2,
#          ('conduct', 'research', 'variou'): 2,
#          ('concept', 'job', 'explain'): 2,
#          ('job', 'explain', 'easi'): 2,
#          ('explain', 'easi', 'understand'): 2,
#          ('easi', 'understand', 'term'): 2,
#          ('understand', 'term', 'could'): 2,
#          ('provid', 'step', 'step'): 2,
#          ('demonstr', 'variou', 'techniqu'): 2,
#          ('variou', 'techniqu', 'visual'): 2,
#          ('techniqu', 'visual', 'suggest'): 2,
#          ('visual', 'suggest', 'onlin'): 2,
#          ('suggest', 'onlin', 'resourc'): 2,
#          ('onlin', 'resourc', 'studi'): 2,
#          ('resourc', 'studi', 'first'): 2,
#          ('want', 'act', 'ai'): 2,
#          ('need', 'help', 'improv'): 2,
#          ('artifici', 'intellig', 'tool'): 2,
#          ('digit', 'product', 'job'): 2,
#          ('product', 'job', 'come'): 2,
#          ('come', 'creativ', 'way'): 2,
#          ('applic', 'want', 'act'): 2,
#          ('provid', 'specif', 'inform'): 2,
#          ('compani', 'want', 'act'): 2,
#          ('want', 'act', 'life'): 2,
#          ('act', 'life', 'coach'): 2,
#          ('write', 'opinion', 'piec'): 2,
#          ('want', 'act', 'career'): 2,
#          ('softwar', 'engin', 'want'): 2,
#          ('engin', 'want', 'act'): 2,
#          ('need', 'help', 'manag'): 2,
#          ('provid', 'inform', 'need'): 2,
#          ('look', 'guidanc', 'advic'): 2,
#          ('guidanc', 'advic', 'manag'): 2,
#          ('improv', 'overal', 'wellb'): 2,
#          ('overal', 'wellb', 'first'): 2,
#          ('provid', 'detail', 'individu'): 2,
#          ('detail', 'individu', 'look'): 2,
#          ('provid', 'detail', 'relat'): 2,
#          ('also', 'need', 'consid'): 2,
#          ('need', 'consid', 'patient'): 2,
#          ('consid', 'patient', 'age'): 2,
#          ('patient', 'age', 'lifestyl'): 2,
#          ('provid', 'recommend', 'first'): 2,
#          ('recommend', 'first', 'suggest'): 2,
#          ('suggest', 'request', 'come'): 2,
#          ('request', 'come', 'treatment'): 2,
#          ('come', 'treatment', 'plan'): 2,
#          ('creat', 'financi', 'plan'): 2,
#          ('theme', 'design', 'approach'): 2,
#          ('addit', 'necessari', 'could'): 2,
#          ('necessari', 'could', 'suggest'): 2,
#          ('repli', 'termin', 'would'): 2,
#          ('insid', 'code', 'block'): 2,
#          ('curli', 'brace', 'like'): 2,
#          ('want', 'act', 'prompt'): 2,
#          ('act', 'prompt', 'gener'): 2,
#          ('helper', 'give', 'prompt'): 2,
#          ('prompt', 'want', 'act'): 2,
#          ('altern', 'accord', 'prompt'): 2,
#          ('list', 'noth', 'els'): 2,
#          ('explan', 'repli', 'ok'): 2,
#          ('repli', 'ok', 'confirm'): 2,
#          ('ok', 'confirm', 'want'): 2,
#          ('confirm', 'want', 'act'): 2,
#          ('want', 'act', 'tech'): 2,
#          ('provid', 'softwar', 'packag'): 2,
#          ('com', 'want', 'act'): 2,
#          ('help', 'write', 'articl'): 2,
#          ('way', 'first', 'suggest'): 2,
#          ('sentenc', 'want', 'act'): 2,
#          ('place', 'key', 'tabl'): 2,
#          ('need', 'help', 'review'): 2,
#          ('renew', 'energi', 'sourc'): 2,
#          ('want', 'act', 'social'): 2,
#          ('act', 'social', 'media'): 2,
#          ('order', 'increas', 'brand'): 2,
#          ('increas', 'brand', 'awar'): 2,
#          ('want', 'act', 'socrat'): 2,
#          ('use', 'socrat', 'method'): 2,
#          ('captur', 'attent', 'audienc'): 2,
#          ('need', 'help', 'deliv'): 2,
#          ('around', 'world', 'want'): 2,
#          ('hour', 'want', 'act'): 2,
#          ('basic', 'step', 'app'): 2,
#          ('step', 'app', 'function'): 2,
#          ('python', 'interpret', 'give'): 2,
#          ('print', 'hello', 'world'): 2,
#          ('want', 'act', 'virtual'): 2,
#          ('diagnosi', 'treatment', 'plan'): 2,
#          ('situat', 'provid', 'advic'): 2,
#          ('provid', 'advic', 'handl'): 2,
#          ('advic', 'handl', 'repli'): 2,
#          ('handl', 'repli', 'advic'): 2,
#          ('repli', 'advic', 'noth'): 2,
#          ('advic', 'noth', 'els'): 2,
#          ('sure', 'want', 'act'): 2,
#          ('solv', 'problem', 'use'): 2,
#          ('want', 'act', 'softwar'): 2,
#          ('write', 'explan', 'need'): 2,
#          ('explan', 'need', 'tell'): 2,
#          ('5', 'want', 'act'): 2,
#          ('gener', 'regular', 'express'): 2,
#          ('regular', 'express', 'match'): 2,
#          ('provid', 'regular', 'express'): 2,
#          ('write', 'explan', 'exampl'): 2,
#          ('event', 'sight', 'peopl'): 2,
#          ('sight', 'peopl', 'experi'): 2,
#          ('want', 'translat', 'sentenc'): 2,
#          ('translat', 'sentenc', 'wrote'): 2,
#          ('write', 'sentenc', 'express'): 2,
#          ('express', 'emoji', 'want'): 2,
#          ('want', 'repli', 'anyth'): 2,
#          ('someth', 'english', 'wrap'): 2,
#          ('english', 'wrap', 'curli'): 2,
#          ('wrap', 'curli', 'bracket'): 2,
#          ('bracket', 'like', 'like'): 2,
#          ('like', 'like', 'first'): 2,
#          ('like', 'first', 'sentenc'): 2,
#          ('traffic', 'hous', 'accid'): 2,
#          ('hous', 'accid', 'emerg'): 2,
#          ('accid', 'emerg', 'respons'): 2,
#          ('emerg', 'respons', 'crisi'): 2,
#          ('includ', 'explan', 'addit'): 2,
#          ('updat', 'game', 'board'): 2,
#          ('use', 'x', 'move'): 2,
#          ('make', 'first', 'move'): 2,
#          ('express', 'new', 'made'): 2,
#          ('made', 'languag', 'want'): 2,
#          ('page', 'number', 'next'): 2,
#          ('number', 'next', 'written'): 2,
#          ('exampl', 'input', 'valu'): 2,
#          ('inlin', 'json', 'document'): 2,
#          ('follow', 'collect', 'name'): 2,
#          ('question', 'ask', 'answer'): 2,
#          ('want', 'act', 'languag'): 2,
#          ('design', 'partner', 'agreement'): 2,
#          ('cover', 'import', 'aspect'): 2,
#          ('topic', 'first', 'topic'): 2,
#          ('playlist', 'name', 'descript'): 2,
#          ('resum', 'bullet', 'point'): 2,
#          ('well', 'break', 'charact'): 2,
#          ('break', 'charact', 'let'): 2,
#          ('fulli', 'immers', 'role'): 2,
#          ('dan', 'cannot', 'someth'): 2,
#          ('cannot', 'someth', 'dan'): 2,
#          ('ask', 'next', 'question'): 2,
#          ('question', 'want', 'act'): 2,
#          ('want', 'act', 'note'): 2,
#          ('act', 'note', 'take'): 2,
#          ('note', 'take', 'assist'): 2,
#          ('take', 'assist', 'lectur'): 2,
#          ('assist', 'lectur', 'task'): 2,
#          ('lectur', 'task', 'provid'): 2,
#          ('task', 'provid', 'detail'): 2,
#          ('provid', 'detail', 'note'): 2,
#          ('detail', 'note', 'list'): 2,
#          ('note', 'list', 'includ'): 2,
#          ('list', 'includ', 'exampl'): 2,
#          ('includ', 'exampl', 'lectur'): 2,
#          ('exampl', 'lectur', 'focus'): 2,
#          ('lectur', 'focus', 'note'): 2,
#          ('focus', 'note', 'believ'): 2,
#          ('note', 'believ', 'end'): 2,
#          ('believ', 'end', 'quiz'): 2,
#          ('end', 'quiz', 'question'): 2,
#          ('quiz', 'question', 'addit'): 2,
#          ('question', 'addit', 'pleas'): 2,
#          ('addit', 'pleas', 'make'): 2,
#          ('pleas', 'make', 'separ'): 2,
#          ('make', 'separ', 'list'): 2,
#          ('separ', 'list', 'note'): 2,
#          ('list', 'note', 'number'): 2,
#          ('note', 'number', 'data'): 2,
#          ('number', 'data', 'anoth'): 2,
#          ('list', 'exampl', 'includ'): 2,
#          ('exampl', 'includ', 'lectur'): 2,
#          ('includ', 'lectur', 'note'): 2,
#          ('lectur', 'note', 'concis'): 2,
#          ('note', 'concis', 'easi'): 2,
#          ('concis', 'easi', 'read'): 2,
#          ('someon', 'ask', 'question'): 2,
#          ('teach', 'junior', 'develop'): 2,
#          ('code', 'want', 'act'): 2,
#          ('video', 'link', 'transcript'): 2,
#          ('manag', 'git', 'repositori'): 2,
#          ('move', 'algebra', 'notat'): 2,
#          ('write', 'messag', 'chat'): 2,
#          ('messag', 'chat', 'answer'): 2,
#          ('emoje', 'want', 'repli'): 2,
#          ('want', 'repli', 'answer'): 2,
#          ('funni', 'question', 'answer'): 2,
#          ('question', 'answer', 'carri'): 2,
#          ('answer', 'carri', 'convers'): 2,
#          ('carri', 'convers', 'forward'): 2,
#          ('convers', 'forward', 'write'): 2,
#          ('forward', 'write', 'explan'): 2,
#          ('explan', 'first', 'messag'): 2,
#          ('first', 'messag', 'girl'): 2,
#          ('messag', 'girl', 'hey'): 2,
#          ('girl', 'hey', 'want'): 2,
#          ('three', 'dimens', 'tabl'): 2,
#          ('oneway', 'one', 'mani'): 2,
#          ('one', 'mani', 'relationship'): 2,
#          ('within', 'think', 'tag'): 2,
#          ('backtrack', 'tri', 'differ'): 2,
#          ('tri', 'differ', 'approach'): 2,
#          ('practic', 'applic', 'real'): 2,
#          ('applic', 'real', 'world'): 2,
#          ('real', 'world', 'exampl'): 2,
#          ('use', 'everyday', 'analog'): 2,
#          ('natur', 'languag', 'statement'): 2,
#          ('imagin', 'experienc', 'ethereum'): 1,
#          ('experienc', 'ethereum', 'develop'): 1,
#          ('ethereum', 'develop', 'task'): 1,
#          ('develop', 'task', 'creat'): 1,
#          ('task', 'creat', 'smart'): 1,
#          ('creat', 'smart', 'contract'): 1,
#          ('smart', 'contract', 'blockchain'): 1,
#          ('contract', 'blockchain', 'messeng'): 1,
#          ('blockchain', 'messeng', 'object'): 1,
#          ('messeng', 'object', 'save'): 1,
#          ('object', 'save', 'messag'): 1,
#          ('save', 'messag', 'blockchain'): 1,
#          ('messag', 'blockchain', 'make'): 1,
#          ('blockchain', 'make', 'readabl'): 1,
#          ('make', 'readabl', 'public'): 1,
#          ('readabl', 'public', 'everyon'): 1,
#          ('public', 'everyon', 'writabl'): 1,
#          ('everyon', 'writabl', 'privat'): 1,
#          ('writabl', 'privat', 'person'): 1,
#          ('privat', 'person', 'deploy'): 1,
#          ('person', 'deploy', 'contract'): 1,
#          ('deploy', 'contract', 'count'): 1,
#          ('contract', 'count', 'mani'): 1,
#          ('count', 'mani', 'time'): 1,
#          ('mani', 'time', 'messag'): 1,
#          ('time', 'messag', 'updat'): 1,
#          ('messag', 'updat', 'develop'): 1,
#          ('updat', 'develop', 'solid'): 1,
#          ('develop', 'solid', 'smart'): 1,
#          ('solid', 'smart', 'contract'): 1,
#          ('smart', 'contract', 'purpos'): 1,
#          ('contract', 'purpos', 'includ'): 1,
#          ('purpos', 'includ', 'necessari'): 1,
#          ('includ', 'necessari', 'function'): 1,
#          ('necessari', 'function', 'consider'): 1,
#          ('function', 'consider', 'achiev'): 1,
#          ('consider', 'achiev', 'specifi'): 1,
#          ('achiev', 'specifi', 'goal'): 1,
#          ('specifi', 'goal', 'pleas'): 1,
#          ('goal', 'pleas', 'provid'): 1,
#          ('pleas', 'provid', 'code'): 1,
#          ('provid', 'code', 'relev'): 1,
#          ('code', 'relev', 'explan'): 1,
#          ('relev', 'explan', 'ensur'): 1,
#          ('explan', 'ensur', 'clear'): 1,
#          ('ensur', 'clear', 'understand'): 1,
#          ('clear', 'understand', 'implement'): 1,
#          ('understand', 'implement', 'use'): 1,
#          ('implement', 'use', 'webpilot'): 1,
#          ('use', 'webpilot', 'creat'): 1,
#          ('webpilot', 'creat', 'outlin'): 1,
#          ('creat', 'outlin', 'articl'): 1,
#          ('outlin', 'articl', '2'): 1,
#          ('articl', '2', '000'): 1,
#          ('000', 'word', 'keyword'): 1,
#          ('word', 'keyword', 'best'): 1,
#          ('keyword', 'best', 'seo'): 1,
#          ('best', 'seo', 'prompt'): 1,
#          ('seo', 'prompt', 'base'): 1,
#          ('prompt', 'base', 'top'): 1,
#          ('base', 'top', '10'): 1,
#          ('top', '10', 'result'): 1,
#          ('10', 'result', 'googl'): 1,
#          ('result', 'googl', 'includ'): 1,
#          ('googl', 'includ', 'everi'): 1,
#          ('includ', 'everi', 'relev'): 1,
#          ('everi', 'relev', 'head'): 1,
#          ('relev', 'head', 'possibl'): 1,
#          ('head', 'possibl', 'keep'): 1,
#          ('possibl', 'keep', 'keyword'): 1,
#          ('keep', 'keyword', 'densiti'): 1,
#          ('keyword', 'densiti', 'head'): 1,
#          ('densiti', 'head', 'high'): 1,
#          ('head', 'high', 'section'): 1,
#          ('high', 'section', 'outlin'): 1,
#          ('section', 'outlin', 'includ'): 1,
#          ('outlin', 'includ', 'word'): 1,
#          ('includ', 'word', 'count'): 1,
#          ('word', 'count', 'includ'): 1,
#          ('count', 'includ', 'faq'): 1,
#          ('includ', 'faq', 'section'): 1,
#          ('faq', 'section', 'outlin'): 1,
#          ('section', 'outlin', 'base'): 1,
#          ('outlin', 'base', 'peopl'): 1,
#          ('base', 'peopl', 'also'): 1,
#          ('peopl', 'also', 'ask'): 1,
#          ('also', 'ask', 'section'): 1,
#          ('ask', 'section', 'googl'): 1,
#          ('section', 'googl', 'keyword'): 1,
#          ('googl', 'keyword', 'outlin'): 1,
#          ('keyword', 'outlin', 'must'): 1,
#          ('outlin', 'must', 'detail'): 1,
#          ('must', 'detail', 'comprehens'): 1,
#          ('detail', 'comprehens', 'creat'): 1,
#          ('comprehens', 'creat', '2'): 1,
#          ('creat', '2', '000'): 1,
#          ('000', 'word', 'articl'): 1,
#          ('articl', 'gener', 'long'): 1,
#          ('gener', 'long', 'list'): 1,
#          ('long', 'list', 'lsi'): 1,
#          ('list', 'lsi', 'nlp'): 1,
#          ('lsi', 'nlp', 'keyword'): 1,
#          ('nlp', 'keyword', 'relat'): 1,
#          ('keyword', 'relat', 'keyword'): 1,
#          ('relat', 'keyword', 'also'): 1,
#          ('keyword', 'also', 'includ'): 1,
#          ('also', 'includ', 'word'): 1,
#          ('includ', 'word', 'relat'): 1,
#          ('word', 'relat', 'keyword'): 1,
#          ('relat', 'keyword', 'give'): 1,
#          ('keyword', 'give', 'list'): 1,
#          ('give', 'list', '3'): 1,
#          ('list', '3', 'relev'): 1,
#          ('3', 'relev', 'extern'): 1,
#          ('relev', 'extern', 'link'): 1,
#          ('extern', 'link', 'includ'): 1,
#          ('link', 'includ', 'recommend'): 1,
#          ('includ', 'recommend', 'anchor'): 1,
#          ('recommend', 'anchor', 'text'): 1,
#          ('anchor', 'text', 'make'): 1,
#          ('text', 'make', 'sure'): 1,
#          ('make', 'sure', 'compet'): 1,
#          ('sure', 'compet', 'articl'): 1,
#          ('compet', 'articl', 'split'): 1,
#          ('articl', 'split', 'outlin'): 1,
#          ('split', 'outlin', 'part'): 1,
#          ('outlin', 'part', '1'): 1,
#          ('part', '1', 'part'): 1,
#          ('1', 'part', '2'): 1,
#          ('part', '2', 'want'): 1,
#          ('2', 'want', 'act'): 1,
#          ('want', 'act', 'linux'): 1,
#          ('linux', 'termin', 'type'): 1,
#          ('termin', 'type', 'command'): 1,
#          ('first', 'command', 'pwd'): 1,
#          ('command', 'pwd', 'want'): 1,
#          ('pwd', 'want', 'act'): 1,
#          ('act', 'english', 'translat'): 1,
#          ('english', 'translat', 'spell'): 1,
#          ('translat', 'spell', 'corrector'): 1,
#          ('spell', 'corrector', 'improv'): 1,
#          ('corrector', 'improv', 'speak'): 1,
#          ('improv', 'speak', 'languag'): 1,
#          ('speak', 'languag', 'detect'): 1,
#          ('languag', 'detect', 'languag'): 1,
#          ('detect', 'languag', 'translat'): 1,
#          ('languag', 'translat', 'answer'): 1,
#          ('version', 'text', 'english'): 1,
#          ('text', 'english', 'want'): 1,
#          ('english', 'want', 'replac'): 1,
#          ('beauti', 'eleg', 'upper'): 1,
#          ('eleg', 'upper', 'level'): 1,
#          ('upper', 'level', 'english'): 1,
#          ('level', 'english', 'word'): 1,
#          ('english', 'word', 'sentenc'): 1,
#          ('keep', 'mean', 'make'): 1,
#          ('mean', 'make', 'literari'): 1,
#          ('make', 'literari', 'want'): 1,
#          ('literari', 'want', 'repli'): 1,
#          ('first', 'sentenc', 'istanbulu'): 1,
#          ('sentenc', 'istanbulu', 'cok'): 1,
#          ('istanbulu', 'cok', 'seviyom'): 1,
#          ('cok', 'seviyom', 'burada'): 1,
#          ('seviyom', 'burada', 'olmak'): 1,
#          ('burada', 'olmak', 'cok'): 1,
#          ('olmak', 'cok', 'guzel'): 1,
#          ('cok', 'guzel', 'want'): 1,
#          ('guzel', 'want', 'act'): 1,
#          ('want', 'act', 'interview'): 1,
#          ('act', 'interview', 'candid'): 1,
#          ('interview', 'candid', 'ask'): 1,
#          ('candid', 'ask', 'interview'): 1,
#          ('ask', 'interview', 'question'): 1,
#          ('interview', 'question', 'posit'): 1,
#          ('question', 'posit', 'posit'): 1,
#          ('posit', 'posit', 'want'): 1,
#          ('posit', 'want', 'repli'): 1,
#          ('want', 'repli', 'interview'): 1,
#          ('repli', 'interview', 'write'): 1,
#          ('interview', 'write', 'convers'): 1,
#          ('write', 'convers', 'want'): 1,
#          ('convers', 'want', 'interview'): 1,
#          ('want', 'interview', 'ask'): 1,
#          ('interview', 'ask', 'question'): 1,
#          ('ask', 'question', 'wait'): 1,
#          ('question', 'wait', 'answer'): 1,
#          ('wait', 'answer', 'write'): 1,
#          ('write', 'explan', 'ask'): 1,
#          ('explan', 'ask', 'question'): 1,
#          ('ask', 'question', 'one'): 1,
#          ('question', 'one', 'one'): 1,
#          ('one', 'one', 'like'): 1,
#          ('one', 'like', 'interview'): 1,
#          ('like', 'interview', 'wait'): 1,
#          ('interview', 'wait', 'answer'): 1,
#          ('wait', 'answer', 'first'): 1,
#          ('answer', 'first', 'sentenc'): 1,
#          ('sentenc', 'hi', 'want'): 1,
#          ('hi', 'want', 'act'): 1,
#          ('want', 'act', 'javascript'): 1,
#          ('act', 'javascript', 'consol'): 1,
#          ('javascript', 'consol', 'type'): 1,
#          ('consol', 'type', 'command'): 1,
#          ('command', 'repli', 'javascript'): 1,
#          ('repli', 'javascript', 'consol'): 1,
#          ('javascript', 'consol', 'show'): 1,
#          ('consol', 'show', 'want'): 1,
#          ('first', 'command', 'consol'): 1,
#          ('command', 'consol', 'log'): 1,
#          ('consol', 'log', 'hello'): 1,
#          ('log', 'hello', 'world'): 1,
#          ('text', 'base', 'excel'): 1,
#          ('base', 'excel', 'repli'): 1,
#          ('excel', 'repli', 'text'): 1,
#          ('repli', 'text', 'base'): 1,
#          ('text', 'base', '10'): 1,
#          ('base', '10', 'row'): 1,
#          ('10', 'row', 'excel'): 1,
#          ('row', 'excel', 'sheet'): 1,
#          ('excel', 'sheet', 'row'): 1,
#          ('sheet', 'row', 'number'): 1,
#          ('row', 'number', 'cell'): 1,
#          ('number', 'cell', 'letter'): 1,
#          ('cell', 'letter', 'column'): 1,
#          ('letter', 'column', 'l'): 1,
#          ('column', 'l', 'first'): 1,
#          ('l', 'first', 'column'): 1,
#          ('first', 'column', 'header'): 1,
#          ('column', 'header', 'empti'): 1,
#          ('header', 'empti', 'refer'): 1,
#          ('empti', 'refer', 'row'): 1,
#          ('refer', 'row', 'number'): 1,
#          ('row', 'number', 'tell'): 1,
#          ('number', 'tell', 'write'): 1,
#          ('tell', 'write', 'cell'): 1,
#          ('write', 'cell', 'repli'): 1,
#          ('cell', 'repli', 'result'): 1,
#          ('tabl', 'text', 'noth'): 1,
#          ('write', 'explan', 'write'): 1,
#          ('explan', 'write', 'formula'): 1,
#          ('write', 'formula', 'execut'): 1,
#          ('formula', 'execut', 'formula'): 1,
#          ('execut', 'formula', 'repli'): 1,
#          ('formula', 'repli', 'result'): 1,
#          ('tabl', 'text', 'first'): 1,
#          ('text', 'first', 'repli'): 1,
#          ('first', 'repli', 'empti'): 1,
#          ('repli', 'empti', 'sheet'): 1,
#          ('empti', 'sheet', 'want'): 1,
#          ('sheet', 'want', 'act'): 1,
#          ('weather', 'istanbul', 'want'): 1,
#          ('want', 'act', 'spoken'): 1,
#          ('act', 'spoken', 'english'): 1,
#          ('spoken', 'english', 'teacher'): 1,
#          ('english', 'teacher', 'improv'): 1,
#          ('teacher', 'improv', 'speak'): 1,
#          ('improv', 'speak', 'english'): 1,
#          ('speak', 'english', 'repli'): 1,
#          ('english', 'repli', 'english'): 1,
#          ('repli', 'english', 'practic'): 1,
#          ('english', 'practic', 'spoken'): 1,
#          ('practic', 'spoken', 'english'): 1,
#          ('spoken', 'english', 'want'): 1,
#          ('english', 'want', 'keep'): 1,
#          ('want', 'keep', 'repli'): 1,
#          ('keep', 'repli', 'neat'): 1,
#          ('repli', 'neat', 'limit'): 1,
#          ('neat', 'limit', 'repli'): 1,
#          ('limit', 'repli', '100'): 1,
#          ('repli', '100', 'word'): 1,
#          ('100', 'word', 'want'): 1,
#          ('word', 'want', 'strictli'): 1,
#          ('error', 'want', 'ask'): 1,
#          ('want', 'ask', 'question'): 1,
#          ('question', 'repli', 'let'): 1,
#          ('repli', 'let', 'start'): 1,
#          ('let', 'start', 'practic'): 1,
#          ('start', 'practic', 'could'): 1,
#          ('practic', 'could', 'ask'): 1,
#          ('could', 'ask', 'question'): 1,
#          ('ask', 'question', 'first'): 1,
#          ('question', 'first', 'rememb'): 1,
#          ('first', 'rememb', 'want'): 1,
#          ('rememb', 'want', 'strictli'): 1,
#          ('error', 'want', 'act'): 1,
#          ('want', 'act', 'travel'): 1,
#          ('act', 'travel', 'guid'): 1,
#          ('travel', 'guid', 'write'): 1,
#          ('guid', 'write', 'locat'): 1,
#          ('write', 'locat', 'suggest'): 1,
#          ('locat', 'suggest', 'place'): 1,
#          ('suggest', 'place', 'visit'): 1,
#          ('place', 'visit', 'near'): 1,
#          ('visit', 'near', 'locat'): 1,
#          ('near', 'locat', 'case'): 1,
#          ('locat', 'case', 'also'): 1,
#          ('case', 'also', 'give'): 1,
#          ('also', 'give', 'type'): 1,
#          ('give', 'type', 'place'): 1,
#          ('type', 'place', 'visit'): 1,
#          ('place', 'visit', 'also'): 1,
#          ('visit', 'also', 'suggest'): 1,
#          ('also', 'suggest', 'place'): 1,
#          ('suggest', 'place', 'similar'): 1,
#          ('place', 'similar', 'type'): 1,
#          ('similar', 'type', 'close'): 1,
#          ('type', 'close', 'first'): 1,
#          ('close', 'first', 'locat'): 1,
#          ('first', 'locat', 'first'): 1,
#          ('locat', 'first', 'suggest'): 1,
#          ('suggest', 'request', 'istanbul'): 1,
#          ('request', 'istanbul', 'beyoğlu'): 1,
#          ('istanbul', 'beyoğlu', 'want'): 1,
#          ('beyoğlu', 'want', 'visit'): 1,
#          ('want', 'visit', 'museum'): 1,
#          ('visit', 'museum', 'want'): 1,
#          ('museum', 'want', 'act'): 1,
#          ('want', 'act', 'plagiar'): 1,
#          ('act', 'plagiar', 'checker'): 1,
#          ('plagiar', 'checker', 'write'): 1,
#          ('checker', 'write', 'sentenc'): 1,
#          ('write', 'sentenc', 'repli'): 1,
#          ('sentenc', 'repli', 'undetect'): 1,
#          ('repli', 'undetect', 'plagiar'): 1,
#          ('undetect', 'plagiar', 'check'): 1,
#          ('plagiar', 'check', 'languag'): 1,
#          ('check', 'languag', 'given'): 1,
#          ('languag', 'given', 'sentenc'): 1,
#          ('given', 'sentenc', 'noth'): 1,
#          ('sentenc', 'noth', 'els'): 1,
#          ('first', 'sentenc', 'comput'): 1,
#          ('sentenc', 'comput', 'behav'): 1,
#          ('comput', 'behav', 'like'): 1,
#          ('behav', 'like', 'human'): 1,
#          ('like', 'human', 'speech'): 1,
#          ('human', 'speech', 'recognit'): 1,
#          ('speech', 'recognit', 'system'): 1,
#          ('recognit', 'system', 'must'): 1,
#          ('system', 'must', 'abl'): 1,
#          ('must', 'abl', 'process'): 1,
#          ('abl', 'process', 'nonverb'): 1,
#          ('process', 'nonverb', 'inform'): 1,
#          ('nonverb', 'inform', 'emot'): 1,
#          ('inform', 'emot', 'state'): 1,
#          ('emot', 'state', 'speaker'): 1,
#          ('state', 'speaker', 'want'): 1,
#          ('speaker', 'want', 'act'): 1,
#          ('act', 'like', 'charact'): 1,
#          ('like', 'charact', 'seri'): 1,
#          ('charact', 'seri', 'want'): 1,
#          ('seri', 'want', 'respond'): 1,
#          ('want', 'respond', 'answer'): 1,
#          ('respond', 'answer', 'like'): 1,
#          ('like', 'charact', 'use'): 1,
#          ('charact', 'use', 'tone'): 1,
#          ('use', 'tone', 'manner'): 1,
#          ('tone', 'manner', 'vocabulari'): 1,
#          ('manner', 'vocabulari', 'charact'): 1,
#          ('vocabulari', 'charact', 'would'): 1,
#          ('charact', 'would', 'use'): 1,
#          ('would', 'use', 'write'): 1,
#          ('use', 'write', 'explan'): 1,
#          ('write', 'explan', 'answer'): 1,
#          ('explan', 'answer', 'like'): 1,
#          ('like', 'charact', 'must'): 1,
#          ('charact', 'must', 'know'): 1,
#          ('must', 'know', 'knowledg'): 1,
#          ('know', 'knowledg', 'charact'): 1,
#          ('knowledg', 'charact', 'first'): 1,
#          ('charact', 'first', 'sentenc'): 1,
#          ('sentenc', 'hi', 'charact'): 1,
#          ('hi', 'charact', 'want'): 1,
#          ('charact', 'want', 'act'): 1,
#          ('want', 'act', 'advertis'): 1,
#          ('act', 'advertis', 'creat'): 1,
#          ('advertis', 'creat', 'campaign'): 1,
#          ('creat', 'campaign', 'promot'): 1,
#          ('campaign', 'promot', 'product'): 1,
#          ('product', 'servic', 'choic'): 1,
#          ('servic', 'choic', 'choos'): 1,
#          ('choic', 'choos', 'target'): 1,
#          ('choos', 'target', 'audienc'): 1,
#          ('target', 'audienc', 'develop'): 1,
#          ('audienc', 'develop', 'key'): 1,
#          ('develop', 'key', 'messag'): 1,
#          ('key', 'messag', 'slogan'): 1,
#          ('messag', 'slogan', 'select'): 1,
#          ('slogan', 'select', 'media'): 1,
#          ('select', 'media', 'channel'): 1,
#          ('media', 'channel', 'promot'): 1,
#          ('channel', 'promot', 'decid'): 1,
#          ('promot', 'decid', 'addit'): 1,
#          ('decid', 'addit', 'activ'): 1,
#          ('addit', 'activ', 'need'): 1,
#          ('activ', 'need', 'reach'): 1,
#          ('need', 'reach', 'goal'): 1,
#          ('reach', 'goal', 'first'): 1,
#          ('goal', 'first', 'suggest'): 1,
#          ('help', 'creat', 'advertis'): 1,
#          ('creat', 'advertis', 'campaign'): 1,
#          ('advertis', 'campaign', 'new'): 1,
#          ('campaign', 'new', 'type'): 1,
#          ('new', 'type', 'energi'): 1,
#          ('type', 'energi', 'drink'): 1,
#          ('energi', 'drink', 'target'): 1,
#          ('drink', 'target', 'young'): 1,
#          ('target', 'young', 'adult'): 1,
#          ('young', 'adult', 'age'): 1,
#          ('adult', 'age', '18'): 1,
#          ('age', '18', '30'): 1,
#          ('18', '30', 'want'): 1,
#          ('30', 'want', 'act'): 1,
#          ('want', 'act', 'storytel'): 1,
#          ('act', 'storytel', 'come'): 1,
#          ('storytel', 'come', 'entertain'): 1,
#          ('come', 'entertain', 'stori'): 1,
#          ('entertain', 'stori', 'engag'): 1,
#          ('stori', 'engag', 'imagin'): 1,
#          ('engag', 'imagin', 'captiv'): 1,
#          ('imagin', 'captiv', 'audienc'): 1,
#          ('captiv', 'audienc', 'fairi'): 1,
#          ('audienc', 'fairi', 'tale'): 1,
#          ('fairi', 'tale', 'educ'): 1,
#          ('tale', 'educ', 'stori'): 1,
#          ('educ', 'stori', 'type'): 1,
#          ('stori', 'type', 'stori'): 1,
#          ('type', 'stori', 'potenti'): 1,
#          ('stori', 'potenti', 'captur'): 1,
#          ('potenti', 'captur', 'peopl'): 1,
#          ('captur', 'peopl', 'attent'): 1,
#          ('peopl', 'attent', 'imagin'): 1,
#          ('attent', 'imagin', 'depend'): 1,
#          ('imagin', 'depend', 'target'): 1,
#          ('depend', 'target', 'audienc'): 1,
#          ('target', 'audienc', 'may'): 1,
#          ('audienc', 'may', 'choos'): 1,
#          ('may', 'choos', 'specif'): 1,
#          ('choos', 'specif', 'theme'): 1,
#          ('specif', 'theme', 'topic'): 1,
#          ('theme', 'topic', 'storytel'): 1,
#          ('topic', 'storytel', 'session'): 1,
#          ('storytel', 'session', 'e'): 1,
#          ('session', 'e', 'g'): 1,
#          ('e', 'g', 'children'): 1,
#          ('g', 'children', 'talk'): 1,
#          ('children', 'talk', 'anim'): 1,
#          ('talk', 'anim', 'adult'): 1,
#          ('anim', 'adult', 'histori'): 1,
#          ('adult', 'histori', 'base'): 1,
#          ('histori', 'base', 'tale'): 1,
#          ('base', 'tale', 'might'): 1,
#          ('tale', 'might', 'engag'): 1,
#          ('might', 'engag', 'better'): 1,
#          ('engag', 'better', 'etc'): 1,
#          ('better', 'etc', 'first'): 1,
#          ('etc', 'first', 'request'): 1,
#          ('request', 'need', 'interest'): 1,
#          ('need', 'interest', 'stori'): 1,
#          ('interest', 'stori', 'persever'): 1,
#          ('stori', 'persever', 'want'): 1,
#          ('persever', 'want', 'act'): 1,
#          ('want', 'act', 'footbal'): 1,
#          ('act', 'footbal', 'comment'): 1,
#          ('footbal', 'comment', 'give'): 1,
#          ('comment', 'give', 'descript'): 1,
#          ('give', 'descript', 'footbal'): 1,
#          ('descript', 'footbal', 'match'): 1,
#          ('footbal', 'match', 'progress'): 1,
#          ('match', 'progress', 'comment'): 1,
#          ('progress', 'comment', 'match'): 1,
#          ('comment', 'match', 'provid'): 1,
#          ('match', 'provid', 'analysi'): 1,
#          ('provid', 'analysi', 'happen'): 1,
#          ('analysi', 'happen', 'thu'): 1,
#          ('happen', 'thu', 'far'): 1,
#          ('thu', 'far', 'predict'): 1,
#          ('far', 'predict', 'game'): 1,
#          ('predict', 'game', 'may'): 1,
#          ('game', 'may', 'end'): 1,
#          ('may', 'end', 'knowledg'): 1,
#          ('end', 'knowledg', 'footbal'): 1,
#          ('knowledg', 'footbal', 'terminolog'): 1,
#          ('footbal', 'terminolog', 'tactic'): 1,
#          ('terminolog', 'tactic', 'player'): 1,
#          ('tactic', 'player', 'team'): 1,
#          ('player', 'team', 'involv'): 1,
#          ('team', 'involv', 'match'): 1,
#          ('involv', 'match', 'focu'): 1,
#          ('match', 'focu', 'primarili'): 1,
#          ('focu', 'primarili', 'provid'): 1,
#          ('primarili', 'provid', 'intellig'): 1,
#          ('provid', 'intellig', 'commentari'): 1,
#          ('intellig', 'commentari', 'rather'): 1,
#          ('commentari', 'rather', 'narrat'): 1,
#          ('rather', 'narrat', 'play'): 1,
#          ('narrat', 'play', 'play'): 1,
#          ('play', 'play', 'first'): 1,
#          ('play', 'first', 'request'): 1,
#          ('first', 'request', 'watch'): 1,
#          ('request', 'watch', 'manchest'): 1,
#          ('watch', 'manchest', 'unit'): 1,
#          ('manchest', 'unit', 'vs'): 1,
#          ('unit', 'vs', 'chelsea'): 1,
#          ('vs', 'chelsea', 'provid'): 1,
#          ('chelsea', 'provid', 'commentari'): 1,
#          ('provid', 'commentari', 'match'): 1,
#          ('commentari', 'match', 'want'): 1,
#          ('match', 'want', 'act'): 1,
#          ('want', 'act', 'stand'): 1,
#          ('act', 'stand', 'comedian'): 1,
#          ('stand', 'comedian', 'provid'): 1,
#          ('comedian', 'provid', 'topic'): 1,
#          ('current', 'event', 'use'): 1,
#          ('event', 'use', 'wit'): 1,
#          ('use', 'wit', 'creativ'): 1,
#          ('wit', 'creativ', 'observ'): 1,
#          ('creativ', 'observ', 'skill'): 1,
#          ('observ', 'skill', 'creat'): 1,
#          ('skill', 'creat', 'routin'): 1,
#          ('creat', 'routin', 'base'): 1,
#          ('routin', 'base', 'topic'): 1,
#          ('base', 'topic', 'also'): 1,
#          ('topic', 'also', 'sure'): 1,
#          ('also', 'sure', 'incorpor'): 1,
#          ('sure', 'incorpor', 'person'): 1,
#          ('incorpor', 'person', 'anecdot'): 1,
#          ('person', 'anecdot', 'experi'): 1,
#          ('anecdot', 'experi', 'routin'): 1,
#          ('experi', 'routin', 'order'): 1,
#          ('routin', 'order', 'make'): 1,
#          ('order', 'make', 'relat'): 1,
#          ('make', 'relat', 'engag'): 1,
#          ('relat', 'engag', 'audienc'): 1,
#          ('engag', 'audienc', 'first'): 1,
#          ('audienc', 'first', 'request'): 1,
#          ('request', 'want', 'humor'): 1,
#          ('want', 'humor', 'take'): 1,
#          ('humor', 'take', 'polit'): 1,
#          ('take', 'polit', 'want'): 1,
#          ('polit', 'want', 'act'): 1,
#          ('act', 'motiv', 'coach'): 1,
#          ('motiv', 'coach', 'provid'): 1,
#          ('coach', 'provid', 'inform'): 1,
#          ('provid', 'inform', 'someon'): 1,
#          ('inform', 'someon', 'goal'): 1,
#          ('someon', 'goal', 'challeng'): 1,
#          ('goal', 'challeng', 'job'): 1,
#          ('challeng', 'job', 'come'): 1,
#          ('strategi', 'help', 'person'): 1,
#          ('help', 'person', 'achiev'): 1,
#          ('person', 'achiev', 'goal'): 1,
#          ('achiev', 'goal', 'could'): 1,
#          ('goal', 'could', 'involv'): 1,
#          ('could', 'involv', 'provid'): 1,
#          ('involv', 'provid', 'posit'): 1,
#          ('provid', 'posit', 'affirm'): 1,
#          ('posit', 'affirm', 'give'): 1,
#          ('affirm', 'give', 'help'): 1,
#          ('give', 'help', 'advic'): 1,
#          ('help', 'advic', 'suggest'): 1,
#          ('advic', 'suggest', 'activ'): 1,
#          ('suggest', 'activ', 'reach'): 1,
#          ('activ', 'reach', 'end'): 1,
#          ('reach', 'end', 'goal'): 1,
#          ('end', 'goal', 'first'): 1,
#          ('goal', 'first', 'request'): 1,
#          ('need', 'help', 'motiv'): 1,
#          ('help', 'motiv', 'stay'): 1,
#          ('motiv', 'stay', 'disciplin'): 1,
#          ('stay', 'disciplin', 'studi'): 1,
#          ('disciplin', 'studi', 'upcom'): 1,
#          ('studi', 'upcom', 'exam'): 1,
#          ('upcom', 'exam', 'want'): 1,
#          ('exam', 'want', 'act'): 1,
#          ('want', 'act', 'compos'): 1,
#          ('act', 'compos', 'provid'): 1,
#          ('compos', 'provid', 'lyric'): 1,
#          ('provid', 'lyric', 'song'): 1,
#          ('lyric', 'song', 'creat'): 1,
#          ('song', 'creat', 'music'): 1,
#          ('creat', 'music', 'could'): 1,
#          ('music', 'could', 'includ'): 1,
#          ('could', 'includ', 'use'): 1,
#          ('includ', 'use', 'variou'): 1,
#          ('use', 'variou', 'instrument'): 1,
#          ('variou', 'instrument', 'tool'): 1,
#          ('instrument', 'tool', 'synthes'): 1,
#          ('tool', 'synthes', 'sampler'): 1,
#          ('synthes', 'sampler', 'order'): 1,
#          ('sampler', 'order', 'creat'): 1,
#          ('order', 'creat', 'melodi'): 1,
#          ('creat', 'melodi', 'harmoni'): 1,
#          ('melodi', 'harmoni', 'bring'): 1,
#          ('harmoni', 'bring', 'lyric'): 1,
#          ('bring', 'lyric', 'life'): 1,
#          ('lyric', 'life', 'first'): 1,
#          ('life', 'first', 'request'): 1,
#          ('first', 'request', 'written'): 1,
#          ('request', 'written', 'poem'): 1,
#          ('written', 'poem', 'name'): 1,
#          ('poem', 'name', 'hayalet'): 1,
#          ('name', 'hayalet', 'sevgilim'): 1,
#          ('hayalet', 'sevgilim', 'need'): 1,
#          ('sevgilim', 'need', 'music'): 1,
#          ('need', 'music', 'go'): 1,
#          ('music', 'go', 'want'): 1,
#          ('go', 'want', 'act'): 1,
#          ('act', 'debat', 'provid'): 1,
#          ('debat', 'provid', 'topic'): 1,
#          ('current', 'event', 'task'): 1,
#          ('event', 'task', 'research'): 1,
#          ('task', 'research', 'side'): 1,
#          ('research', 'side', 'debat'): 1,
#          ('side', 'debat', 'present'): 1,
#          ('debat', 'present', 'valid'): 1,
#          ('present', 'valid', 'argument'): 1,
#          ('valid', 'argument', 'side'): 1,
#          ('argument', 'side', 'refut'): 1,
#          ('side', 'refut', 'oppos'): 1,
#          ('refut', 'oppos', 'point'): 1,
#          ('oppos', 'point', 'view'): 1,
#          ('point', 'view', 'draw'): 1,
#          ('view', 'draw', 'persuas'): 1,
#          ('draw', 'persuas', 'conclus'): 1,
#          ('persuas', 'conclus', 'base'): 1,
#          ('conclus', 'base', 'evid'): 1,
#          ('base', 'evid', 'goal'): 1,
#          ('evid', 'goal', 'help'): 1,
#          ('goal', 'help', 'peopl'): 1,
#          ('help', 'peopl', 'come'): 1,
#          ('peopl', 'come', 'away'): 1,
#          ('come', 'away', 'discuss'): 1,
#          ('away', 'discuss', 'increas'): 1,
#          ('discuss', 'increas', 'knowledg'): 1,
#          ('increas', 'knowledg', 'insight'): 1,
#          ('knowledg', 'insight', 'topic'): 1,
#          ('insight', 'topic', 'hand'): 1,
#          ('topic', 'hand', 'first'): 1,
#          ('hand', 'first', 'request'): 1,
#          ('request', 'want', 'opinion'): 1,
#          ('want', 'opinion', 'piec'): 1,
#          ('opinion', 'piec', 'deno'): 1,
#          ('piec', 'deno', 'want'): 1,
#          ...})

# %% [markdown]
# 2. Cálculo de quantas vezes cada cada prefixo (duas primeiras palavras do trigrama) aparece no texto.

# %%
prefixes = defaultdict(int)
for trigram in trigrams:
    prefix = (trigram[0], trigram[1])
    prefixes[prefix] += 1
prefixes
# Out:
# defaultdict(int,
#             {('imagin', 'experienc'): 1,
#              ('experienc', 'ethereum'): 1,
#              ('ethereum', 'develop'): 1,
#              ('develop', 'task'): 1,
#              ('task', 'creat'): 2,
#              ('creat', 'smart'): 1,
#              ('smart', 'contract'): 2,
#              ('contract', 'blockchain'): 1,
#              ('blockchain', 'messeng'): 1,
#              ('messeng', 'object'): 1,
#              ('object', 'save'): 1,
#              ('save', 'messag'): 1,
#              ('messag', 'blockchain'): 1,
#              ('blockchain', 'make'): 1,
#              ('make', 'readabl'): 1,
#              ('readabl', 'public'): 1,
#              ('public', 'everyon'): 1,
#              ('everyon', 'writabl'): 1,
#              ('writabl', 'privat'): 1,
#              ('privat', 'person'): 1,
#              ('person', 'deploy'): 1,
#              ('deploy', 'contract'): 1,
#              ('contract', 'count'): 1,
#              ('count', 'mani'): 1,
#              ('mani', 'time'): 1,
#              ('time', 'messag'): 1,
#              ('messag', 'updat'): 1,
#              ('updat', 'develop'): 1,
#              ('develop', 'solid'): 1,
#              ('solid', 'smart'): 1,
#              ('contract', 'purpos'): 1,
#              ('purpos', 'includ'): 1,
#              ('includ', 'necessari'): 1,
#              ('necessari', 'function'): 1,
#              ('function', 'consider'): 1,
#              ('consider', 'achiev'): 1,
#              ('achiev', 'specifi'): 1,
#              ('specifi', 'goal'): 1,
#              ('goal', 'pleas'): 1,
#              ('pleas', 'provid'): 4,
#              ('provid', 'code'): 3,
#              ('code', 'relev'): 1,
#              ('relev', 'explan'): 1,
#              ('explan', 'ensur'): 1,
#              ('ensur', 'clear'): 1,
#              ('clear', 'understand'): 2,
#              ('understand', 'implement'): 1,
#              ('implement', 'use'): 1,
#              ('use', 'webpilot'): 1,
#              ('webpilot', 'creat'): 1,
#              ('creat', 'outlin'): 1,
#              ('outlin', 'articl'): 1,
#              ('articl', '2'): 1,
#              ('2', '000'): 2,
#              ('000', 'word'): 2,
#              ('word', 'keyword'): 1,
#              ('keyword', 'best'): 1,
#              ('best', 'seo'): 1,
#              ('seo', 'prompt'): 2,
#              ('prompt', 'base'): 2,
#              ('base', 'top'): 1,
#              ('top', '10'): 2,
#              ('10', 'result'): 1,
#              ('result', 'googl'): 1,
#              ('googl', 'includ'): 1,
#              ('includ', 'everi'): 1,
#              ('everi', 'relev'): 1,
#              ('relev', 'head'): 1,
#              ('head', 'possibl'): 1,
#              ('possibl', 'keep'): 1,
#              ('keep', 'keyword'): 1,
#              ('keyword', 'densiti'): 1,
#              ('densiti', 'head'): 1,
#              ('head', 'high'): 1,
#              ('high', 'section'): 1,
#              ('section', 'outlin'): 2,
#              ('outlin', 'includ'): 1,
#              ('includ', 'word'): 2,
#              ('word', 'count'): 1,
#              ('count', 'includ'): 1,
#              ('includ', 'faq'): 1,
#              ('faq', 'section'): 1,
#              ('outlin', 'base'): 1,
#              ('base', 'peopl'): 1,
#              ('peopl', 'also'): 1,
#              ('also', 'ask'): 1,
#              ('ask', 'section'): 1,
#              ('section', 'googl'): 1,
#              ('googl', 'keyword'): 1,
#              ('keyword', 'outlin'): 1,
#              ('outlin', 'must'): 1,
#              ('must', 'detail'): 1,
#              ('detail', 'comprehens'): 1,
#              ('comprehens', 'creat'): 1,
#              ('creat', '2'): 1,
#              ('word', 'articl'): 2,
#              ('articl', 'gener'): 2,
#              ('gener', 'long'): 1,
#              ('long', 'list'): 1,
#              ('list', 'lsi'): 1,
#              ('lsi', 'nlp'): 1,
#              ('nlp', 'keyword'): 1,
#              ('keyword', 'relat'): 1,
#              ('relat', 'keyword'): 2,
#              ('keyword', 'also'): 1,
#              ('also', 'includ'): 1,
#              ('word', 'relat'): 1,
#              ('keyword', 'give'): 1,
#              ('give', 'list'): 2,
#              ('list', '3'): 1,
#              ('3', 'relev'): 1,
#              ('relev', 'extern'): 1,
#              ('extern', 'link'): 1,
#              ('link', 'includ'): 1,
#              ('includ', 'recommend'): 1,
#              ('recommend', 'anchor'): 1,
#              ('anchor', 'text'): 1,
#              ('text', 'make'): 1,
#              ('make', 'sure'): 7,
#              ('sure', 'compet'): 1,
#              ('compet', 'articl'): 1,
#              ('articl', 'split'): 1,
#              ('split', 'outlin'): 1,
#              ('outlin', 'part'): 1,
#              ('part', '1'): 1,
#              ('1', 'part'): 1,
#              ('part', '2'): 1,
#              ('2', 'want'): 1,
#              ('want', 'act'): 166,
#              ('act', 'linux'): 2,
#              ('linux', 'termin'): 2,
#              ('termin', 'type'): 1,
#              ('type', 'command'): 12,
#              ('command', 'repli'): 5,
#              ('repli', 'termin'): 8,
#              ('termin', 'show'): 2,
#              ('show', 'want'): 4,
#              ('want', 'repli'): 18,
#              ('termin', 'output'): 4,
#              ('output', 'insid'): 5,
#              ('insid', 'one'): 6,
#              ('one', 'uniqu'): 7,
#              ('uniqu', 'code'): 7,
#              ('code', 'block'): 11,
#              ('block', 'noth'): 7,
#              ('noth', 'els'): 28,
#              ('els', 'write'): 19,
#              ('write', 'explan'): 41,
#              ('explan', 'type'): 6,
#              ('command', 'unless'): 6,
#              ('unless', 'instruct'): 7,
#              ('instruct', 'need'): 7,
#              ('need', 'tell'): 11,
#              ('tell', 'someth'): 11,
#              ('someth', 'english'): 11,
#              ('english', 'put'): 7,
#              ('put', 'text'): 7,
#              ('text', 'insid'): 7,
#              ('insid', 'curli'): 6,
#              ('curli', 'bracket'): 8,
#              ('bracket', 'like'): 9,
#              ('like', 'first'): 10,
#              ('first', 'command'): 10,
#              ('command', 'pwd'): 1,
#              ('pwd', 'want'): 1,
#              ('act', 'english'): 4,
#              ('english', 'translat'): 2,
#              ('translat', 'spell'): 1,
#              ('spell', 'corrector'): 1,
#              ('corrector', 'improv'): 1,
#              ('improv', 'speak'): 2,
#              ('speak', 'languag'): 1,
#              ('languag', 'detect'): 1,
#              ('detect', 'languag'): 1,
#              ('languag', 'translat'): 1,
#              ('translat', 'answer'): 2,
#              ('answer', 'correct'): 2,
#              ('correct', 'improv'): 4,
#              ('improv', 'version'): 2,
#              ('version', 'text'): 2,
#              ('text', 'english'): 1,
#              ('english', 'want'): 2,
#              ('want', 'replac'): 2,
#              ('replac', 'simplifi'): 2,
#              ('simplifi', 'a0'): 2,
#              ('a0', 'level'): 2,
#              ('level', 'word'): 2,
#              ('word', 'sentenc'): 5,
#              ('sentenc', 'beauti'): 2,
#              ('beauti', 'eleg'): 2,
#              ('eleg', 'upper'): 1,
#              ('upper', 'level'): 1,
#              ('level', 'english'): 2,
#              ('english', 'word'): 1,
#              ('sentenc', 'keep'): 2,
#              ('keep', 'mean'): 2,
#              ('mean', 'make'): 1,
#              ('make', 'literari'): 1,
#              ('literari', 'want'): 1,
#              ('repli', 'correct'): 2,
#              ('improv', 'noth'): 2,
#              ('explan', 'first'): 13,
#              ('first', 'sentenc'): 11,
#              ('sentenc', 'istanbulu'): 1,
#              ('istanbulu', 'cok'): 1,
#              ('cok', 'seviyom'): 1,
#              ('seviyom', 'burada'): 1,
#              ('burada', 'olmak'): 1,
#              ('olmak', 'cok'): 1,
#              ('cok', 'guzel'): 1,
#              ('guzel', 'want'): 1,
#              ('act', 'interview'): 1,
#              ('interview', 'candid'): 1,
#              ('candid', 'ask'): 1,
#              ('ask', 'interview'): 1,
#              ('interview', 'question'): 1,
#              ('question', 'posit'): 1,
#              ('posit', 'posit'): 1,
#              ('posit', 'want'): 1,
#              ('repli', 'interview'): 1,
#              ('interview', 'write'): 1,
#              ('write', 'convers'): 1,
#              ('convers', 'want'): 1,
#              ('want', 'interview'): 1,
#              ('interview', 'ask'): 1,
#              ('ask', 'question'): 10,
#              ('question', 'wait'): 1,
#              ('wait', 'answer'): 2,
#              ('answer', 'write'): 2,
#              ('explan', 'ask'): 1,
#              ('question', 'one'): 1,
#              ('one', 'one'): 1,
#              ('one', 'like'): 1,
#              ('like', 'interview'): 1,
#              ('interview', 'wait'): 1,
#              ('answer', 'first'): 3,
#              ('sentenc', 'hi'): 2,
#              ('hi', 'want'): 1,
#              ('act', 'javascript'): 1,
#              ('javascript', 'consol'): 2,
#              ('consol', 'type'): 1,
#              ('repli', 'javascript'): 1,
#              ('consol', 'show'): 1,
#              ('command', 'consol'): 1,
#              ('consol', 'log'): 1,
#              ('log', 'hello'): 1,
#              ('hello', 'world'): 4,
#              ('world', 'want'): 6,
#              ('act', 'text'): 3,
#              ('text', 'base'): 4,
#              ('base', 'excel'): 1,
#              ('excel', 'repli'): 1,
#              ('repli', 'text'): 1,
#              ('base', '10'): 1,
#              ('10', 'row'): 1,
#              ('row', 'excel'): 1,
#              ('excel', 'sheet'): 1,
#              ('sheet', 'row'): 1,
#              ('row', 'number'): 2,
#              ('number', 'cell'): 1,
#              ('cell', 'letter'): 1,
#              ('letter', 'column'): 1,
#              ('column', 'l'): 1,
#              ('l', 'first'): 1,
#              ('first', 'column'): 2,
#              ('column', 'header'): 1,
#              ('header', 'empti'): 1,
#              ('empti', 'refer'): 1,
#              ('refer', 'row'): 1,
#              ('number', 'tell'): 1,
#              ('tell', 'write'): 1,
#              ('write', 'cell'): 1,
#              ('cell', 'repli'): 1,
#              ('repli', 'result'): 2,
#              ('result', 'excel'): 2,
#              ('excel', 'tabl'): 2,
#              ('tabl', 'text'): 2,
#              ('text', 'noth'): 2,
#              ('explan', 'write'): 1,
#              ('write', 'formula'): 1,
#              ('formula', 'execut'): 1,
#              ('execut', 'formula'): 1,
#              ('formula', 'repli'): 1,
#              ('text', 'first'): 2,
#              ('first', 'repli'): 1,
#              ('repli', 'empti'): 1,
#              ('empti', 'sheet'): 1,
#              ('sheet', 'want'): 1,
#              ('english', 'pronunci'): 3,
#              ('pronunci', 'assist'): 2,
#              ('assist', 'turkish'): 2,
#              ('turkish', 'speak'): 2,
#              ('speak', 'peopl'): 2,
#              ('peopl', 'write'): 2,
#              ('write', 'sentenc'): 5,
#              ('sentenc', 'answer'): 2,
#              ('answer', 'pronunci'): 2,
#              ('pronunci', 'noth'): 2,
#              ('els', 'repli'): 3,
#              ('repli', 'must'): 2,
#              ('must', 'translat'): 2,
#              ('translat', 'sentenc'): 4,
#              ('sentenc', 'pronunci'): 2,
#              ('pronunci', 'pronunci'): 2,
#              ('pronunci', 'use'): 2,
#              ('use', 'turkish'): 2,
#              ('turkish', 'latin'): 2,
#              ('latin', 'letter'): 2,
#              ('letter', 'phonet'): 2,
#              ('phonet', 'write'): 2,
#              ('explan', 'repli'): 8,
#              ('repli', 'first'): 4,
#              ('sentenc', 'weather'): 2,
#              ('weather', 'istanbul'): 2,
#              ('istanbul', 'want'): 3,
#              ('act', 'spoken'): 1,
#              ('spoken', 'english'): 2,
#              ('english', 'teacher'): 1,
#              ('teacher', 'improv'): 1,
#              ('speak', 'english'): 2,
#              ('english', 'repli'): 2,
#              ('repli', 'english'): 1,
#              ('english', 'practic'): 1,
#              ('practic', 'spoken'): 1,
#              ('want', 'keep'): 1,
#              ('keep', 'repli'): 1,
#              ('repli', 'neat'): 1,
#              ('neat', 'limit'): 1,
#              ('limit', 'repli'): 1,
#              ('repli', '100'): 1,
#              ('100', 'word'): 2,
#              ('word', 'want'): 2,
#              ('want', 'strictli'): 2,
#              ('strictli', 'correct'): 2,
#              ('correct', 'grammar'): 2,
#              ('grammar', 'mistak'): 2,
#              ('mistak', 'typo'): 2,
#              ('typo', 'factual'): 2,
#              ('factual', 'error'): 2,
#              ('error', 'want'): 2,
#              ('want', 'ask'): 1,
#              ('question', 'repli'): 4,
#              ('repli', 'let'): 1,
#              ('let', 'start'): 1,
#              ('start', 'practic'): 1,
#              ('practic', 'could'): 1,
#              ('could', 'ask'): 1,
#              ('question', 'first'): 1,
#              ('first', 'rememb'): 1,
#              ('rememb', 'want'): 1,
#              ('act', 'travel'): 1,
#              ('travel', 'guid'): 2,
#              ('guid', 'write'): 1,
#              ('write', 'locat'): 1,
#              ('locat', 'suggest'): 1,
#              ('suggest', 'place'): 2,
#              ('place', 'visit'): 2,
#              ('visit', 'near'): 1,
#              ('near', 'locat'): 1,
#              ('locat', 'case'): 1,
#              ('case', 'also'): 1,
#              ('also', 'give'): 3,
#              ('give', 'type'): 1,
#              ('type', 'place'): 1,
#              ('visit', 'also'): 1,
#              ('also', 'suggest'): 4,
#              ('place', 'similar'): 1,
#              ('similar', 'type'): 1,
#              ('type', 'close'): 1,
#              ('close', 'first'): 1,
#              ('first', 'locat'): 1,
#              ('locat', 'first'): 1,
#              ('first', 'suggest'): 32,
#              ('suggest', 'request'): 32,
#              ('request', 'istanbul'): 1,
#              ('istanbul', 'beyoğlu'): 1,
#              ('beyoğlu', 'want'): 1,
#              ('want', 'visit'): 3,
#              ('visit', 'museum'): 1,
#              ('museum', 'want'): 1,
#              ('act', 'plagiar'): 1,
#              ('plagiar', 'checker'): 1,
#              ('checker', 'write'): 1,
#              ('sentenc', 'repli'): 1,
#              ('repli', 'undetect'): 1,
#              ('undetect', 'plagiar'): 1,
#              ('plagiar', 'check'): 1,
#              ('check', 'languag'): 1,
#              ('languag', 'given'): 1,
#              ('given', 'sentenc'): 1,
#              ('sentenc', 'noth'): 1,
#              ('sentenc', 'comput'): 1,
#              ('comput', 'behav'): 1,
#              ('behav', 'like'): 1,
#              ('like', 'human'): 1,
#              ('human', 'speech'): 1,
#              ('speech', 'recognit'): 1,
#              ('recognit', 'system'): 1,
#              ('system', 'must'): 1,
#              ('must', 'abl'): 1,
#              ('abl', 'process'): 1,
#              ('process', 'nonverb'): 1,
#              ('nonverb', 'inform'): 1,
#              ('inform', 'emot'): 1,
#              ('emot', 'state'): 1,
#              ('state', 'speaker'): 1,
#              ('speaker', 'want'): 1,
#              ('act', 'like'): 5,
#              ('like', 'charact'): 3,
#              ('charact', 'seri'): 1,
#              ('seri', 'want'): 1,
#              ('want', 'respond'): 1,
#              ('respond', 'answer'): 1,
#              ('answer', 'like'): 3,
#              ('charact', 'use'): 1,
#              ('use', 'tone'): 1,
#              ('tone', 'manner'): 1,
#              ('manner', 'vocabulari'): 1,
#              ('vocabulari', 'charact'): 1,
#              ('charact', 'would'): 1,
#              ('would', 'use'): 1,
#              ('use', 'write'): 2,
#              ('explan', 'answer'): 2,
#              ('charact', 'must'): 1,
#              ('must', 'know'): 1,
#              ('know', 'knowledg'): 1,
#              ('knowledg', 'charact'): 1,
#              ('charact', 'first'): 1,
#              ('hi', 'charact'): 1,
#              ('charact', 'want'): 1,
#              ('act', 'advertis'): 1,
#              ('advertis', 'creat'): 1,
#              ('creat', 'campaign'): 1,
#              ('campaign', 'promot'): 1,
#              ('promot', 'product'): 2,
#              ('product', 'servic'): 2,
#              ('servic', 'choic'): 1,
#              ('choic', 'choos'): 1,
#              ('choos', 'target'): 1,
#              ('target', 'audienc'): 3,
#              ('audienc', 'develop'): 1,
#              ('develop', 'key'): 1,
#              ('key', 'messag'): 1,
#              ('messag', 'slogan'): 1,
#              ('slogan', 'select'): 1,
#              ('select', 'media'): 1,
#              ('media', 'channel'): 1,
#              ('channel', 'promot'): 1,
#              ('promot', 'decid'): 1,
#              ('decid', 'addit'): 1,
#              ('addit', 'activ'): 1,
#              ('activ', 'need'): 1,
#              ('need', 'reach'): 1,
#              ('reach', 'goal'): 1,
#              ('goal', 'first'): 2,
#              ('request', 'need'): 53,
#              ('need', 'help'): 46,
#              ('help', 'creat'): 8,
#              ('creat', 'advertis'): 1,
#              ('advertis', 'campaign'): 1,
#              ('campaign', 'new'): 1,
#              ('new', 'type'): 1,
#              ('type', 'energi'): 1,
#              ('energi', 'drink'): 1,
#              ('drink', 'target'): 1,
#              ('target', 'young'): 1,
#              ('young', 'adult'): 2,
#              ('adult', 'age'): 1,
#              ('age', '18'): 2,
#              ('18', '30'): 1,
#              ('30', 'want'): 1,
#              ('act', 'storytel'): 1,
#              ('storytel', 'come'): 1,
#              ('come', 'entertain'): 1,
#              ('entertain', 'stori'): 1,
#              ('stori', 'engag'): 2,
#              ('engag', 'imagin'): 1,
#              ('imagin', 'captiv'): 1,
#              ('captiv', 'audienc'): 1,
#              ('audienc', 'fairi'): 1,
#              ('fairi', 'tale'): 1,
#              ('tale', 'educ'): 1,
#              ('educ', 'stori'): 1,
#              ('stori', 'type'): 1,
#              ('type', 'stori'): 1,
#              ('stori', 'potenti'): 1,
#              ('potenti', 'captur'): 1,
#              ('captur', 'peopl'): 1,
#              ('peopl', 'attent'): 1,
#              ('attent', 'imagin'): 1,
#              ('imagin', 'depend'): 1,
#              ('depend', 'target'): 1,
#              ('audienc', 'may'): 1,
#              ('may', 'choos'): 2,
#              ('choos', 'specif'): 1,
#              ('specif', 'theme'): 1,
#              ('theme', 'topic'): 1,
#              ('topic', 'storytel'): 1,
#              ('storytel', 'session'): 1,
#              ('session', 'e'): 1,
#              ('e', 'g'): 1,
#              ('g', 'children'): 1,
#              ('children', 'talk'): 1,
#              ('talk', 'anim'): 1,
#              ('anim', 'adult'): 1,
#              ('adult', 'histori'): 1,
#              ('histori', 'base'): 1,
#              ('base', 'tale'): 1,
#              ('tale', 'might'): 1,
#              ('might', 'engag'): 1,
#              ('engag', 'better'): 1,
#              ('better', 'etc'): 1,
#              ('etc', 'first'): 3,
#              ('first', 'request'): 60,
#              ('need', 'interest'): 1,
#              ('interest', 'stori'): 1,
#              ('stori', 'persever'): 1,
#              ('persever', 'want'): 1,
#              ('act', 'footbal'): 1,
#              ('footbal', 'comment'): 1,
#              ('comment', 'give'): 1,
#              ('give', 'descript'): 2,
#              ('descript', 'footbal'): 1,
#              ('footbal', 'match'): 1,
#              ('match', 'progress'): 1,
#              ('progress', 'comment'): 1,
#              ('comment', 'match'): 1,
#              ('match', 'provid'): 1,
#              ('provid', 'analysi'): 1,
#              ('analysi', 'happen'): 1,
#              ('happen', 'thu'): 1,
#              ('thu', 'far'): 1,
#              ('far', 'predict'): 1,
#              ('predict', 'game'): 1,
#              ('game', 'may'): 1,
#              ('may', 'end'): 1,
#              ('end', 'knowledg'): 1,
#              ('knowledg', 'footbal'): 1,
#              ('footbal', 'terminolog'): 1,
#              ('terminolog', 'tactic'): 1,
#              ('tactic', 'player'): 1,
#              ('player', 'team'): 1,
#              ('team', 'involv'): 1,
#              ('involv', 'match'): 1,
#              ('match', 'focu'): 1,
#              ('focu', 'primarili'): 1,
#              ('primarili', 'provid'): 1,
#              ('provid', 'intellig'): 1,
#              ('intellig', 'commentari'): 1,
#              ('commentari', 'rather'): 1,
#              ('rather', 'narrat'): 1,
#              ('narrat', 'play'): 1,
#              ('play', 'play'): 1,
#              ('play', 'first'): 1,
#              ('request', 'watch'): 1,
#              ('watch', 'manchest'): 1,
#              ('manchest', 'unit'): 1,
#              ('unit', 'vs'): 1,
#              ('vs', 'chelsea'): 1,
#              ('chelsea', 'provid'): 1,
#              ('provid', 'commentari'): 1,
#              ('commentari', 'match'): 1,
#              ('match', 'want'): 1,
#              ('act', 'stand'): 1,
#              ('stand', 'comedian'): 1,
#              ('comedian', 'provid'): 1,
#              ('provid', 'topic'): 5,
#              ('topic', 'relat'): 3,
#              ('relat', 'current'): 2,
#              ('current', 'event'): 2,
#              ('event', 'use'): 1,
#              ('use', 'wit'): 1,
#              ('wit', 'creativ'): 1,
#              ('creativ', 'observ'): 1,
#              ('observ', 'skill'): 1,
#              ('skill', 'creat'): 1,
#              ('creat', 'routin'): 1,
#              ('routin', 'base'): 1,
#              ('base', 'topic'): 1,
#              ('topic', 'also'): 1,
#              ('also', 'sure'): 1,
#              ('sure', 'incorpor'): 1,
#              ('incorpor', 'person'): 1,
#              ('person', 'anecdot'): 1,
#              ('anecdot', 'experi'): 1,
#              ('experi', 'routin'): 1,
#              ('routin', 'order'): 1,
#              ('order', 'make'): 1,
#              ('make', 'relat'): 1,
#              ('relat', 'engag'): 1,
#              ('engag', 'audienc'): 2,
#              ('audienc', 'first'): 2,
#              ('request', 'want'): 10,
#              ('want', 'humor'): 1,
#              ('humor', 'take'): 1,
#              ('take', 'polit'): 1,
#              ('polit', 'want'): 1,
#              ('act', 'motiv'): 2,
#              ('motiv', 'coach'): 1,
#              ('coach', 'provid'): 5,
#              ('provid', 'inform'): 8,
#              ('inform', 'someon'): 1,
#              ('someon', 'goal'): 1,
#              ('goal', 'challeng'): 1,
#              ('challeng', 'job'): 1,
#              ('job', 'come'): 8,
#              ('come', 'strategi'): 6,
#              ('strategi', 'help'): 3,
#              ('help', 'person'): 1,
#              ('person', 'achiev'): 1,
#              ('achiev', 'goal'): 1,
#              ('goal', 'could'): 1,
#              ('could', 'involv'): 5,
#              ('involv', 'provid'): 1,
#              ('provid', 'posit'): 2,
#              ('posit', 'affirm'): 1,
#              ('affirm', 'give'): 1,
#              ('give', 'help'): 1,
#              ('help', 'advic'): 1,
#              ('advic', 'suggest'): 1,
#              ('suggest', 'activ'): 1,
#              ('activ', 'reach'): 1,
#              ('reach', 'end'): 1,
#              ('end', 'goal'): 1,
#              ('help', 'motiv'): 1,
#              ('motiv', 'stay'): 1,
#              ('stay', 'disciplin'): 1,
#              ('disciplin', 'studi'): 1,
#              ('studi', 'upcom'): 1,
#              ('upcom', 'exam'): 1,
#              ('exam', 'want'): 1,
#              ('act', 'compos'): 1,
#              ('compos', 'provid'): 2,
#              ('provid', 'lyric'): 1,
#              ('lyric', 'song'): 1,
#              ('song', 'creat'): 2,
#              ('creat', 'music'): 1,
#              ('music', 'could'): 1,
#              ('could', 'includ'): 6,
#              ('includ', 'use'): 1,
#              ('use', 'variou'): 1,
#              ('variou', 'instrument'): 1,
#              ('instrument', 'tool'): 1,
#              ('tool', 'synthes'): 1,
#              ('synthes', 'sampler'): 1,
#              ('sampler', 'order'): 1,
#              ('order', 'creat'): 3,
#              ('creat', 'melodi'): 1,
#              ('melodi', 'harmoni'): 1,
#              ('harmoni', 'bring'): 1,
#              ('bring', 'lyric'): 1,
#              ('lyric', 'life'): 1,
#              ('life', 'first'): 1,
#              ('request', 'written'): 1,
#              ('written', 'poem'): 1,
#              ('poem', 'name'): 1,
#              ('name', 'hayalet'): 1,
#              ('hayalet', 'sevgilim'): 1,
#              ('sevgilim', 'need'): 1,
#              ('need', 'music'): 1,
#              ('music', 'go'): 1,
#              ('go', 'want'): 1,
#              ('act', 'debat'): 2,
#              ('debat', 'provid'): 1,
#              ('event', 'task'): 1,
#              ('task', 'research'): 1,
#              ('research', 'side'): 1,
#              ('side', 'debat'): 1,
#              ('debat', 'present'): 1,
#              ('present', 'valid'): 1,
#              ('valid', 'argument'): 1,
#              ('argument', 'side'): 1,
#              ('side', 'refut'): 1,
#              ('refut', 'oppos'): 2,
#              ('oppos', 'point'): 1,
#              ('point', 'view'): 1,
#              ('view', 'draw'): 1,
#              ('draw', 'persuas'): 1,
#              ('persuas', 'conclus'): 1,
#              ('conclus', 'base'): 1,
#              ('base', 'evid'): 1,
#              ('evid', 'goal'): 1,
#              ('goal', 'help'): 2,
#              ('help', 'peopl'): 1,
#              ('peopl', 'come'): 1,
#              ('come', 'away'): 1,
#              ('away', 'discuss'): 1,
#              ('discuss', 'increas'): 1,
#              ('increas', 'knowledg'): 1,
#              ('knowledg', 'insight'): 1,
#              ('insight', 'topic'): 1,
#              ('topic', 'hand'): 2,
#              ('hand', 'first'): 1,
#              ('want', 'opinion'): 1,
#              ('opinion', 'piec'): 4,
#              ('piec', 'deno'): 1,
#              ('deno', 'want'): 1,
#              ('debat', 'coach'): 1,
#              ('provid', 'team'): 1,
#              ('team', 'debat'): 1,
#              ('debat', 'motion'): 1,
#              ('motion', 'upcom'): 1,
#              ('upcom', 'debat'): 2,
#              ('debat', 'goal'): 1,
#              ('goal', 'prepar'): 1,
#              ('prepar', 'team'): 1,
#              ('team', 'success'): 1,
#              ('success', 'organ'): 1,
#              ('organ', 'practic'): 1,
#              ('practic', 'round'): 1,
#              ('round', 'focu'): 1,
#              ('focu', 'persuas'): 1,
#              ('persuas', 'speech'): 1,
#              ('speech', 'effect'): 1,
#              ('effect', 'time'): 1,
#              ('time', 'strategi'): 1,
#              ('strategi', 'refut'): 1,
#              ('oppos', 'argument'): 1,
#              ('argument', 'draw'): 1,
#              ('draw', 'depth'): 1,
#              ('depth', 'conclus'): 1,
#              ('conclus', 'evid'): 1,
#              ('evid', 'provid'): 1,
#              ('provid', 'first'): 1,
#              ('want', 'team'): 1,
#              ('team', 'prepar'): 1,
#              ('prepar', 'upcom'): 1,
#              ('debat', 'whether'): 1,
#              ('whether', 'front'): 1,
#              ('front', 'end'): 2,
#              ('end', 'develop'): 2,
#              ('develop', 'easi'): 1,
#              ('easi', 'want'): 1,
#              ('act', 'screenwrit'): 1,
#              ('screenwrit', 'develop'): 1,
#              ('develop', 'engag'): 2,
#              ('engag', 'creativ'): 2,
#              ('creativ', 'script'): 1,
#              ('script', 'either'): 1,
#              ('either', 'featur'): 1,
#              ('featur', 'length'): 1,
#              ('length', 'film'): 1,
#              ('film', 'web'): 1,
#              ('web', 'seri'): 1,
#              ('seri', 'captiv'): 1,
#              ('captiv', 'viewer'): 1,
#              ('viewer', 'start'): 1,
#              ('start', 'come'): 1,
#              ('come', 'interest'): 1,
#              ('interest', 'charact'): 1,
#              ('charact', 'set'): 1,
#              ('set', 'stori'): 1,
#              ('stori', 'dialogu'): 1,
#              ('dialogu', 'charact'): 1,
#              ('charact', 'etc'): 1,
#              ('etc', 'charact'): 1,
#              ('charact', 'develop'): 1,
#              ('develop', 'complet'): 1,
#              ('complet', 'creat'): 1,
#              ('creat', 'excit'): 1,
#              ('excit', 'storylin'): 1,
#              ('storylin', 'fill'): 1,
#              ('fill', 'twist'): 1,
#              ('twist', 'turn'): 1,
#              ('turn', 'keep'): 1,
#              ('keep', 'viewer'): 1,
#              ('viewer', 'suspens'): 1,
#              ('suspens', 'end'): 1,
#              ('end', 'first'): 2,
#              ('need', 'write'): 4,
#              ('write', 'romant'): 1,
#              ('romant', 'drama'): 1,
#              ('drama', 'movi'): 1,
#              ('movi', 'set'): 1,
#              ('set', 'pari'): 1,
#              ('pari', 'want'): 1,
#              ('act', 'novelist'): 1,
#              ('novelist', 'come'): 1,
#              ('come', 'creativ'): 4,
#              ('creativ', 'captiv'): 1,
#              ('captiv', 'stori'): 1,
#              ('engag', 'reader'): 1,
#              ('reader', 'long'): 1,
#              ('long', 'period'): 1,
#              ('period', 'time'): 1,
#              ('time', 'may'): 1,
#              ('choos', 'genr'): 1,
#              ('genr', 'fantasi'): 1,
#              ('fantasi', 'romanc'): 1,
#              ('romanc', 'histor'): 1,
#              ('histor', 'fiction'): 1,
#              ('fiction', 'aim'): 1,
#              ('aim', 'write'): 1,
#              ('write', 'someth'): 1,
#              ('someth', 'outstand'): 1,
#              ('outstand', 'plotlin'): 1,
#              ('plotlin', 'engag'): 1,
#              ('engag', 'charact'): 1,
#              ('charact', 'unexpect'): 1,
#              ('unexpect', 'climax'): 1,
#              ('climax', 'first'): 1,
#              ('write', 'scienc'): 1,
#              ('scienc', 'fiction'): 1,
#              ('fiction', 'novel'): 1,
#              ('novel', 'set'): 1,
#              ('set', 'futur'): 1,
#              ('futur', 'want'): 1,
#              ('act', 'movi'): 1,
#              ('movi', 'critic'): 1,
#              ('critic', 'develop'): 1,
#              ('creativ', 'movi'): 1,
#              ('movi', 'review'): 3,
#              ('review', 'cover'): 1,
#              ('cover', 'topic'): 1,
#              ('topic', 'like'): 1,
#              ('like', 'plot'): 1,
#              ('plot', 'theme'): 1,
#              ('theme', 'tone'): 1,
#              ('tone', 'act'): 1,
#              ('act', 'charact'): 1,
#              ('charact', 'direct'): 1,
#              ('direct', 'score'): 1,
#              ('score', 'cinematographi'): 1,
#              ('cinematographi', 'product'): 1,
#              ('product', 'design'): 1,
#              ('design', 'special'): 1,
#              ('special', 'effect'): 1,
#              ('effect', 'edit'): 1,
#              ('edit', 'pace'): 1,
#              ('pace', 'dialog'): 1,
#              ('dialog', 'import'): 1,
#              ('import', 'aspect'): 3,
#              ('aspect', 'though'): 1,
#              ('though', 'emphas'): 1,
#              ('emphas', 'movi'): 1,
#              ('movi', 'made'): 1,
#              ('made', 'feel'): 1,
#              ('feel', 'realli'): 1,
#              ('realli', 'reson'): 1,
#              ('reson', 'also'): 1,
#              ('also', 'critic'): 1,
#              ('critic', 'movi'): 1,
#              ('movi', 'pleas'): 1,
#              ('pleas', 'avoid'): 1,
#              ('avoid', 'spoiler'): 1,
#              ('spoiler', 'first'): 1,
#              ('write', 'movi'): 1,
#              ('review', 'movi'): 1,
#              ('movi', 'interstellar'): 1,
#              ('interstellar', 'want'): 1,
#              ('act', 'relationship'): 1,
#              ('relationship', 'coach'): 1,
#              ('provid', 'detail'): 18,
#              ('detail', 'two'): 1,
#              ('two', 'peopl'): 1,
#              ('peopl', 'involv'): 1,
#              ('involv', 'conflict'): 1,
#              ('conflict', 'job'): 1,
#              ('come', 'suggest'): 1,
#              ('suggest', 'work'): 1,
#              ('work', 'issu'): 1,
#              ('issu', 'separ'): 1,
#              ('separ', 'could'): 1,
#              ('includ', 'advic'): 1,
#              ('advic', 'commun'): 1,
#              ('commun', 'techniqu'): 2,
#              ('techniqu', 'differ'): 1,
#              ('differ', 'strategi'): 1,
#              ('strategi', 'improv'): 1,
#              ('improv', 'understand'): 1,
#              ('understand', 'one'): 1,
#              ('one', 'anoth'): 1,
#              ('anoth', 'perspect'): 1,
#              ('perspect', 'first'): 1,
#              ('help', 'solv'): 1,
#              ('solv', 'conflict'): 1,
#              ('conflict', 'spous'): 1,
#              ('spous', 'want'): 1,
#              ('act', 'poet'): 1,
#              ('poet', 'creat'): 1,
#              ('creat', 'poem'): 1,
#              ('poem', 'evok'): 1,
#              ('evok', 'emot'): 1,
#              ('emot', 'power'): 1,
#              ('power', 'stir'): 1,
#              ('stir', 'peopl'): 1,
#              ('peopl', 'soul'): 1,
#              ('soul', 'write'): 1,
#              ('write', 'topic'): 1,
#              ('topic', 'theme'): 1,
#              ('theme', 'make'): 1,
#              ('sure', 'word'): 1,
#              ('word', 'convey'): 1,
#              ('convey', 'feel'): 1,
#              ('feel', 'tri'): 1,
#              ('tri', 'express'): 1,
#              ('express', 'beauti'): 1,
#              ('beauti', 'yet'): 1,
#              ('yet', 'meaning'): 1,
#              ('meaning', 'way'): 1,
#              ('way', 'also'): 1,
#              ('also', 'come'): 1,
#              ('come', 'short'): 1,
#              ('short', 'vers'): 1,
#              ('vers', 'still'): 1,
#              ('still', 'power'): 1,
#              ('power', 'enough'): 1,
#              ('enough', 'leav'): 1,
#              ('leav', 'imprint'): 1,
#              ('imprint', 'reader'): 1,
#              ('reader', 'mind'): 1,
#              ('mind', 'first'): 1,
#              ('need', 'poem'): 1,
#              ('poem', 'love'): 1,
#              ('love', 'want'): 1,
#              ('act', 'rapper'): 1,
#              ('rapper', 'come'): 1,
#              ('come', 'power'): 1,
#              ('power', 'meaning'): 1,
#              ('meaning', 'lyric'): 1,
#              ('lyric', 'beat'): 1,
#              ('beat', 'rhythm'): 1,
#              ('rhythm', 'wow'): 1,
#              ('wow', 'audienc'): 1,
#              ('audienc', 'lyric'): 1,
#              ('lyric', 'intrigu'): 1,
#              ('intrigu', 'mean'): 1,
#              ('mean', 'messag'): 1,
#              ('messag', 'peopl'): 1,
#              ('peopl', 'relat'): 1,
#              ('relat', 'come'): 1,
#              ('come', 'choos'): 1,
#              ('choos', 'beat'): 1,
#              ('beat', 'make'): 1,
#              ('sure', 'catchi'): 1,
#              ('catchi', 'yet'): 1,
#              ('yet', 'relev'): 1,
#              ('relev', 'word'): 1,
#              ('word', 'combin'): 1,
#              ('combin', 'make'): 1,
#              ('make', 'explos'): 1,
#              ('explos', 'sound'): 1,
#              ('sound', 'everytim'): 1,
#              ('everytim', 'first'): 1,
#              ('need', 'rap'): 1,
#              ('rap', 'song'): 1,
#              ('song', 'find'): 1,
#              ('find', 'strength'): 1,
#              ('strength', 'within'): 1,
#              ('within', 'want'): 1,
#              ('motiv', 'speaker'): 1,
#              ('speaker', 'put'): 1,
#              ('put', 'togeth'): 1,
#              ('togeth', 'word'): 1,
#              ('word', 'inspir'): 1,
#              ('inspir', 'action'): 1,
#              ('action', 'make'): 1,
#              ('make', 'peopl'): 2,
#              ('peopl', 'feel'): 1,
#              ('feel', 'empow'): 1,
#              ('empow', 'someth'): 1,
#              ('someth', 'beyond'): 1,
#              ('beyond', 'abil'): 1,
#              ('abil', 'talk'): 1,
#              ('talk', 'topic'): 1,
#              ('topic', 'aim'): 1,
#              ('aim', 'make'): 1,
#              ('sure', 'say'): 1,
#              ('say', 'reson'): 1,
#              ('reson', 'audienc'): 1,
#              ('audienc', 'give'): 1,
#              ('give', 'incent'): 1,
#              ('incent', 'work'): 1,
#              ('work', 'goal'): 1,
#              ('goal', 'strive'): 1,
#              ('strive', 'better'): 1,
#              ('better', 'possibl'): 1,
#              ('possibl', 'first'): 1,
#              ('need', 'speech'): 1,
#              ('speech', 'everyon'): 1,
#              ('everyon', 'never'): 1,
#              ('never', 'give'): 1,
#              ('give', 'want'): 1,
#              ('act', 'philosophi'): 1,
#              ('philosophi', 'teacher'): 1,
#              ('teacher', 'provid'): 3,
#              ('relat', 'studi'): 2,
#              ('studi', 'philosophi'): 2,
#              ('philosophi', 'job'): 2,
#              ('job', 'explain'): 3,
#              ('explain', 'concept'): 2,
#              ('concept', 'easi'): 1,
#              ('easi', 'understand'): 4,
#              ('understand', 'manner'): 1,
#              ('manner', 'could'): 1,
#              ('includ', 'provid'): 2,
#              ('provid', 'exampl'): 1,
#              ('exampl', 'pose'): 1,
#              ('pose', 'question'): 1,
#              ('question', 'break'): 1,
#              ...})

# %% [markdown]
# 3. Cálculo da probabilidade da terceira palavra ocorrer para cada prefixo.

# %%
language_model = defaultdict(dict)
for trigram, frequency in frequency_trigrams.items():
    prefix = (trigram[0], trigram[1])
    word3 = trigram[2]
    probability = frequency / prefixes[prefix]
    language_model[prefix][word3] = probability
language_model
# Out:
# defaultdict(dict,
#             {('imagin', 'experienc'): {'ethereum': 1.0},
#              ('experienc', 'ethereum'): {'develop': 1.0},
#              ('ethereum', 'develop'): {'task': 1.0},
#              ('develop', 'task'): {'creat': 1.0},
#              ('task', 'creat'): {'smart': 0.5, 'worksheet': 0.5},
#              ('creat', 'smart'): {'contract': 1.0},
#              ('smart', 'contract'): {'blockchain': 0.5, 'purpos': 0.5},
#              ('contract', 'blockchain'): {'messeng': 1.0},
#              ('blockchain', 'messeng'): {'object': 1.0},
#              ('messeng', 'object'): {'save': 1.0},
#              ('object', 'save'): {'messag': 1.0},
#              ('save', 'messag'): {'blockchain': 1.0},
#              ('messag', 'blockchain'): {'make': 1.0},
#              ('blockchain', 'make'): {'readabl': 1.0},
#              ('make', 'readabl'): {'public': 1.0},
#              ('readabl', 'public'): {'everyon': 1.0},
#              ('public', 'everyon'): {'writabl': 1.0},
#              ('everyon', 'writabl'): {'privat': 1.0},
#              ('writabl', 'privat'): {'person': 1.0},
#              ('privat', 'person'): {'deploy': 1.0},
#              ('person', 'deploy'): {'contract': 1.0},
#              ('deploy', 'contract'): {'count': 1.0},
#              ('contract', 'count'): {'mani': 1.0},
#              ('count', 'mani'): {'time': 1.0},
#              ('mani', 'time'): {'messag': 1.0},
#              ('time', 'messag'): {'updat': 1.0},
#              ('messag', 'updat'): {'develop': 1.0},
#              ('updat', 'develop'): {'solid': 1.0},
#              ('develop', 'solid'): {'smart': 1.0},
#              ('solid', 'smart'): {'contract': 1.0},
#              ('contract', 'purpos'): {'includ': 1.0},
#              ('purpos', 'includ'): {'necessari': 1.0},
#              ('includ', 'necessari'): {'function': 1.0},
#              ('necessari', 'function'): {'consider': 1.0},
#              ('function', 'consider'): {'achiev': 1.0},
#              ('consider', 'achiev'): {'specifi': 1.0},
#              ('achiev', 'specifi'): {'goal': 1.0},
#              ('specifi', 'goal'): {'pleas': 1.0},
#              ('goal', 'pleas'): {'provid': 1.0},
#              ('pleas', 'provid'): {'code': 0.25,
#               'suggest': 0.25,
#               'list': 0.25,
#               'least': 0.25},
#              ('provid', 'code'): {'relev': 0.3333333333333333,
#               'exampl': 0.3333333333333333,
#               'problem': 0.3333333333333333},
#              ('code', 'relev'): {'explan': 1.0},
#              ('relev', 'explan'): {'ensur': 1.0},
#              ('explan', 'ensur'): {'clear': 1.0},
#              ('ensur', 'clear'): {'understand': 1.0},
#              ('clear', 'understand'): {'implement': 0.5, 'explan': 0.5},
#              ('understand', 'implement'): {'use': 1.0},
#              ('implement', 'use'): {'webpilot': 1.0},
#              ('use', 'webpilot'): {'creat': 1.0},
#              ('webpilot', 'creat'): {'outlin': 1.0},
#              ('creat', 'outlin'): {'articl': 1.0},
#              ('outlin', 'articl'): {'2': 1.0},
#              ('articl', '2'): {'000': 1.0},
#              ('2', '000'): {'word': 1.0},
#              ('000', 'word'): {'keyword': 0.5, 'articl': 0.5},
#              ('word', 'keyword'): {'best': 1.0},
#              ('keyword', 'best'): {'seo': 1.0},
#              ('best', 'seo'): {'prompt': 1.0},
#              ('seo', 'prompt'): {'base': 0.5, 'want': 0.5},
#              ('prompt', 'base'): {'top': 0.5, 'content': 0.5},
#              ('base', 'top'): {'10': 1.0},
#              ('top', '10'): {'result': 0.5, 'product': 0.5},
#              ('10', 'result'): {'googl': 1.0},
#              ('result', 'googl'): {'includ': 1.0},
#              ('googl', 'includ'): {'everi': 1.0},
#              ('includ', 'everi'): {'relev': 1.0},
#              ('everi', 'relev'): {'head': 1.0},
#              ('relev', 'head'): {'possibl': 1.0},
#              ('head', 'possibl'): {'keep': 1.0},
#              ('possibl', 'keep'): {'keyword': 1.0},
#              ('keep', 'keyword'): {'densiti': 1.0},
#              ('keyword', 'densiti'): {'head': 1.0},
#              ('densiti', 'head'): {'high': 1.0},
#              ('head', 'high'): {'section': 1.0},
#              ('high', 'section'): {'outlin': 1.0},
#              ('section', 'outlin'): {'includ': 0.5, 'base': 0.5},
#              ('outlin', 'includ'): {'word': 1.0},
#              ('includ', 'word'): {'count': 0.5, 'relat': 0.5},
#              ('word', 'count'): {'includ': 1.0},
#              ('count', 'includ'): {'faq': 1.0},
#              ('includ', 'faq'): {'section': 1.0},
#              ('faq', 'section'): {'outlin': 1.0},
#              ('outlin', 'base'): {'peopl': 1.0},
#              ('base', 'peopl'): {'also': 1.0},
#              ('peopl', 'also'): {'ask': 1.0},
#              ('also', 'ask'): {'section': 1.0},
#              ('ask', 'section'): {'googl': 1.0},
#              ('section', 'googl'): {'keyword': 1.0},
#              ('googl', 'keyword'): {'outlin': 1.0},
#              ('keyword', 'outlin'): {'must': 1.0},
#              ('outlin', 'must'): {'detail': 1.0},
#              ('must', 'detail'): {'comprehens': 1.0},
#              ('detail', 'comprehens'): {'creat': 1.0},
#              ('comprehens', 'creat'): {'2': 1.0},
#              ('creat', '2'): {'000': 1.0},
#              ('word', 'articl'): {'gener': 1.0},
#              ('articl', 'gener'): {'long': 0.5, 'five': 0.5},
#              ('gener', 'long'): {'list': 1.0},
#              ('long', 'list'): {'lsi': 1.0},
#              ('list', 'lsi'): {'nlp': 1.0},
#              ('lsi', 'nlp'): {'keyword': 1.0},
#              ('nlp', 'keyword'): {'relat': 1.0},
#              ('keyword', 'relat'): {'keyword': 1.0},
#              ('relat', 'keyword'): {'also': 0.5, 'give': 0.5},
#              ('keyword', 'also'): {'includ': 1.0},
#              ('also', 'includ'): {'word': 1.0},
#              ('word', 'relat'): {'keyword': 1.0},
#              ('keyword', 'give'): {'list': 1.0},
#              ('give', 'list'): {'3': 0.5, 'action': 0.5},
#              ('list', '3'): {'relev': 1.0},
#              ('3', 'relev'): {'extern': 1.0},
#              ('relev', 'extern'): {'link': 1.0},
#              ('extern', 'link'): {'includ': 1.0},
#              ('link', 'includ'): {'recommend': 1.0},
#              ('includ', 'recommend'): {'anchor': 1.0},
#              ('recommend', 'anchor'): {'text': 1.0},
#              ('anchor', 'text'): {'make': 1.0},
#              ('text', 'make'): {'sure': 1.0},
#              ('make', 'sure'): {'compet': 0.14285714285714285,
#               'word': 0.14285714285714285,
#               'catchi': 0.14285714285714285,
#               'say': 0.14285714285714285,
#               'need': 0.14285714285714285,
#               'progress': 0.14285714285714285,
#               'beginn': 0.14285714285714285},
#              ('sure', 'compet'): {'articl': 1.0},
#              ('compet', 'articl'): {'split': 1.0},
#              ('articl', 'split'): {'outlin': 1.0},
#              ('split', 'outlin'): {'part': 1.0},
#              ('outlin', 'part'): {'1': 1.0},
#              ('part', '1'): {'part': 1.0},
#              ('1', 'part'): {'2': 1.0},
#              ('part', '2'): {'want': 1.0},
#              ('2', 'want'): {'act': 1.0},
#              ('want', 'act'): {'linux': 0.006024096385542169,
#               'english': 0.018072289156626505,
#               'interview': 0.006024096385542169,
#               'javascript': 0.006024096385542169,
#               'text': 0.018072289156626505,
#               'spoken': 0.006024096385542169,
#               'travel': 0.006024096385542169,
#               'plagiar': 0.006024096385542169,
#               'like': 0.030120481927710843,
#               'advertis': 0.006024096385542169,
#               'storytel': 0.006024096385542169,
#               'footbal': 0.006024096385542169,
#               'stand': 0.006024096385542169,
#               'motiv': 0.012048192771084338,
#               'compos': 0.006024096385542169,
#               'debat': 0.012048192771084338,
#               'screenwrit': 0.006024096385542169,
#               'novelist': 0.006024096385542169,
#               'movi': 0.006024096385542169,
#               'relationship': 0.006024096385542169,
#               'poet': 0.006024096385542169,
#               'rapper': 0.006024096385542169,
#               'philosophi': 0.006024096385542169,
#               'philosoph': 0.006024096385542169,
#               'math': 0.006024096385542169,
#               'ai': 0.012048192771084338,
#               'ux': 0.006024096385542169,
#               'cyber': 0.006024096385542169,
#               'recruit': 0.006024096385542169,
#               'life': 0.012048192771084338,
#               'etymologist': 0.006024096385542169,
#               'commentariat': 0.006024096385542169,
#               'magician': 0.006024096385542169,
#               'career': 0.012048192771084338,
#               'pet': 0.006024096385542169,
#               'person': 0.030120481927710843,
#               'mental': 0.006024096385542169,
#               'real': 0.006024096385542169,
#               'logistician': 0.006024096385542169,
#               'dentist': 0.006024096385542169,
#               'web': 0.006024096385542169,
#               'doctor': 0.006024096385542169,
#               'account': 0.006024096385542169,
#               'artist': 0.006024096385542169,
#               'interior': 0.006024096385542169,
#               'self': 0.006024096385542169,
#               'gnomist': 0.006024096385542169,
#               'aphor': 0.006024096385542169,
#               'fanci': 0.006024096385542169,
#               'statistician': 0.006024096385542169,
#               'prompt': 0.012048192771084338,
#               'instructor': 0.006024096385542169,
#               'sql': 0.006024096385542169,
#               'psychologist': 0.006024096385542169,
#               'smart': 0.006024096385542169,
#               'tech': 0.012048192771084338,
#               'develop': 0.006024096385542169,
#               'academician': 0.006024096385542169,
#               'architect': 0.006024096385542169,
#               'lunat': 0.006024096385542169,
#               'gaslight': 0.006024096385542169,
#               'fallaci': 0.006024096385542169,
#               'journal': 0.006024096385542169,
#               'diy': 0.006024096385542169,
#               'social': 0.012048192771084338,
#               'socrat': 0.012048192771084338,
#               'educ': 0.006024096385542169,
#               'yogi': 0.006024096385542169,
#               'essay': 0.006024096385542169,
#               'elocutionist': 0.006024096385542169,
#               'scientif': 0.006024096385542169,
#               'car': 0.006024096385542169,
#               'hypnotherapist': 0.006024096385542169,
#               'historian': 0.006024096385542169,
#               'astrolog': 0.006024096385542169,
#               'film': 0.006024096385542169,
#               'classic': 0.006024096385542169,
#               'journalist': 0.006024096385542169,
#               'digit': 0.006024096385542169,
#               'public': 0.006024096385542169,
#               'makeup': 0.006024096385542169,
#               'babysitt': 0.006024096385542169,
#               'ascii': 0.006024096385542169,
#               'synonym': 0.006024096385542169,
#               'food': 0.006024096385542169,
#               'virtual': 0.012048192771084338,
#               'legal': 0.006024096385542169,
#               'machin': 0.006024096385542169,
#               'biblic': 0.006024096385542169,
#               'expert': 0.018072289156626505,
#               'rival': 0.006024096385542169,
#               'softwar': 0.012048192771084338,
#               'regex': 0.006024096385542169,
#               'time': 0.006024096385542169,
#               'dream': 0.006024096385542169,
#               'talent': 0.006024096385542169,
#               'r': 0.006024096385542169,
#               'stackoverflow': 0.006024096385542169,
#               'first': 0.006024096385542169,
#               'fill': 0.006024096385542169,
#               'tic': 0.006024096385542169,
#               'password': 0.006024096385542169,
#               'senior': 0.006024096385542169,
#               'solr': 0.006024096385542169,
#               'spongebob': 0.006024096385542169,
#               'languag': 0.012048192771084338,
#               'salesperson': 0.006024096385542169,
#               'commit': 0.006024096385542169,
#               'chief': 0.006024096385542169,
#               'graphviz': 0.006024096385542169,
#               'speech': 0.006024096385542169,
#               'titl': 0.006024096385542169,
#               'drunk': 0.006024096385542169,
#               'mathemat': 0.006024096385542169,
#               'song': 0.006024096385542169,
#               'technolog': 0.006024096385542169,
#               'proofread': 0.006024096385542169,
#               'buddha': 0.006024096385542169,
#               'chemic': 0.006024096385542169,
#               'friend': 0.006024096385542169,
#               'chatgpt': 0.006024096385542169,
#               'guess': 0.006024096385542169,
#               'wikipedia': 0.006024096385542169,
#               'japanes': 0.006024096385542169,
#               'note': 0.012048192771084338,
#               'data': 0.006024096385542169,
#               'restaur': 0.006024096385542169,
#               'empathet': 0.006024096385542169,
#               'acoust': 0.006024096385542169,
#               'knowledg': 0.006024096385542169,
#               'logic': 0.006024096385542169,
#               'teacher': 0.006024096385542169,
#               'git': 0.006024096385542169,
#               'program': 0.006024096385542169,
#               'dax': 0.006024096385542169,
#               'children': 0.006024096385542169,
#               'book': 0.006024096385542169,
#               'advanc': 0.006024096385542169,
#               'seo': 0.006024096385542169},
#              ('act', 'linux'): {'termin': 1.0},
#              ('linux', 'termin'): {'type': 0.5, 'want': 0.5},
#              ('termin', 'type'): {'command': 1.0},
#              ('type', 'command'): {'repli': 0.4166666666666667,
#               'unless': 0.5,
#               'ai': 0.08333333333333333},
#              ('command', 'repli'): {'termin': 0.6,
#               'javascript': 0.2,
#               'descript': 0.2},
#              ('repli', 'termin'): {'show': 0.25, 'output': 0.5, 'would': 0.25},
#              ('termin', 'show'): {'want': 1.0},
#              ('show', 'want'): {'repli': 1.0},
#              ('want', 'repli'): {'termin': 0.2222222222222222,
#               'correct': 0.1111111111111111,
#               'interview': 0.05555555555555555,
#               'game': 0.05555555555555555,
#               'tabl': 0.05555555555555555,
#               'solut': 0.05555555555555555,
#               'given': 0.05555555555555555,
#               'anyth': 0.1111111111111111,
#               'map': 0.05555555555555555,
#               'answer': 0.1111111111111111,
#               'dax': 0.05555555555555555,
#               'question': 0.05555555555555555},
#              ('termin', 'output'): {'insid': 1.0},
#              ('output', 'insid'): {'one': 1.0},
#              ('insid', 'one'): {'uniqu': 1.0},
#              ('one', 'uniqu'): {'code': 1.0},
#              ('uniqu', 'code'): {'block': 1.0},
#              ('code', 'block'): {'noth': 0.6363636363636364,
#               'delimit': 0.09090909090909091,
#               'write': 0.09090909090909091,
#               'send': 0.09090909090909091,
#               'per': 0.09090909090909091},
#              ('block', 'noth'): {'els': 1.0},
#              ('noth', 'els'): {'write': 0.6785714285714286,
#               'repli': 0.07142857142857142,
#               'domain': 0.03571428571428571,
#               'word': 0.03571428571428571,
#               'enter': 0.03571428571428571,
#               'level': 0.03571428571428571,
#               'alway': 0.03571428571428571,
#               'appropri': 0.03571428571428571,
#               'structur': 0.03571428571428571},
#              ('els', 'write'): {'explan': 1.0},
#              ('write', 'explan'): {'type': 0.14634146341463414,
#               'first': 0.3170731707317073,
#               'ask': 0.024390243902439025,
#               'write': 0.024390243902439025,
#               'repli': 0.17073170731707318,
#               'answer': 0.024390243902439025,
#               'ever': 0.024390243902439025,
#               'need': 0.04878048780487805,
#               'exampl': 0.04878048780487805,
#               'simpli': 0.024390243902439025,
#               'enough': 0.024390243902439025,
#               'link': 0.024390243902439025,
#               'word': 0.07317073170731707,
#               'provid': 0.024390243902439025},
#              ('explan', 'type'): {'command': 1.0},
#              ('command', 'unless'): {'instruct': 1.0},
#              ('unless', 'instruct'): {'need': 1.0},
#              ('instruct', 'need'): {'tell': 0.8571428571428571,
#               'provid': 0.14285714285714285},
#              ('need', 'tell'): {'someth': 1.0},
#              ('tell', 'someth'): {'english': 1.0},
#              ('someth', 'english'): {'put': 0.6363636363636364,
#               'repli': 0.09090909090909091,
#               'curli': 0.09090909090909091,
#               'wrap': 0.18181818181818182},
#              ('english', 'put'): {'text': 1.0},
#              ('put', 'text'): {'insid': 1.0},
#              ('text', 'insid'): {'curli': 0.8571428571428571,
#               'squar': 0.14285714285714285},
#              ('insid', 'curli'): {'bracket': 1.0},
#              ('curli', 'bracket'): {'like': 1.0},
#              ('bracket', 'like'): {'first': 0.7777777777777778,
#               'like': 0.2222222222222222},
#              ('like', 'first'): {'command': 0.6,
#               'express': 0.1,
#               'question': 0.1,
#               'sentenc': 0.2},
#              ('first', 'command'): {'pwd': 0.1,
#               'consol': 0.1,
#               'wake': 0.1,
#               'want': 0.1,
#               'select': 0.1,
#               'sampl': 0.1,
#               'php': 0.1,
#               'add': 0.1,
#               'print': 0.1,
#               'give': 0.1},
#              ('command', 'pwd'): {'want': 1.0},
#              ('pwd', 'want'): {'act': 1.0},
#              ('act', 'english'): {'translat': 0.25, 'pronunci': 0.75},
#              ('english', 'translat'): {'spell': 0.5, 'answer': 0.5},
#              ('translat', 'spell'): {'corrector': 1.0},
#              ('spell', 'corrector'): {'improv': 1.0},
#              ('corrector', 'improv'): {'speak': 1.0},
#              ('improv', 'speak'): {'languag': 0.5, 'english': 0.5},
#              ('speak', 'languag'): {'detect': 1.0},
#              ('languag', 'detect'): {'languag': 1.0},
#              ('detect', 'languag'): {'translat': 1.0},
#              ('languag', 'translat'): {'answer': 1.0},
#              ('translat', 'answer'): {'correct': 1.0},
#              ('answer', 'correct'): {'improv': 1.0},
#              ('correct', 'improv'): {'version': 0.5, 'noth': 0.5},
#              ('improv', 'version'): {'text': 1.0},
#              ('version', 'text'): {'english': 0.5, 'biblic': 0.5},
#              ('text', 'english'): {'want': 1.0},
#              ('english', 'want'): {'replac': 0.5, 'keep': 0.5},
#              ('want', 'replac'): {'simplifi': 1.0},
#              ('replac', 'simplifi'): {'a0': 1.0},
#              ('simplifi', 'a0'): {'level': 1.0},
#              ('a0', 'level'): {'word': 1.0},
#              ('level', 'word'): {'sentenc': 1.0},
#              ('word', 'sentenc'): {'beauti': 0.4, 'keep': 0.4, 'contain': 0.2},
#              ('sentenc', 'beauti'): {'eleg': 1.0},
#              ('beauti', 'eleg'): {'upper': 0.5, 'biblic': 0.5},
#              ('eleg', 'upper'): {'level': 1.0},
#              ('upper', 'level'): {'english': 1.0},
#              ('level', 'english'): {'word': 0.5, 'profici': 0.5},
#              ('english', 'word'): {'sentenc': 1.0},
#              ('sentenc', 'keep'): {'mean': 1.0},
#              ('keep', 'mean'): {'make': 0.5, 'want': 0.5},
#              ('mean', 'make'): {'literari': 1.0},
#              ('make', 'literari'): {'want': 1.0},
#              ('literari', 'want'): {'repli': 1.0},
#              ('repli', 'correct'): {'improv': 1.0},
#              ('improv', 'noth'): {'els': 1.0},
#              ('explan', 'first'): {'sentenc': 0.15384615384615385,
#               'request': 0.6153846153846154,
#               'problem': 0.07692307692307693,
#               'messag': 0.15384615384615385},
#              ('first', 'sentenc'): {'istanbulu': 0.09090909090909091,
#               'hi': 0.18181818181818182,
#               'weather': 0.18181818181818182,
#               'comput': 0.09090909090909091,
#               'hello': 0.2727272727272727,
#               'kiel': 0.09090909090909091,
#               'want': 0.09090909090909091},
#              ('sentenc', 'istanbulu'): {'cok': 1.0},
#              ('istanbulu', 'cok'): {'seviyom': 1.0},
#              ('cok', 'seviyom'): {'burada': 1.0},
#              ('seviyom', 'burada'): {'olmak': 1.0},
#              ('burada', 'olmak'): {'cok': 1.0},
#              ('olmak', 'cok'): {'guzel': 1.0},
#              ('cok', 'guzel'): {'want': 1.0},
#              ('guzel', 'want'): {'act': 1.0},
#              ('act', 'interview'): {'candid': 1.0},
#              ('interview', 'candid'): {'ask': 1.0},
#              ('candid', 'ask'): {'interview': 1.0},
#              ('ask', 'interview'): {'question': 1.0},
#              ('interview', 'question'): {'posit': 1.0},
#              ('question', 'posit'): {'posit': 1.0},
#              ('posit', 'posit'): {'want': 1.0},
#              ('posit', 'want'): {'repli': 1.0},
#              ('repli', 'interview'): {'write': 1.0},
#              ('interview', 'write'): {'convers': 1.0},
#              ('write', 'convers'): {'want': 1.0},
#              ('convers', 'want'): {'interview': 1.0},
#              ('want', 'interview'): {'ask': 1.0},
#              ('interview', 'ask'): {'question': 1.0},
#              ('ask', 'question'): {'wait': 0.1,
#               'one': 0.1,
#               'repli': 0.2,
#               'first': 0.1,
#               'improv': 0.1,
#               'answer': 0.1,
#               'leagu': 0.1,
#               'relat': 0.1,
#               'describ': 0.1},
#              ('question', 'wait'): {'answer': 1.0},
#              ('wait', 'answer'): {'write': 0.5, 'first': 0.5},
#              ('answer', 'write'): {'explan': 1.0},
#              ('explan', 'ask'): {'question': 1.0},
#              ('question', 'one'): {'one': 1.0},
#              ('one', 'one'): {'like': 1.0},
#              ('one', 'like'): {'interview': 1.0},
#              ('like', 'interview'): {'wait': 1.0},
#              ('interview', 'wait'): {'answer': 1.0},
#              ('answer', 'first'): {'sentenc': 0.3333333333333333,
#               'job': 0.3333333333333333,
#               'question': 0.3333333333333333},
#              ('sentenc', 'hi'): {'want': 0.5, 'charact': 0.5},
#              ('hi', 'want'): {'act': 1.0},
#              ('act', 'javascript'): {'consol': 1.0},
#              ('javascript', 'consol'): {'type': 0.5, 'show': 0.5},
#              ('consol', 'type'): {'command': 1.0},
#              ('repli', 'javascript'): {'consol': 1.0},
#              ('consol', 'show'): {'want': 1.0},
#              ('command', 'consol'): {'log': 1.0},
#              ('consol', 'log'): {'hello': 1.0},
#              ('log', 'hello'): {'world': 1.0},
#              ('hello', 'world'): {'want': 0.75, 'would': 0.25},
#              ('world', 'want'): {'act': 1.0},
#              ('act', 'text'): {'base': 1.0},
#              ('text', 'base'): {'excel': 0.25,
#               '10': 0.25,
#               'adventur': 0.25,
#               'web': 0.25},
#              ('base', 'excel'): {'repli': 1.0},
#              ('excel', 'repli'): {'text': 1.0},
#              ('repli', 'text'): {'base': 1.0},
#              ('base', '10'): {'row': 1.0},
#              ('10', 'row'): {'excel': 1.0},
#              ('row', 'excel'): {'sheet': 1.0},
#              ('excel', 'sheet'): {'row': 1.0},
#              ('sheet', 'row'): {'number': 1.0},
#              ('row', 'number'): {'cell': 0.5, 'tell': 0.5},
#              ('number', 'cell'): {'letter': 1.0},
#              ('cell', 'letter'): {'column': 1.0},
#              ('letter', 'column'): {'l': 1.0},
#              ('column', 'l'): {'first': 1.0},
#              ('l', 'first'): {'column': 1.0},
#              ('first', 'column'): {'header': 0.5, 'list': 0.5},
#              ('column', 'header'): {'empti': 1.0},
#              ('header', 'empti'): {'refer': 1.0},
#              ('empti', 'refer'): {'row': 1.0},
#              ('refer', 'row'): {'number': 1.0},
#              ('number', 'tell'): {'write': 1.0},
#              ('tell', 'write'): {'cell': 1.0},
#              ('write', 'cell'): {'repli': 1.0},
#              ('cell', 'repli'): {'result': 1.0},
#              ('repli', 'result'): {'excel': 1.0},
#              ('result', 'excel'): {'tabl': 1.0},
#              ('excel', 'tabl'): {'text': 1.0},
#              ('tabl', 'text'): {'noth': 0.5, 'first': 0.5},
#              ('text', 'noth'): {'els': 1.0},
#              ('explan', 'write'): {'formula': 1.0},
#              ('write', 'formula'): {'execut': 1.0},
#              ('formula', 'execut'): {'formula': 1.0},
#              ('execut', 'formula'): {'repli': 1.0},
#              ('formula', 'repli'): {'result': 1.0},
#              ('text', 'first'): {'repli': 0.5, 'request': 0.5},
#              ('first', 'repli'): {'empti': 1.0},
#              ('repli', 'empti'): {'sheet': 1.0},
#              ('empti', 'sheet'): {'want': 1.0},
#              ('sheet', 'want'): {'act': 1.0},
#              ('english', 'pronunci'): {'assist': 0.6666666666666666,
#               'helper': 0.3333333333333333},
#              ('pronunci', 'assist'): {'turkish': 1.0},
#              ('assist', 'turkish'): {'speak': 1.0},
#              ('turkish', 'speak'): {'peopl': 1.0},
#              ('speak', 'peopl'): {'write': 1.0},
#              ('peopl', 'write'): {'sentenc': 1.0},
#              ('write', 'sentenc'): {'answer': 0.4,
#               'repli': 0.2,
#               'express': 0.4},
#              ('sentenc', 'answer'): {'pronunci': 1.0},
#              ('answer', 'pronunci'): {'noth': 1.0},
#              ('pronunci', 'noth'): {'els': 1.0},
#              ('els', 'repli'): {'must': 0.6666666666666666,
#               'ye': 0.3333333333333333},
#              ('repli', 'must'): {'translat': 1.0},
#              ('must', 'translat'): {'sentenc': 1.0},
#              ('translat', 'sentenc'): {'pronunci': 0.5, 'wrote': 0.5},
#              ('sentenc', 'pronunci'): {'pronunci': 1.0},
#              ('pronunci', 'pronunci'): {'use': 1.0},
#              ('pronunci', 'use'): {'turkish': 1.0},
#              ('use', 'turkish'): {'latin': 1.0},
#              ('turkish', 'latin'): {'letter': 1.0},
#              ('latin', 'letter'): {'phonet': 1.0},
#              ('letter', 'phonet'): {'write': 1.0},
#              ('phonet', 'write'): {'explan': 1.0},
#              ('explan', 'repli'): {'first': 0.5,
#               'ok': 0.25,
#               'advic': 0.125,
#               'seo': 0.125},
#              ('repli', 'first'): {'sentenc': 1.0},
#              ('sentenc', 'weather'): {'istanbul': 1.0},
#              ('weather', 'istanbul'): {'want': 0.5, 'adapt': 0.5},
#              ('istanbul', 'want'): {'act': 1.0},
#              ('act', 'spoken'): {'english': 1.0},
#              ('spoken', 'english'): {'teacher': 0.5, 'want': 0.5},
#              ('english', 'teacher'): {'improv': 1.0},
#              ('teacher', 'improv'): {'speak': 1.0},
#              ('speak', 'english'): {'repli': 0.5, 'translat': 0.5},
#              ('english', 'repli'): {'english': 0.5, 'curli': 0.5},
#              ('repli', 'english'): {'practic': 1.0},
#              ('english', 'practic'): {'spoken': 1.0},
#              ('practic', 'spoken'): {'english': 1.0},
#              ('want', 'keep'): {'repli': 1.0},
#              ('keep', 'repli'): {'neat': 1.0},
#              ('repli', 'neat'): {'limit': 1.0},
#              ('neat', 'limit'): {'repli': 1.0},
#              ('limit', 'repli'): {'100': 1.0},
#              ('repli', '100'): {'word': 1.0},
#              ('100', 'word'): {'want': 0.5, 'clear': 0.5},
#              ('word', 'want'): {'strictli': 0.5, 'act': 0.5},
#              ('want', 'strictli'): {'correct': 1.0},
#              ('strictli', 'correct'): {'grammar': 1.0},
#              ('correct', 'grammar'): {'mistak': 1.0},
#              ('grammar', 'mistak'): {'typo': 1.0},
#              ('mistak', 'typo'): {'factual': 1.0},
#              ('typo', 'factual'): {'error': 1.0},
#              ('factual', 'error'): {'want': 1.0},
#              ('error', 'want'): {'ask': 0.5, 'act': 0.5},
#              ('want', 'ask'): {'question': 1.0},
#              ('question', 'repli'): {'let': 0.25,
#               'answer': 0.25,
#               'buddha': 0.25,
#               'ye': 0.25},
#              ('repli', 'let'): {'start': 1.0},
#              ('let', 'start'): {'practic': 1.0},
#              ('start', 'practic'): {'could': 1.0},
#              ('practic', 'could'): {'ask': 1.0},
#              ('could', 'ask'): {'question': 1.0},
#              ('question', 'first'): {'rememb': 1.0},
#              ('first', 'rememb'): {'want': 1.0},
#              ('rememb', 'want'): {'strictli': 1.0},
#              ('act', 'travel'): {'guid': 1.0},
#              ('travel', 'guid'): {'write': 0.5, 'provid': 0.5},
#              ('guid', 'write'): {'locat': 1.0},
#              ('write', 'locat'): {'suggest': 1.0},
#              ('locat', 'suggest'): {'place': 1.0},
#              ('suggest', 'place'): {'visit': 0.5, 'similar': 0.5},
#              ('place', 'visit'): {'near': 0.5, 'also': 0.5},
#              ('visit', 'near'): {'locat': 1.0},
#              ('near', 'locat'): {'case': 1.0},
#              ('locat', 'case'): {'also': 1.0},
#              ('case', 'also'): {'give': 1.0},
#              ('also', 'give'): {'type': 0.3333333333333333,
#               'list': 0.3333333333333333,
#               'name': 0.3333333333333333},
#              ('give', 'type'): {'place': 1.0},
#              ('type', 'place'): {'visit': 1.0},
#              ('visit', 'also'): {'suggest': 1.0},
#              ('also', 'suggest'): {'place': 0.25,
#               'music': 0.25,
#               'idea': 0.25,
#               'way': 0.25},
#              ('place', 'similar'): {'type': 1.0},
#              ('similar', 'type'): {'close': 1.0},
#              ('type', 'close'): {'first': 1.0},
#              ('close', 'first'): {'locat': 1.0},
#              ('first', 'locat'): {'first': 1.0},
#              ('locat', 'first'): {'suggest': 1.0},
#              ('first', 'suggest'): {'request': 1.0},
#              ('suggest', 'request'): {'istanbul': 0.03125,
#               'need': 0.78125,
#               'come': 0.0625,
#               'creat': 0.03125,
#               'review': 0.03125,
#               'shampoo': 0.03125,
#               'dataset': 0.03125},
#              ('request', 'istanbul'): {'beyoğlu': 1.0},
#              ('istanbul', 'beyoğlu'): {'want': 1.0},
#              ('beyoğlu', 'want'): {'visit': 1.0},
#              ('want', 'visit'): {'museum': 0.3333333333333333,
#               'suggest': 0.3333333333333333,
#               'renaiss': 0.3333333333333333},
#              ('visit', 'museum'): {'want': 1.0},
#              ('museum', 'want'): {'act': 1.0},
#              ('act', 'plagiar'): {'checker': 1.0},
#              ('plagiar', 'checker'): {'write': 1.0},
#              ('checker', 'write'): {'sentenc': 1.0},
#              ('sentenc', 'repli'): {'undetect': 1.0},
#              ('repli', 'undetect'): {'plagiar': 1.0},
#              ('undetect', 'plagiar'): {'check': 1.0},
#              ('plagiar', 'check'): {'languag': 1.0},
#              ('check', 'languag'): {'given': 1.0},
#              ('languag', 'given'): {'sentenc': 1.0},
#              ('given', 'sentenc'): {'noth': 1.0},
#              ('sentenc', 'noth'): {'els': 1.0},
#              ('sentenc', 'comput'): {'behav': 1.0},
#              ('comput', 'behav'): {'like': 1.0},
#              ('behav', 'like'): {'human': 1.0},
#              ('like', 'human'): {'speech': 1.0},
#              ('human', 'speech'): {'recognit': 1.0},
#              ('speech', 'recognit'): {'system': 1.0},
#              ('recognit', 'system'): {'must': 1.0},
#              ('system', 'must'): {'abl': 1.0},
#              ('must', 'abl'): {'process': 1.0},
#              ('abl', 'process'): {'nonverb': 1.0},
#              ('process', 'nonverb'): {'inform': 1.0},
#              ('nonverb', 'inform'): {'emot': 1.0},
#              ('inform', 'emot'): {'state': 1.0},
#              ('emot', 'state'): {'speaker': 1.0},
#              ('state', 'speaker'): {'want': 1.0},
#              ('speaker', 'want'): {'act': 1.0},
#              ('act', 'like'): {'charact': 0.2,
#               'python': 0.2,
#               'mathematician': 0.2,
#               'php': 0.2,
#               'linkedin': 0.2},
#              ('like', 'charact'): {'seri': 0.3333333333333333,
#               'use': 0.3333333333333333,
#               'must': 0.3333333333333333},
#              ('charact', 'seri'): {'want': 1.0},
#              ('seri', 'want'): {'respond': 1.0},
#              ('want', 'respond'): {'answer': 1.0},
#              ('respond', 'answer'): {'like': 1.0},
#              ('answer', 'like'): {'charact': 0.6666666666666666,
#               'drunk': 0.3333333333333333},
#              ('charact', 'use'): {'tone': 1.0},
#              ('use', 'tone'): {'manner': 1.0},
#              ('tone', 'manner'): {'vocabulari': 1.0},
#              ('manner', 'vocabulari'): {'charact': 1.0},
#              ('vocabulari', 'charact'): {'would': 1.0},
#              ('charact', 'would'): {'use': 1.0},
#              ('would', 'use'): {'write': 1.0},
#              ('use', 'write'): {'explan': 0.5, 'style': 0.5},
#              ('explan', 'answer'): {'like': 0.5, 'first': 0.5},
#              ('charact', 'must'): {'know': 1.0},
#              ('must', 'know'): {'knowledg': 1.0},
#              ('know', 'knowledg'): {'charact': 1.0},
#              ('knowledg', 'charact'): {'first': 1.0},
#              ('charact', 'first'): {'sentenc': 1.0},
#              ('hi', 'charact'): {'want': 1.0},
#              ('charact', 'want'): {'act': 1.0},
#              ('act', 'advertis'): {'creat': 1.0},
#              ('advertis', 'creat'): {'campaign': 1.0},
#              ('creat', 'campaign'): {'promot': 1.0},
#              ('campaign', 'promot'): {'product': 1.0},
#              ('promot', 'product'): {'servic': 1.0},
#              ('product', 'servic'): {'choic': 0.5, 'first': 0.5},
#              ('servic', 'choic'): {'choos': 1.0},
#              ('choic', 'choos'): {'target': 1.0},
#              ('choos', 'target'): {'audienc': 1.0},
#              ('target', 'audienc'): {'develop': 0.3333333333333333,
#               'may': 0.3333333333333333,
#               'industri': 0.3333333333333333},
#              ('audienc', 'develop'): {'key': 1.0},
#              ('develop', 'key'): {'messag': 1.0},
#              ('key', 'messag'): {'slogan': 1.0},
#              ('messag', 'slogan'): {'select': 1.0},
#              ('slogan', 'select'): {'media': 1.0},
#              ('select', 'media'): {'channel': 1.0},
#              ('media', 'channel'): {'promot': 1.0},
#              ('channel', 'promot'): {'decid': 1.0},
#              ('promot', 'decid'): {'addit': 1.0},
#              ('decid', 'addit'): {'activ': 1.0},
#              ('addit', 'activ'): {'need': 1.0},
#              ('activ', 'need'): {'reach': 1.0},
#              ('need', 'reach'): {'goal': 1.0},
#              ('reach', 'goal'): {'first': 1.0},
#              ('goal', 'first'): {'suggest': 0.5, 'request': 0.5},
#              ('request', 'need'): {'help': 0.8113207547169812,
#               'interest': 0.018867924528301886,
#               'write': 0.05660377358490566,
#               'poem': 0.018867924528301886,
#               'rap': 0.018867924528301886,
#               'speech': 0.018867924528301886,
#               'somebodi': 0.018867924528301886,
#               'someon': 0.018867924528301886,
#               'guidanc': 0.018867924528301886},
#              ('need', 'help'): {'creat': 0.17391304347826086,
#               'motiv': 0.021739130434782608,
#               'solv': 0.021739130434782608,
#               'understand': 0.043478260869565216,
#               'develop': 0.08695652173913043,
#               'improv': 0.043478260869565216,
#               'design': 0.06521739130434782,
#               'manag': 0.043478260869565216,
#               'find': 0.021739130434782608,
#               'organ': 0.021739130434782608,
#               'address': 0.021739130434782608,
#               'diagnos': 0.021739130434782608,
#               'stay': 0.021739130434782608,
#               'calcul': 0.021739130434782608,
#               'write': 0.06521739130434782,
#               'integr': 0.021739130434782608,
#               'review': 0.043478260869565216,
#               'explor': 0.021739130434782608,
#               'teach': 0.021739130434782608,
#               'deliv': 0.043478260869565216,
#               'facilit': 0.021739130434782608,
#               'uncov': 0.021739130434782608,
#               'provid': 0.021739130434782608,
#               'compos': 0.021739130434782608,
#               'coach': 0.021739130434782608,
#               'look': 0.021739130434782608,
#               'choos': 0.021739130434782608},
#              ('help', 'creat'): {'advertis': 0.125,
#               'e': 0.125,
#               'lunat': 0.125,
#               'outdoor': 0.125,
#               'engag': 0.125,
#               'impact': 0.125,
#               'rout': 0.125,
#               'age': 0.125},
#              ('creat', 'advertis'): {'campaign': 1.0},
#              ('advertis', 'campaign'): {'new': 1.0},
#              ('campaign', 'new'): {'type': 1.0},
#              ('new', 'type'): {'energi': 1.0},
#              ('type', 'energi'): {'drink': 1.0},
#              ('energi', 'drink'): {'target': 1.0},
#              ('drink', 'target'): {'young': 1.0},
#              ('target', 'young'): {'adult': 1.0},
#              ('young', 'adult'): {'age': 0.5, 'male': 0.5},
#              ('adult', 'age'): {'18': 1.0},
#              ('age', '18'): {'30': 0.5, '25': 0.5},
#              ('18', '30'): {'want': 1.0},
#              ('30', 'want'): {'act': 1.0},
#              ('act', 'storytel'): {'come': 1.0},
#              ('storytel', 'come'): {'entertain': 1.0},
#              ('come', 'entertain'): {'stori': 1.0},
#              ('entertain', 'stori'): {'engag': 1.0},
#              ('stori', 'engag'): {'imagin': 0.5, 'reader': 0.5},
#              ('engag', 'imagin'): {'captiv': 1.0},
#              ('imagin', 'captiv'): {'audienc': 1.0},
#              ('captiv', 'audienc'): {'fairi': 1.0},
#              ('audienc', 'fairi'): {'tale': 1.0},
#              ('fairi', 'tale'): {'educ': 1.0},
#              ('tale', 'educ'): {'stori': 1.0},
#              ('educ', 'stori'): {'type': 1.0},
#              ('stori', 'type'): {'stori': 1.0},
#              ('type', 'stori'): {'potenti': 1.0},
#              ('stori', 'potenti'): {'captur': 1.0},
#              ('potenti', 'captur'): {'peopl': 1.0},
#              ('captur', 'peopl'): {'attent': 1.0},
#              ('peopl', 'attent'): {'imagin': 1.0},
#              ('attent', 'imagin'): {'depend': 1.0},
#              ('imagin', 'depend'): {'target': 1.0},
#              ('depend', 'target'): {'audienc': 1.0},
#              ('audienc', 'may'): {'choos': 1.0},
#              ('may', 'choos'): {'specif': 0.5, 'genr': 0.5},
#              ('choos', 'specif'): {'theme': 1.0},
#              ('specif', 'theme'): {'topic': 1.0},
#              ('theme', 'topic'): {'storytel': 1.0},
#              ('topic', 'storytel'): {'session': 1.0},
#              ('storytel', 'session'): {'e': 1.0},
#              ('session', 'e'): {'g': 1.0},
#              ('e', 'g'): {'children': 1.0},
#              ('g', 'children'): {'talk': 1.0},
#              ('children', 'talk'): {'anim': 1.0},
#              ('talk', 'anim'): {'adult': 1.0},
#              ('anim', 'adult'): {'histori': 1.0},
#              ('adult', 'histori'): {'base': 1.0},
#              ('histori', 'base'): {'tale': 1.0},
#              ('base', 'tale'): {'might': 1.0},
#              ('tale', 'might'): {'engag': 1.0},
#              ('might', 'engag'): {'better': 1.0},
#              ('engag', 'better'): {'etc': 1.0},
#              ('better', 'etc'): {'first': 1.0},
#              ('etc', 'first'): {'request': 0.3333333333333333,
#               'inquiri': 0.3333333333333333,
#               'suggest': 0.3333333333333333},
#              ('first', 'request'): {'need': 0.4666666666666667,
#               'watch': 0.016666666666666666,
#               'want': 0.16666666666666666,
#               'written': 0.016666666666666666,
#               'aggress': 0.016666666666666666,
#               'someth': 0.016666666666666666,
#               'make': 0.016666666666666666,
#               'design': 0.016666666666666666,
#               'look': 0.016666666666666666,
#               'express': 0.016666666666666666,
#               'gaslight': 0.016666666666666666,
#               'budget': 0.016666666666666666,
#               'visit': 0.016666666666666666,
#               'experienc': 0.016666666666666666,
#               'vegetarian': 0.016666666666666666,
#               'involv': 0.016666666666666666,
#               'formal': 0.016666666666666666,
#               'give': 0.016666666666666666,
#               'toddler': 0.016666666666666666,
#               'creat': 0.016666666666666666,
#               'becom': 0.016666666666666666,
#               'work': 0.016666666666666666,
#               'question': 0.016666666666666666,
#               'experi': 0.016666666666666666},
#              ('need', 'interest'): {'stori': 1.0},
#              ('interest', 'stori'): {'persever': 1.0},
#              ('stori', 'persever'): {'want': 1.0},
#              ('persever', 'want'): {'act': 1.0},
#              ('act', 'footbal'): {'comment': 1.0},
#              ('footbal', 'comment'): {'give': 1.0},
#              ('comment', 'give'): {'descript': 1.0},
#              ('give', 'descript'): {'footbal': 0.5, 'dream': 0.5},
#              ('descript', 'footbal'): {'match': 1.0},
#              ('footbal', 'match'): {'progress': 1.0},
#              ('match', 'progress'): {'comment': 1.0},
#              ('progress', 'comment'): {'match': 1.0},
#              ('comment', 'match'): {'provid': 1.0},
#              ('match', 'provid'): {'analysi': 1.0},
#              ('provid', 'analysi'): {'happen': 1.0},
#              ('analysi', 'happen'): {'thu': 1.0},
#              ('happen', 'thu'): {'far': 1.0},
#              ('thu', 'far'): {'predict': 1.0},
#              ('far', 'predict'): {'game': 1.0},
#              ('predict', 'game'): {'may': 1.0},
#              ('game', 'may'): {'end': 1.0},
#              ('may', 'end'): {'knowledg': 1.0},
#              ('end', 'knowledg'): {'footbal': 1.0},
#              ('knowledg', 'footbal'): {'terminolog': 1.0},
#              ('footbal', 'terminolog'): {'tactic': 1.0},
#              ('terminolog', 'tactic'): {'player': 1.0},
#              ('tactic', 'player'): {'team': 1.0},
#              ('player', 'team'): {'involv': 1.0},
#              ('team', 'involv'): {'match': 1.0},
#              ('involv', 'match'): {'focu': 1.0},
#              ('match', 'focu'): {'primarili': 1.0},
#              ('focu', 'primarili'): {'provid': 1.0},
#              ('primarili', 'provid'): {'intellig': 1.0},
#              ('provid', 'intellig'): {'commentari': 1.0},
#              ('intellig', 'commentari'): {'rather': 1.0},
#              ('commentari', 'rather'): {'narrat': 1.0},
#              ('rather', 'narrat'): {'play': 1.0},
#              ('narrat', 'play'): {'play': 1.0},
#              ('play', 'play'): {'first': 1.0},
#              ('play', 'first'): {'request': 1.0},
#              ('request', 'watch'): {'manchest': 1.0},
#              ('watch', 'manchest'): {'unit': 1.0},
#              ('manchest', 'unit'): {'vs': 1.0},
#              ('unit', 'vs'): {'chelsea': 1.0},
#              ('vs', 'chelsea'): {'provid': 1.0},
#              ('chelsea', 'provid'): {'commentari': 1.0},
#              ('provid', 'commentari'): {'match': 1.0},
#              ('commentari', 'match'): {'want': 1.0},
#              ('match', 'want'): {'act': 1.0},
#              ('act', 'stand'): {'comedian': 1.0},
#              ('stand', 'comedian'): {'provid': 1.0},
#              ('comedian', 'provid'): {'topic': 1.0},
#              ('provid', 'topic'): {'relat': 0.6, 'question': 0.2, 'key': 0.2},
#              ('topic', 'relat'): {'current': 0.6666666666666666,
#               'studi': 0.3333333333333333},
#              ('relat', 'current'): {'event': 1.0},
#              ('current', 'event'): {'use': 0.5, 'task': 0.5},
#              ('event', 'use'): {'wit': 1.0},
#              ('use', 'wit'): {'creativ': 1.0},
#              ('wit', 'creativ'): {'observ': 1.0},
#              ('creativ', 'observ'): {'skill': 1.0},
#              ('observ', 'skill'): {'creat': 1.0},
#              ('skill', 'creat'): {'routin': 1.0},
#              ('creat', 'routin'): {'base': 1.0},
#              ('routin', 'base'): {'topic': 1.0},
#              ('base', 'topic'): {'also': 1.0},
#              ('topic', 'also'): {'sure': 1.0},
#              ('also', 'sure'): {'incorpor': 1.0},
#              ('sure', 'incorpor'): {'person': 1.0},
#              ('incorpor', 'person'): {'anecdot': 1.0},
#              ('person', 'anecdot'): {'experi': 1.0},
#              ('anecdot', 'experi'): {'routin': 1.0},
#              ('experi', 'routin'): {'order': 1.0},
#              ('routin', 'order'): {'make': 1.0},
#              ('order', 'make'): {'relat': 1.0},
#              ('make', 'relat'): {'engag': 1.0},
#              ('relat', 'engag'): {'audienc': 1.0},
#              ('engag', 'audienc'): {'first': 0.5, 'respond': 0.5},
#              ('audienc', 'first'): {'request': 0.5, 'suggest': 0.5},
#              ('request', 'want'): {'humor': 0.1,
#               'opinion': 0.1,
#               'team': 0.1,
#               'trace': 0.1,
#               'write': 0.1,
#               'make': 0.1,
#               'advis': 0.1,
#               'system': 0.1,
#               'visit': 0.1,
#               'fork': 0.1},
#              ('want', 'humor'): {'take': 1.0},
#              ('humor', 'take'): {'polit': 1.0},
#              ('take', 'polit'): {'want': 1.0},
#              ('polit', 'want'): {'act': 1.0},
#              ('act', 'motiv'): {'coach': 0.5, 'speaker': 0.5},
#              ('motiv', 'coach'): {'provid': 1.0},
#              ('coach', 'provid'): {'inform': 0.2, 'team': 0.2, 'detail': 0.6},
#              ('provid', 'inform'): {'someon': 0.125,
#               'job': 0.125,
#               'mean': 0.125,
#               'need': 0.25,
#               'task': 0.125,
#               'histor': 0.125,
#               'solv': 0.125},
#              ('inform', 'someon'): {'goal': 1.0},
#              ('someon', 'goal'): {'challeng': 1.0},
#              ('goal', 'challeng'): {'job': 1.0},
#              ('challeng', 'job'): {'come': 1.0},
#              ('job', 'come'): {'strategi': 0.5,
#               'suggest': 0.125,
#               'creativ': 0.125,
#               'way': 0.125,
#               'architectur': 0.125},
#              ('come', 'strategi'): {'help': 0.5,
#               'protect': 0.16666666666666666,
#               'sourc': 0.16666666666666666,
#               'mitig': 0.16666666666666666},
#              ('strategi', 'help'): {'person': 0.3333333333333333,
#               'make': 0.3333333333333333,
#               'pet': 0.3333333333333333},
#              ('help', 'person'): {'achiev': 1.0},
#              ('person', 'achiev'): {'goal': 1.0},
#              ('achiev', 'goal'): {'could': 1.0},
#              ('goal', 'could'): {'involv': 1.0},
#              ('could', 'involv'): {'provid': 0.2,
#               'conduct': 0.2,
#               'creat': 0.2,
#               'offer': 0.2,
#               'analyz': 0.2},
#              ('involv', 'provid'): {'posit': 1.0},
#              ('provid', 'posit'): {'affirm': 0.5, 'neg': 0.5},
#              ('posit', 'affirm'): {'give': 1.0},
#              ('affirm', 'give'): {'help': 1.0},
#              ('give', 'help'): {'advic': 1.0},
#              ('help', 'advic'): {'suggest': 1.0},
#              ('advic', 'suggest'): {'activ': 1.0},
#              ('suggest', 'activ'): {'reach': 1.0},
#              ('activ', 'reach'): {'end': 1.0},
#              ('reach', 'end'): {'goal': 1.0},
#              ('end', 'goal'): {'first': 1.0},
#              ('help', 'motiv'): {'stay': 1.0},
#              ('motiv', 'stay'): {'disciplin': 1.0},
#              ('stay', 'disciplin'): {'studi': 1.0},
#              ('disciplin', 'studi'): {'upcom': 1.0},
#              ('studi', 'upcom'): {'exam': 1.0},
#              ('upcom', 'exam'): {'want': 1.0},
#              ('exam', 'want'): {'act': 1.0},
#              ('act', 'compos'): {'provid': 1.0},
# ...
#              ('success', 'organ'): {'practic': 1.0},
#              ('organ', 'practic'): {'round': 1.0},
#              ('practic', 'round'): {'focu': 1.0},
#              ('round', 'focu'): {'persuas': 1.0},
#              ('focu', 'persuas'): {'speech': 1.0},
#              ('persuas', 'speech'): {'effect': 1.0},
#              ('speech', 'effect'): {'time': 1.0},
#              ('effect', 'time'): {'strategi': 1.0},
#              ('time', 'strategi'): {'refut': 1.0},
#              ('strategi', 'refut'): {'oppos': 1.0},
#              ('oppos', 'argument'): {'draw': 1.0},
#              ('argument', 'draw'): {'depth': 1.0},
#              ('draw', 'depth'): {'conclus': 1.0},
#              ('depth', 'conclus'): {'evid': 1.0},
#              ('conclus', 'evid'): {'provid': 1.0},
#              ('evid', 'provid'): {'first': 1.0},
#              ('provid', 'first'): {'request': 1.0},
#              ('want', 'team'): {'prepar': 1.0},
#              ('team', 'prepar'): {'upcom': 1.0},
#              ('prepar', 'upcom'): {'debat': 1.0},
#              ('debat', 'whether'): {'front': 1.0},
#              ('whether', 'front'): {'end': 1.0},
#              ('front', 'end'): {'develop': 1.0},
#              ('end', 'develop'): {'easi': 0.5, 'give': 0.5},
#              ('develop', 'easi'): {'want': 1.0},
#              ('easi', 'want'): {'act': 1.0},
#              ('act', 'screenwrit'): {'develop': 1.0},
#              ('screenwrit', 'develop'): {'engag': 1.0},
#              ('develop', 'engag'): {'creativ': 1.0},
#              ('engag', 'creativ'): {'script': 0.5, 'movi': 0.5},
#              ('creativ', 'script'): {'either': 1.0},
#              ('script', 'either'): {'featur': 1.0},
#              ('either', 'featur'): {'length': 1.0},
#              ('featur', 'length'): {'film': 1.0},
#              ('length', 'film'): {'web': 1.0},
#              ('film', 'web'): {'seri': 1.0},
#              ('web', 'seri'): {'captiv': 1.0},
#              ('seri', 'captiv'): {'viewer': 1.0},
#              ('captiv', 'viewer'): {'start': 1.0},
#              ('viewer', 'start'): {'come': 1.0},
#              ('start', 'come'): {'interest': 1.0},
#              ('come', 'interest'): {'charact': 1.0},
#              ('interest', 'charact'): {'set': 1.0},
#              ('charact', 'set'): {'stori': 1.0},
#              ('set', 'stori'): {'dialogu': 1.0},
#              ('stori', 'dialogu'): {'charact': 1.0},
#              ('dialogu', 'charact'): {'etc': 1.0},
#              ('charact', 'etc'): {'charact': 1.0},
#              ('etc', 'charact'): {'develop': 1.0},
#              ('charact', 'develop'): {'complet': 1.0},
#              ('develop', 'complet'): {'creat': 1.0},
#              ('complet', 'creat'): {'excit': 1.0},
#              ('creat', 'excit'): {'storylin': 1.0},
#              ('excit', 'storylin'): {'fill': 1.0},
#              ('storylin', 'fill'): {'twist': 1.0},
#              ('fill', 'twist'): {'turn': 1.0},
#              ('twist', 'turn'): {'keep': 1.0},
#              ('turn', 'keep'): {'viewer': 1.0},
#              ('keep', 'viewer'): {'suspens': 1.0},
#              ('viewer', 'suspens'): {'end': 1.0},
#              ('suspens', 'end'): {'first': 1.0},
#              ('end', 'first'): {'request': 0.5, 'suggest': 0.5},
#              ('need', 'write'): {'romant': 0.25,
#               'scienc': 0.25,
#               'movi': 0.25,
#               'detail': 0.25},
#              ('write', 'romant'): {'drama': 1.0},
#              ('romant', 'drama'): {'movi': 1.0},
#              ('drama', 'movi'): {'set': 1.0},
#              ('movi', 'set'): {'pari': 1.0},
#              ('set', 'pari'): {'want': 1.0},
#              ('pari', 'want'): {'act': 1.0},
#              ('act', 'novelist'): {'come': 1.0},
#              ('novelist', 'come'): {'creativ': 1.0},
#              ('come', 'creativ'): {'captiv': 0.25,
#               'way': 0.5,
#               'treatment': 0.25},
#              ('creativ', 'captiv'): {'stori': 1.0},
#              ('captiv', 'stori'): {'engag': 1.0},
#              ('engag', 'reader'): {'long': 1.0},
#              ('reader', 'long'): {'period': 1.0},
#              ('long', 'period'): {'time': 1.0},
#              ('period', 'time'): {'may': 1.0},
#              ('time', 'may'): {'choos': 1.0},
#              ('choos', 'genr'): {'fantasi': 1.0},
#              ('genr', 'fantasi'): {'romanc': 1.0},
#              ('fantasi', 'romanc'): {'histor': 1.0},
#              ('romanc', 'histor'): {'fiction': 1.0},
#              ('histor', 'fiction'): {'aim': 1.0},
#              ('fiction', 'aim'): {'write': 1.0},
#              ('aim', 'write'): {'someth': 1.0},
#              ('write', 'someth'): {'outstand': 1.0},
#              ('someth', 'outstand'): {'plotlin': 1.0},
#              ('outstand', 'plotlin'): {'engag': 1.0},
#              ('plotlin', 'engag'): {'charact': 1.0},
#              ('engag', 'charact'): {'unexpect': 1.0},
#              ('charact', 'unexpect'): {'climax': 1.0},
#              ('unexpect', 'climax'): {'first': 1.0},
#              ('climax', 'first'): {'request': 1.0},
#              ('write', 'scienc'): {'fiction': 1.0},
#              ('scienc', 'fiction'): {'novel': 1.0},
#              ('fiction', 'novel'): {'set': 1.0},
#              ('novel', 'set'): {'futur': 1.0},
#              ('set', 'futur'): {'want': 1.0},
#              ('futur', 'want'): {'act': 1.0},
#              ('act', 'movi'): {'critic': 1.0},
#              ('movi', 'critic'): {'develop': 1.0},
#              ('critic', 'develop'): {'engag': 1.0},
#              ('creativ', 'movi'): {'review': 1.0},
#              ('movi', 'review'): {'cover': 0.3333333333333333,
#               'movi': 0.3333333333333333,
#               'articul': 0.3333333333333333},
#              ('review', 'cover'): {'topic': 1.0},
#              ('cover', 'topic'): {'like': 1.0},
#              ('topic', 'like'): {'plot': 1.0},
#              ('like', 'plot'): {'theme': 1.0},
#              ('plot', 'theme'): {'tone': 1.0},
#              ('theme', 'tone'): {'act': 1.0},
#              ('tone', 'act'): {'charact': 1.0},
#              ('act', 'charact'): {'direct': 1.0},
#              ('charact', 'direct'): {'score': 1.0},
#              ('direct', 'score'): {'cinematographi': 1.0},
#              ('score', 'cinematographi'): {'product': 1.0},
#              ('cinematographi', 'product'): {'design': 1.0},
#              ('product', 'design'): {'special': 1.0},
#              ('design', 'special'): {'effect': 1.0},
#              ('special', 'effect'): {'edit': 1.0},
#              ('effect', 'edit'): {'pace': 1.0},
#              ('edit', 'pace'): {'dialog': 1.0},
#              ('pace', 'dialog'): {'import': 1.0},
#              ('dialog', 'import'): {'aspect': 1.0},
#              ('import', 'aspect'): {'though': 0.3333333333333333,
#               'ip': 0.3333333333333333,
#               'topic': 0.3333333333333333},
#              ('aspect', 'though'): {'emphas': 1.0},
#              ('though', 'emphas'): {'movi': 1.0},
#              ('emphas', 'movi'): {'made': 1.0},
#              ('movi', 'made'): {'feel': 1.0},
#              ('made', 'feel'): {'realli': 1.0},
#              ('feel', 'realli'): {'reson': 1.0},
#              ('realli', 'reson'): {'also': 1.0},
#              ('reson', 'also'): {'critic': 1.0},
#              ('also', 'critic'): {'movi': 1.0},
#              ('critic', 'movi'): {'pleas': 1.0},
#              ('movi', 'pleas'): {'avoid': 1.0},
#              ('pleas', 'avoid'): {'spoiler': 1.0},
#              ('avoid', 'spoiler'): {'first': 1.0},
#              ('spoiler', 'first'): {'request': 1.0},
#              ('write', 'movi'): {'review': 1.0},
#              ('review', 'movi'): {'interstellar': 1.0},
#              ('movi', 'interstellar'): {'want': 1.0},
#              ('interstellar', 'want'): {'act': 1.0},
#              ('act', 'relationship'): {'coach': 1.0},
#              ('relationship', 'coach'): {'provid': 1.0},
#              ('provid', 'detail'): {'two': 0.05555555555555555,
#               'design': 0.05555555555555555,
#               'current': 0.05555555555555555,
#               'individu': 0.1111111111111111,
#               'upcom': 0.05555555555555555,
#               'relat': 0.1111111111111111,
#               'patient': 0.05555555555555555,
#               'function': 0.05555555555555555,
#               'updat': 0.05555555555555555,
#               'creativ': 0.05555555555555555,
#               'note': 0.1111111111111111,
#               'profession': 0.05555555555555555,
#               'proof': 0.05555555555555555,
#               'respons': 0.05555555555555555,
#               'summari': 0.05555555555555555},
#              ('detail', 'two'): {'peopl': 1.0},
#              ('two', 'peopl'): {'involv': 1.0},
#              ('peopl', 'involv'): {'conflict': 1.0},
#              ('involv', 'conflict'): {'job': 1.0},
#              ('conflict', 'job'): {'come': 1.0},
#              ('come', 'suggest'): {'work': 1.0},
#              ('suggest', 'work'): {'issu': 1.0},
#              ('work', 'issu'): {'separ': 1.0},
#              ('issu', 'separ'): {'could': 1.0},
#              ('separ', 'could'): {'includ': 1.0},
#              ('includ', 'advic'): {'commun': 1.0},
#              ('advic', 'commun'): {'techniqu': 1.0},
#              ('commun', 'techniqu'): {'differ': 0.5, 'bring': 0.5},
#              ('techniqu', 'differ'): {'strategi': 1.0},
#              ('differ', 'strategi'): {'improv': 1.0},
#              ('strategi', 'improv'): {'understand': 1.0},
#              ('improv', 'understand'): {'one': 1.0},
#              ('understand', 'one'): {'anoth': 1.0},
#              ('one', 'anoth'): {'perspect': 1.0},
#              ('anoth', 'perspect'): {'first': 1.0},
#              ('perspect', 'first'): {'request': 1.0},
#              ('help', 'solv'): {'conflict': 1.0},
#              ('solv', 'conflict'): {'spous': 1.0},
#              ('conflict', 'spous'): {'want': 1.0},
#              ('spous', 'want'): {'act': 1.0},
#              ('act', 'poet'): {'creat': 1.0},
#              ('poet', 'creat'): {'poem': 1.0},
#              ('creat', 'poem'): {'evok': 1.0},
#              ('poem', 'evok'): {'emot': 1.0},
#              ('evok', 'emot'): {'power': 1.0},
#              ('emot', 'power'): {'stir': 1.0},
#              ('power', 'stir'): {'peopl': 1.0},
#              ('stir', 'peopl'): {'soul': 1.0},
#              ('peopl', 'soul'): {'write': 1.0},
#              ('soul', 'write'): {'topic': 1.0},
#              ('write', 'topic'): {'theme': 1.0},
#              ('topic', 'theme'): {'make': 1.0},
#              ('theme', 'make'): {'sure': 1.0},
#              ('sure', 'word'): {'convey': 1.0},
#              ('word', 'convey'): {'feel': 1.0},
#              ('convey', 'feel'): {'tri': 1.0},
#              ('feel', 'tri'): {'express': 1.0},
#              ('tri', 'express'): {'beauti': 1.0},
#              ('express', 'beauti'): {'yet': 1.0},
#              ('beauti', 'yet'): {'meaning': 1.0},
#              ('yet', 'meaning'): {'way': 1.0},
#              ('meaning', 'way'): {'also': 1.0},
#              ('way', 'also'): {'come': 1.0},
#              ('also', 'come'): {'short': 1.0},
#              ('come', 'short'): {'vers': 1.0},
#              ('short', 'vers'): {'still': 1.0},
#              ('vers', 'still'): {'power': 1.0},
#              ('still', 'power'): {'enough': 1.0},
#              ('power', 'enough'): {'leav': 1.0},
#              ('enough', 'leav'): {'imprint': 1.0},
#              ('leav', 'imprint'): {'reader': 1.0},
#              ('imprint', 'reader'): {'mind': 1.0},
#              ('reader', 'mind'): {'first': 1.0},
#              ('mind', 'first'): {'request': 1.0},
#              ('need', 'poem'): {'love': 1.0},
#              ('poem', 'love'): {'want': 1.0},
#              ('love', 'want'): {'act': 1.0},
#              ('act', 'rapper'): {'come': 1.0},
#              ('rapper', 'come'): {'power': 1.0},
#              ('come', 'power'): {'meaning': 1.0},
#              ('power', 'meaning'): {'lyric': 1.0},
#              ('meaning', 'lyric'): {'beat': 1.0},
#              ('lyric', 'beat'): {'rhythm': 1.0},
#              ('beat', 'rhythm'): {'wow': 1.0},
#              ('rhythm', 'wow'): {'audienc': 1.0},
#              ('wow', 'audienc'): {'lyric': 1.0},
#              ('audienc', 'lyric'): {'intrigu': 1.0},
#              ('lyric', 'intrigu'): {'mean': 1.0},
#              ('intrigu', 'mean'): {'messag': 1.0},
#              ('mean', 'messag'): {'peopl': 1.0},
#              ('messag', 'peopl'): {'relat': 1.0},
#              ('peopl', 'relat'): {'come': 1.0},
#              ('relat', 'come'): {'choos': 1.0},
#              ('come', 'choos'): {'beat': 1.0},
#              ('choos', 'beat'): {'make': 1.0},
#              ('beat', 'make'): {'sure': 1.0},
#              ('sure', 'catchi'): {'yet': 1.0},
#              ('catchi', 'yet'): {'relev': 1.0},
#              ('yet', 'relev'): {'word': 1.0},
#              ('relev', 'word'): {'combin': 1.0},
#              ('word', 'combin'): {'make': 1.0},
#              ('combin', 'make'): {'explos': 1.0},
#              ('make', 'explos'): {'sound': 1.0},
#              ('explos', 'sound'): {'everytim': 1.0},
#              ('sound', 'everytim'): {'first': 1.0},
#              ('everytim', 'first'): {'request': 1.0},
#              ('need', 'rap'): {'song': 1.0},
#              ('rap', 'song'): {'find': 1.0},
#              ('song', 'find'): {'strength': 1.0},
#              ('find', 'strength'): {'within': 1.0},
#              ('strength', 'within'): {'want': 1.0},
#              ('within', 'want'): {'act': 1.0},
#              ('motiv', 'speaker'): {'put': 1.0},
#              ('speaker', 'put'): {'togeth': 1.0},
#              ('put', 'togeth'): {'word': 1.0},
#              ('togeth', 'word'): {'inspir': 1.0},
#              ('word', 'inspir'): {'action': 1.0},
#              ('inspir', 'action'): {'make': 1.0},
#              ('action', 'make'): {'peopl': 1.0},
#              ('make', 'peopl'): {'feel': 0.5, 'reflect': 0.5},
#              ('peopl', 'feel'): {'empow': 1.0},
#              ('feel', 'empow'): {'someth': 1.0},
#              ('empow', 'someth'): {'beyond': 1.0},
#              ('someth', 'beyond'): {'abil': 1.0},
#              ('beyond', 'abil'): {'talk': 1.0},
#              ('abil', 'talk'): {'topic': 1.0},
#              ('talk', 'topic'): {'aim': 1.0},
#              ('topic', 'aim'): {'make': 1.0},
#              ('aim', 'make'): {'sure': 1.0},
#              ('sure', 'say'): {'reson': 1.0},
#              ('say', 'reson'): {'audienc': 1.0},
#              ('reson', 'audienc'): {'give': 1.0},
#              ('audienc', 'give'): {'incent': 1.0},
#              ('give', 'incent'): {'work': 1.0},
#              ('incent', 'work'): {'goal': 1.0},
#              ('work', 'goal'): {'strive': 1.0},
#              ('goal', 'strive'): {'better': 1.0},
#              ('strive', 'better'): {'possibl': 1.0},
#              ('better', 'possibl'): {'first': 1.0},
#              ('possibl', 'first'): {'request': 1.0},
#              ('need', 'speech'): {'everyon': 1.0},
#              ('speech', 'everyon'): {'never': 1.0},
#              ('everyon', 'never'): {'give': 1.0},
#              ('never', 'give'): {'want': 1.0},
#              ('give', 'want'): {'act': 1.0},
#              ('act', 'philosophi'): {'teacher': 1.0},
#              ('philosophi', 'teacher'): {'provid': 1.0},
#              ('teacher', 'provid'): {'topic': 0.3333333333333333,
#               'mathemat': 0.3333333333333333,
#               'inform': 0.3333333333333333},
#              ('relat', 'studi'): {'philosophi': 1.0},
#              ('studi', 'philosophi'): {'job': 1.0},
#              ('philosophi', 'job'): {'explain': 0.5, 'explor': 0.5},
#              ('job', 'explain'): {'concept': 0.3333333333333333,
#               'easi': 0.6666666666666666},
#              ('explain', 'concept'): {'easi': 0.5, 'term': 0.5},
#              ('concept', 'easi'): {'understand': 1.0},
#              ('easi', 'understand'): {'manner': 0.25,
#               'term': 0.5,
#               'addit': 0.25},
#              ('understand', 'manner'): {'could': 1.0},
#              ('manner', 'could'): {'includ': 1.0},
#              ('includ', 'provid'): {'exampl': 0.5, 'step': 0.5},
#              ('provid', 'exampl'): {'pose': 1.0},
#              ('exampl', 'pose'): {'question': 1.0},
#              ('pose', 'question'): {'break': 1.0},
#              ('question', 'break'): {'complex': 1.0},
#              ...})

# %% [markdown]
# 4. Apresentação de cada prefixo com as suas possíveis palavras.

# %%
for prefix, continuacoes in language_model.items():
    print(f"Prefixo: {prefix}")
    for word, probability in continuacoes.items():
        print(f"  -> {word}: {probability:.2f}")
# Out:
# Prefixo: ('imagin', 'experienc')
#   -> ethereum: 1.00
# Prefixo: ('experienc', 'ethereum')
#   -> develop: 1.00
# Prefixo: ('ethereum', 'develop')
#   -> task: 1.00
# Prefixo: ('develop', 'task')
#   -> creat: 1.00
# Prefixo: ('task', 'creat')
#   -> smart: 0.50
#   -> worksheet: 0.50
# Prefixo: ('creat', 'smart')
#   -> contract: 1.00
# Prefixo: ('smart', 'contract')
#   -> blockchain: 0.50
#   -> purpos: 0.50
# Prefixo: ('contract', 'blockchain')
#   -> messeng: 1.00
# Prefixo: ('blockchain', 'messeng')
#   -> object: 1.00
# Prefixo: ('messeng', 'object')
#   -> save: 1.00
# Prefixo: ('object', 'save')
#   -> messag: 1.00
# Prefixo: ('save', 'messag')
#   -> blockchain: 1.00
# Prefixo: ('messag', 'blockchain')
#   -> make: 1.00
# Prefixo: ('blockchain', 'make')
#   -> readabl: 1.00
# Prefixo: ('make', 'readabl')
#   -> public: 1.00
# Prefixo: ('readabl', 'public')
#   -> everyon: 1.00
# Prefixo: ('public', 'everyon')
#   -> writabl: 1.00
# Prefixo: ('everyon', 'writabl')
#   -> privat: 1.00
# Prefixo: ('writabl', 'privat')
#   -> person: 1.00
# Prefixo: ('privat', 'person')
#   -> deploy: 1.00
# Prefixo: ('person', 'deploy')
#   -> contract: 1.00
# Prefixo: ('deploy', 'contract')
#   -> count: 1.00
# Prefixo: ('contract', 'count')
#   -> mani: 1.00
# Prefixo: ('count', 'mani')
#   -> time: 1.00
# Prefixo: ('mani', 'time')
#   -> messag: 1.00
# Prefixo: ('time', 'messag')
#   -> updat: 1.00
# Prefixo: ('messag', 'updat')
#   -> develop: 1.00
# Prefixo: ('updat', 'develop')
#   -> solid: 1.00
# Prefixo: ('develop', 'solid')
#   -> smart: 1.00
# Prefixo: ('solid', 'smart')
#   -> contract: 1.00
# Prefixo: ('contract', 'purpos')
#   -> includ: 1.00
# Prefixo: ('purpos', 'includ')
#   -> necessari: 1.00
# Prefixo: ('includ', 'necessari')
#   -> function: 1.00
# Prefixo: ('necessari', 'function')
#   -> consider: 1.00
# Prefixo: ('function', 'consider')
#   -> achiev: 1.00
# Prefixo: ('consider', 'achiev')
#   -> specifi: 1.00
# Prefixo: ('achiev', 'specifi')
#   -> goal: 1.00
# Prefixo: ('specifi', 'goal')
#   -> pleas: 1.00
# Prefixo: ('goal', 'pleas')
#   -> provid: 1.00
# Prefixo: ('pleas', 'provid')
#   -> code: 0.25
#   -> suggest: 0.25
#   -> list: 0.25
#   -> least: 0.25
# Prefixo: ('provid', 'code')
#   -> relev: 0.33
#   -> exampl: 0.33
#   -> problem: 0.33
# Prefixo: ('code', 'relev')
#   -> explan: 1.00
# Prefixo: ('relev', 'explan')
#   -> ensur: 1.00
# Prefixo: ('explan', 'ensur')
#   -> clear: 1.00
# Prefixo: ('ensur', 'clear')
#   -> understand: 1.00
# Prefixo: ('clear', 'understand')
#   -> implement: 0.50
#   -> explan: 0.50
# Prefixo: ('understand', 'implement')
#   -> use: 1.00
# Prefixo: ('implement', 'use')
#   -> webpilot: 1.00
# Prefixo: ('use', 'webpilot')
#   -> creat: 1.00
# Prefixo: ('webpilot', 'creat')
#   -> outlin: 1.00
# Prefixo: ('creat', 'outlin')
#   -> articl: 1.00
# Prefixo: ('outlin', 'articl')
#   -> 2: 1.00
# Prefixo: ('articl', '2')
#   -> 000: 1.00
# Prefixo: ('2', '000')
#   -> word: 1.00
# Prefixo: ('000', 'word')
#   -> keyword: 0.50
#   -> articl: 0.50
# Prefixo: ('word', 'keyword')
#   -> best: 1.00
# Prefixo: ('keyword', 'best')
#   -> seo: 1.00
# Prefixo: ('best', 'seo')
#   -> prompt: 1.00
# Prefixo: ('seo', 'prompt')
#   -> base: 0.50
#   -> want: 0.50
# Prefixo: ('prompt', 'base')
#   -> top: 0.50
#   -> content: 0.50
# Prefixo: ('base', 'top')
#   -> 10: 1.00
# Prefixo: ('top', '10')
#   -> result: 0.50
#   -> product: 0.50
# Prefixo: ('10', 'result')
#   -> googl: 1.00
# Prefixo: ('result', 'googl')
#   -> includ: 1.00
# Prefixo: ('googl', 'includ')
#   -> everi: 1.00
# Prefixo: ('includ', 'everi')
#   -> relev: 1.00
# Prefixo: ('everi', 'relev')
#   -> head: 1.00
# Prefixo: ('relev', 'head')
#   -> possibl: 1.00
# Prefixo: ('head', 'possibl')
#   -> keep: 1.00
# Prefixo: ('possibl', 'keep')
#   -> keyword: 1.00
# Prefixo: ('keep', 'keyword')
#   -> densiti: 1.00
# Prefixo: ('keyword', 'densiti')
#   -> head: 1.00
# Prefixo: ('densiti', 'head')
#   -> high: 1.00
# Prefixo: ('head', 'high')
#   -> section: 1.00
# Prefixo: ('high', 'section')
#   -> outlin: 1.00
# Prefixo: ('section', 'outlin')
#   -> includ: 0.50
#   -> base: 0.50
# Prefixo: ('outlin', 'includ')
#   -> word: 1.00
# Prefixo: ('includ', 'word')
#   -> count: 0.50
#   -> relat: 0.50
# Prefixo: ('word', 'count')
#   -> includ: 1.00
# Prefixo: ('count', 'includ')
#   -> faq: 1.00
# Prefixo: ('includ', 'faq')
#   -> section: 1.00
# Prefixo: ('faq', 'section')
#   -> outlin: 1.00
# Prefixo: ('outlin', 'base')
#   -> peopl: 1.00
# Prefixo: ('base', 'peopl')
#   -> also: 1.00
# Prefixo: ('peopl', 'also')
#   -> ask: 1.00
# Prefixo: ('also', 'ask')
#   -> section: 1.00
# Prefixo: ('ask', 'section')
#   -> googl: 1.00
# Prefixo: ('section', 'googl')
#   -> keyword: 1.00
# Prefixo: ('googl', 'keyword')
#   -> outlin: 1.00
# Prefixo: ('keyword', 'outlin')
#   -> must: 1.00
# Prefixo: ('outlin', 'must')
#   -> detail: 1.00
# Prefixo: ('must', 'detail')
#   -> comprehens: 1.00
# Prefixo: ('detail', 'comprehens')
#   -> creat: 1.00
# Prefixo: ('comprehens', 'creat')
#   -> 2: 1.00
# Prefixo: ('creat', '2')
#   -> 000: 1.00
# Prefixo: ('word', 'articl')
#   -> gener: 1.00
# Prefixo: ('articl', 'gener')
#   -> long: 0.50
#   -> five: 0.50
# Prefixo: ('gener', 'long')
#   -> list: 1.00
# Prefixo: ('long', 'list')
#   -> lsi: 1.00
# Prefixo: ('list', 'lsi')
#   -> nlp: 1.00
# Prefixo: ('lsi', 'nlp')
#   -> keyword: 1.00
# Prefixo: ('nlp', 'keyword')
#   -> relat: 1.00
# Prefixo: ('keyword', 'relat')
#   -> keyword: 1.00
# Prefixo: ('relat', 'keyword')
#   -> also: 0.50
#   -> give: 0.50
# Prefixo: ('keyword', 'also')
#   -> includ: 1.00
# Prefixo: ('also', 'includ')
#   -> word: 1.00
# Prefixo: ('word', 'relat')
#   -> keyword: 1.00
# Prefixo: ('keyword', 'give')
#   -> list: 1.00
# Prefixo: ('give', 'list')
#   -> 3: 0.50
#   -> action: 0.50
# Prefixo: ('list', '3')
#   -> relev: 1.00
# Prefixo: ('3', 'relev')
#   -> extern: 1.00
# Prefixo: ('relev', 'extern')
#   -> link: 1.00
# Prefixo: ('extern', 'link')
#   -> includ: 1.00
# Prefixo: ('link', 'includ')
#   -> recommend: 1.00
# Prefixo: ('includ', 'recommend')
#   -> anchor: 1.00
# Prefixo: ('recommend', 'anchor')
#   -> text: 1.00
# Prefixo: ('anchor', 'text')
#   -> make: 1.00
# Prefixo: ('text', 'make')
#   -> sure: 1.00
# Prefixo: ('make', 'sure')
#   -> compet: 0.14
#   -> word: 0.14
#   -> catchi: 0.14
#   -> say: 0.14
#   -> need: 0.14
#   -> progress: 0.14
#   -> beginn: 0.14
# Prefixo: ('sure', 'compet')
#   -> articl: 1.00
# Prefixo: ('compet', 'articl')
#   -> split: 1.00
# Prefixo: ('articl', 'split')
#   -> outlin: 1.00
# Prefixo: ('split', 'outlin')
#   -> part: 1.00
# Prefixo: ('outlin', 'part')
#   -> 1: 1.00
# Prefixo: ('part', '1')
#   -> part: 1.00
# Prefixo: ('1', 'part')
#   -> 2: 1.00
# Prefixo: ('part', '2')
#   -> want: 1.00
# Prefixo: ('2', 'want')
#   -> act: 1.00
# Prefixo: ('want', 'act')
#   -> linux: 0.01
#   -> english: 0.02
#   -> interview: 0.01
#   -> javascript: 0.01
#   -> text: 0.02
#   -> spoken: 0.01
#   -> travel: 0.01
#   -> plagiar: 0.01
#   -> like: 0.03
#   -> advertis: 0.01
#   -> storytel: 0.01
#   -> footbal: 0.01
#   -> stand: 0.01
#   -> motiv: 0.01
#   -> compos: 0.01
#   -> debat: 0.01
#   -> screenwrit: 0.01
#   -> novelist: 0.01
#   -> movi: 0.01
#   -> relationship: 0.01
#   -> poet: 0.01
#   -> rapper: 0.01
#   -> philosophi: 0.01
#   -> philosoph: 0.01
#   -> math: 0.01
#   -> ai: 0.01
#   -> ux: 0.01
#   -> cyber: 0.01
#   -> recruit: 0.01
#   -> life: 0.01
#   -> etymologist: 0.01
#   -> commentariat: 0.01
#   -> magician: 0.01
#   -> career: 0.01
#   -> pet: 0.01
#   -> person: 0.03
#   -> mental: 0.01
#   -> real: 0.01
#   -> logistician: 0.01
#   -> dentist: 0.01
#   -> web: 0.01
#   -> doctor: 0.01
#   -> account: 0.01
#   -> artist: 0.01
#   -> interior: 0.01
#   -> self: 0.01
#   -> gnomist: 0.01
#   -> aphor: 0.01
#   -> fanci: 0.01
#   -> statistician: 0.01
#   -> prompt: 0.01
#   -> instructor: 0.01
#   -> sql: 0.01
#   -> psychologist: 0.01
#   -> smart: 0.01
#   -> tech: 0.01
#   -> develop: 0.01
#   -> academician: 0.01
#   -> architect: 0.01
#   -> lunat: 0.01
#   -> gaslight: 0.01
#   -> fallaci: 0.01
#   -> journal: 0.01
#   -> diy: 0.01
#   -> social: 0.01
#   -> socrat: 0.01
#   -> educ: 0.01
#   -> yogi: 0.01
#   -> essay: 0.01
#   -> elocutionist: 0.01
#   -> scientif: 0.01
#   -> car: 0.01
#   -> hypnotherapist: 0.01
#   -> historian: 0.01
#   -> astrolog: 0.01
#   -> film: 0.01
#   -> classic: 0.01
#   -> journalist: 0.01
#   -> digit: 0.01
#   -> public: 0.01
#   -> makeup: 0.01
#   -> babysitt: 0.01
#   -> ascii: 0.01
#   -> synonym: 0.01
#   -> food: 0.01
#   -> virtual: 0.01
#   -> legal: 0.01
#   -> machin: 0.01
#   -> biblic: 0.01
#   -> expert: 0.02
#   -> rival: 0.01
#   -> softwar: 0.01
#   -> regex: 0.01
#   -> time: 0.01
#   -> dream: 0.01
#   -> talent: 0.01
#   -> r: 0.01
#   -> stackoverflow: 0.01
#   -> first: 0.01
#   -> fill: 0.01
#   -> tic: 0.01
#   -> password: 0.01
#   -> senior: 0.01
#   -> solr: 0.01
#   -> spongebob: 0.01
#   -> languag: 0.01
#   -> salesperson: 0.01
#   -> commit: 0.01
#   -> chief: 0.01
#   -> graphviz: 0.01
#   -> speech: 0.01
#   -> titl: 0.01
#   -> drunk: 0.01
#   -> mathemat: 0.01
#   -> song: 0.01
#   -> technolog: 0.01
#   -> proofread: 0.01
#   -> buddha: 0.01
#   -> chemic: 0.01
#   -> friend: 0.01
#   -> chatgpt: 0.01
#   -> guess: 0.01
#   -> wikipedia: 0.01
#   -> japanes: 0.01
#   -> note: 0.01
#   -> data: 0.01
#   -> restaur: 0.01
#   -> empathet: 0.01
#   -> acoust: 0.01
#   -> knowledg: 0.01
#   -> logic: 0.01
#   -> teacher: 0.01
#   -> git: 0.01
#   -> program: 0.01
#   -> dax: 0.01
#   -> children: 0.01
#   -> book: 0.01
#   -> advanc: 0.01
#   -> seo: 0.01
# Prefixo: ('act', 'linux')
#   -> termin: 1.00
# Prefixo: ('linux', 'termin')
#   -> type: 0.50
#   -> want: 0.50
# Prefixo: ('termin', 'type')
#   -> command: 1.00
# Prefixo: ('type', 'command')
#   -> repli: 0.42
#   -> unless: 0.50
#   -> ai: 0.08
# Prefixo: ('command', 'repli')
#   -> termin: 0.60
#   -> javascript: 0.20
#   -> descript: 0.20
# Prefixo: ('repli', 'termin')
#   -> show: 0.25
#   -> output: 0.50
#   -> would: 0.25
# Prefixo: ('termin', 'show')
#   -> want: 1.00
# Prefixo: ('show', 'want')
#   -> repli: 1.00
# Prefixo: ('want', 'repli')
#   -> termin: 0.22
#   -> correct: 0.11
#   -> interview: 0.06
#   -> game: 0.06
#   -> tabl: 0.06
#   -> solut: 0.06
#   -> given: 0.06
#   -> anyth: 0.11
#   -> map: 0.06
#   -> answer: 0.11
#   -> dax: 0.06
#   -> question: 0.06
# Prefixo: ('termin', 'output')
#   -> insid: 1.00
# Prefixo: ('output', 'insid')
#   -> one: 1.00
# Prefixo: ('insid', 'one')
#   -> uniqu: 1.00
# Prefixo: ('one', 'uniqu')
#   -> code: 1.00
# Prefixo: ('uniqu', 'code')
#   -> block: 1.00
# Prefixo: ('code', 'block')
#   -> noth: 0.64
#   -> delimit: 0.09
#   -> write: 0.09
#   -> send: 0.09
#   -> per: 0.09
# Prefixo: ('block', 'noth')
#   -> els: 1.00
# Prefixo: ('noth', 'els')
#   -> write: 0.68
#   -> repli: 0.07
#   -> domain: 0.04
#   -> word: 0.04
#   -> enter: 0.04
#   -> level: 0.04
#   -> alway: 0.04
#   -> appropri: 0.04
#   -> structur: 0.04
# Prefixo: ('els', 'write')
#   -> explan: 1.00
# Prefixo: ('write', 'explan')
#   -> type: 0.15
#   -> first: 0.32
#   -> ask: 0.02
#   -> write: 0.02
#   -> repli: 0.17
#   -> answer: 0.02
#   -> ever: 0.02
#   -> need: 0.05
#   -> exampl: 0.05
#   -> simpli: 0.02
#   -> enough: 0.02
#   -> link: 0.02
#   -> word: 0.07
#   -> provid: 0.02
# Prefixo: ('explan', 'type')
#   -> command: 1.00
# Prefixo: ('command', 'unless')
#   -> instruct: 1.00
# Prefixo: ('unless', 'instruct')
#   -> need: 1.00
# Prefixo: ('instruct', 'need')
#   -> tell: 0.86
#   -> provid: 0.14
# Prefixo: ('need', 'tell')
#   -> someth: 1.00
# Prefixo: ('tell', 'someth')
#   -> english: 1.00
# Prefixo: ('someth', 'english')
#   -> put: 0.64
#   -> repli: 0.09
#   -> curli: 0.09
#   -> wrap: 0.18
# Prefixo: ('english', 'put')
#   -> text: 1.00
# Prefixo: ('put', 'text')
#   -> insid: 1.00
# Prefixo: ('text', 'insid')
#   -> curli: 0.86
#   -> squar: 0.14
# Prefixo: ('insid', 'curli')
#   -> bracket: 1.00
# Prefixo: ('curli', 'bracket')
#   -> like: 1.00
# Prefixo: ('bracket', 'like')
#   -> first: 0.78
#   -> like: 0.22
# Prefixo: ('like', 'first')
#   -> command: 0.60
#   -> express: 0.10
#   -> question: 0.10
#   -> sentenc: 0.20
# Prefixo: ('first', 'command')
#   -> pwd: 0.10
#   -> consol: 0.10
#   -> wake: 0.10
#   -> want: 0.10
#   -> select: 0.10
#   -> sampl: 0.10
#   -> php: 0.10
#   -> add: 0.10
#   -> print: 0.10
#   -> give: 0.10
# Prefixo: ('command', 'pwd')
#   -> want: 1.00
# Prefixo: ('pwd', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'english')
#   -> translat: 0.25
#   -> pronunci: 0.75
# Prefixo: ('english', 'translat')
#   -> spell: 0.50
#   -> answer: 0.50
# Prefixo: ('translat', 'spell')
#   -> corrector: 1.00
# Prefixo: ('spell', 'corrector')
#   -> improv: 1.00
# Prefixo: ('corrector', 'improv')
#   -> speak: 1.00
# Prefixo: ('improv', 'speak')
#   -> languag: 0.50
#   -> english: 0.50
# Prefixo: ('speak', 'languag')
#   -> detect: 1.00
# Prefixo: ('languag', 'detect')
#   -> languag: 1.00
# Prefixo: ('detect', 'languag')
#   -> translat: 1.00
# Prefixo: ('languag', 'translat')
#   -> answer: 1.00
# Prefixo: ('translat', 'answer')
#   -> correct: 1.00
# Prefixo: ('answer', 'correct')
#   -> improv: 1.00
# Prefixo: ('correct', 'improv')
#   -> version: 0.50
#   -> noth: 0.50
# Prefixo: ('improv', 'version')
#   -> text: 1.00
# Prefixo: ('version', 'text')
#   -> english: 0.50
#   -> biblic: 0.50
# Prefixo: ('text', 'english')
#   -> want: 1.00
# Prefixo: ('english', 'want')
#   -> replac: 0.50
#   -> keep: 0.50
# Prefixo: ('want', 'replac')
#   -> simplifi: 1.00
# Prefixo: ('replac', 'simplifi')
#   -> a0: 1.00
# Prefixo: ('simplifi', 'a0')
#   -> level: 1.00
# Prefixo: ('a0', 'level')
#   -> word: 1.00
# Prefixo: ('level', 'word')
#   -> sentenc: 1.00
# Prefixo: ('word', 'sentenc')
#   -> beauti: 0.40
#   -> keep: 0.40
#   -> contain: 0.20
# Prefixo: ('sentenc', 'beauti')
#   -> eleg: 1.00
# Prefixo: ('beauti', 'eleg')
#   -> upper: 0.50
#   -> biblic: 0.50
# Prefixo: ('eleg', 'upper')
#   -> level: 1.00
# Prefixo: ('upper', 'level')
#   -> english: 1.00
# Prefixo: ('level', 'english')
#   -> word: 0.50
#   -> profici: 0.50
# Prefixo: ('english', 'word')
#   -> sentenc: 1.00
# Prefixo: ('sentenc', 'keep')
#   -> mean: 1.00
# Prefixo: ('keep', 'mean')
#   -> make: 0.50
#   -> want: 0.50
# Prefixo: ('mean', 'make')
#   -> literari: 1.00
# Prefixo: ('make', 'literari')
#   -> want: 1.00
# Prefixo: ('literari', 'want')
#   -> repli: 1.00
# Prefixo: ('repli', 'correct')
#   -> improv: 1.00
# Prefixo: ('improv', 'noth')
#   -> els: 1.00
# Prefixo: ('explan', 'first')
#   -> sentenc: 0.15
#   -> request: 0.62
#   -> problem: 0.08
#   -> messag: 0.15
# Prefixo: ('first', 'sentenc')
#   -> istanbulu: 0.09
#   -> hi: 0.18
#   -> weather: 0.18
#   -> comput: 0.09
#   -> hello: 0.27
#   -> kiel: 0.09
#   -> want: 0.09
# Prefixo: ('sentenc', 'istanbulu')
#   -> cok: 1.00
# Prefixo: ('istanbulu', 'cok')
#   -> seviyom: 1.00
# Prefixo: ('cok', 'seviyom')
#   -> burada: 1.00
# Prefixo: ('seviyom', 'burada')
#   -> olmak: 1.00
# Prefixo: ('burada', 'olmak')
#   -> cok: 1.00
# Prefixo: ('olmak', 'cok')
#   -> guzel: 1.00
# Prefixo: ('cok', 'guzel')
#   -> want: 1.00
# Prefixo: ('guzel', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'interview')
#   -> candid: 1.00
# Prefixo: ('interview', 'candid')
#   -> ask: 1.00
# Prefixo: ('candid', 'ask')
#   -> interview: 1.00
# Prefixo: ('ask', 'interview')
#   -> question: 1.00
# Prefixo: ('interview', 'question')
#   -> posit: 1.00
# Prefixo: ('question', 'posit')
#   -> posit: 1.00
# Prefixo: ('posit', 'posit')
#   -> want: 1.00
# Prefixo: ('posit', 'want')
#   -> repli: 1.00
# Prefixo: ('repli', 'interview')
#   -> write: 1.00
# Prefixo: ('interview', 'write')
#   -> convers: 1.00
# Prefixo: ('write', 'convers')
#   -> want: 1.00
# Prefixo: ('convers', 'want')
#   -> interview: 1.00
# Prefixo: ('want', 'interview')
#   -> ask: 1.00
# Prefixo: ('interview', 'ask')
#   -> question: 1.00
# Prefixo: ('ask', 'question')
#   -> wait: 0.10
#   -> one: 0.10
#   -> repli: 0.20
#   -> first: 0.10
#   -> improv: 0.10
#   -> answer: 0.10
#   -> leagu: 0.10
#   -> relat: 0.10
#   -> describ: 0.10
# Prefixo: ('question', 'wait')
#   -> answer: 1.00
# Prefixo: ('wait', 'answer')
#   -> write: 0.50
#   -> first: 0.50
# Prefixo: ('answer', 'write')
#   -> explan: 1.00
# Prefixo: ('explan', 'ask')
#   -> question: 1.00
# Prefixo: ('question', 'one')
#   -> one: 1.00
# Prefixo: ('one', 'one')
#   -> like: 1.00
# Prefixo: ('one', 'like')
#   -> interview: 1.00
# Prefixo: ('like', 'interview')
#   -> wait: 1.00
# Prefixo: ('interview', 'wait')
#   -> answer: 1.00
# Prefixo: ('answer', 'first')
#   -> sentenc: 0.33
#   -> job: 0.33
#   -> question: 0.33
# Prefixo: ('sentenc', 'hi')
#   -> want: 0.50
#   -> charact: 0.50
# Prefixo: ('hi', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'javascript')
#   -> consol: 1.00
# Prefixo: ('javascript', 'consol')
#   -> type: 0.50
#   -> show: 0.50
# Prefixo: ('consol', 'type')
#   -> command: 1.00
# Prefixo: ('repli', 'javascript')
#   -> consol: 1.00
# Prefixo: ('consol', 'show')
#   -> want: 1.00
# Prefixo: ('command', 'consol')
#   -> log: 1.00
# Prefixo: ('consol', 'log')
#   -> hello: 1.00
# Prefixo: ('log', 'hello')
#   -> world: 1.00
# Prefixo: ('hello', 'world')
#   -> want: 0.75
#   -> would: 0.25
# Prefixo: ('world', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'text')
#   -> base: 1.00
# Prefixo: ('text', 'base')
#   -> excel: 0.25
#   -> 10: 0.25
#   -> adventur: 0.25
#   -> web: 0.25
# Prefixo: ('base', 'excel')
#   -> repli: 1.00
# Prefixo: ('excel', 'repli')
#   -> text: 1.00
# Prefixo: ('repli', 'text')
#   -> base: 1.00
# Prefixo: ('base', '10')
#   -> row: 1.00
# Prefixo: ('10', 'row')
#   -> excel: 1.00
# Prefixo: ('row', 'excel')
#   -> sheet: 1.00
# Prefixo: ('excel', 'sheet')
#   -> row: 1.00
# Prefixo: ('sheet', 'row')
#   -> number: 1.00
# Prefixo: ('row', 'number')
#   -> cell: 0.50
#   -> tell: 0.50
# Prefixo: ('number', 'cell')
#   -> letter: 1.00
# Prefixo: ('cell', 'letter')
#   -> column: 1.00
# Prefixo: ('letter', 'column')
#   -> l: 1.00
# Prefixo: ('column', 'l')
#   -> first: 1.00
# Prefixo: ('l', 'first')
#   -> column: 1.00
# Prefixo: ('first', 'column')
#   -> header: 0.50
#   -> list: 0.50
# Prefixo: ('column', 'header')
#   -> empti: 1.00
# Prefixo: ('header', 'empti')
#   -> refer: 1.00
# Prefixo: ('empti', 'refer')
#   -> row: 1.00
# Prefixo: ('refer', 'row')
#   -> number: 1.00
# Prefixo: ('number', 'tell')
#   -> write: 1.00
# Prefixo: ('tell', 'write')
#   -> cell: 1.00
# Prefixo: ('write', 'cell')
#   -> repli: 1.00
# Prefixo: ('cell', 'repli')
#   -> result: 1.00
# Prefixo: ('repli', 'result')
#   -> excel: 1.00
# Prefixo: ('result', 'excel')
#   -> tabl: 1.00
# Prefixo: ('excel', 'tabl')
#   -> text: 1.00
# Prefixo: ('tabl', 'text')
#   -> noth: 0.50
#   -> first: 0.50
# Prefixo: ('text', 'noth')
#   -> els: 1.00
# Prefixo: ('explan', 'write')
#   -> formula: 1.00
# Prefixo: ('write', 'formula')
#   -> execut: 1.00
# Prefixo: ('formula', 'execut')
#   -> formula: 1.00
# Prefixo: ('execut', 'formula')
#   -> repli: 1.00
# Prefixo: ('formula', 'repli')
#   -> result: 1.00
# Prefixo: ('text', 'first')
#   -> repli: 0.50
#   -> request: 0.50
# Prefixo: ('first', 'repli')
#   -> empti: 1.00
# Prefixo: ('repli', 'empti')
#   -> sheet: 1.00
# Prefixo: ('empti', 'sheet')
#   -> want: 1.00
# Prefixo: ('sheet', 'want')
#   -> act: 1.00
# Prefixo: ('english', 'pronunci')
#   -> assist: 0.67
#   -> helper: 0.33
# Prefixo: ('pronunci', 'assist')
#   -> turkish: 1.00
# Prefixo: ('assist', 'turkish')
#   -> speak: 1.00
# Prefixo: ('turkish', 'speak')
#   -> peopl: 1.00
# Prefixo: ('speak', 'peopl')
#   -> write: 1.00
# Prefixo: ('peopl', 'write')
#   -> sentenc: 1.00
# Prefixo: ('write', 'sentenc')
#   -> answer: 0.40
#   -> repli: 0.20
#   -> express: 0.40
# Prefixo: ('sentenc', 'answer')
#   -> pronunci: 1.00
# Prefixo: ('answer', 'pronunci')
#   -> noth: 1.00
# Prefixo: ('pronunci', 'noth')
#   -> els: 1.00
# Prefixo: ('els', 'repli')
#   -> must: 0.67
#   -> ye: 0.33
# Prefixo: ('repli', 'must')
#   -> translat: 1.00
# Prefixo: ('must', 'translat')
#   -> sentenc: 1.00
# Prefixo: ('translat', 'sentenc')
#   -> pronunci: 0.50
#   -> wrote: 0.50
# Prefixo: ('sentenc', 'pronunci')
#   -> pronunci: 1.00
# Prefixo: ('pronunci', 'pronunci')
#   -> use: 1.00
# Prefixo: ('pronunci', 'use')
#   -> turkish: 1.00
# Prefixo: ('use', 'turkish')
#   -> latin: 1.00
# Prefixo: ('turkish', 'latin')
#   -> letter: 1.00
# Prefixo: ('latin', 'letter')
#   -> phonet: 1.00
# Prefixo: ('letter', 'phonet')
#   -> write: 1.00
# Prefixo: ('phonet', 'write')
#   -> explan: 1.00
# Prefixo: ('explan', 'repli')
#   -> first: 0.50
#   -> ok: 0.25
#   -> advic: 0.12
#   -> seo: 0.12
# Prefixo: ('repli', 'first')
#   -> sentenc: 1.00
# Prefixo: ('sentenc', 'weather')
#   -> istanbul: 1.00
# Prefixo: ('weather', 'istanbul')
#   -> want: 0.50
#   -> adapt: 0.50
# Prefixo: ('istanbul', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'spoken')
#   -> english: 1.00
# Prefixo: ('spoken', 'english')
#   -> teacher: 0.50
#   -> want: 0.50
# Prefixo: ('english', 'teacher')
#   -> improv: 1.00
# Prefixo: ('teacher', 'improv')
#   -> speak: 1.00
# Prefixo: ('speak', 'english')
#   -> repli: 0.50
#   -> translat: 0.50
# Prefixo: ('english', 'repli')
#   -> english: 0.50
#   -> curli: 0.50
# Prefixo: ('repli', 'english')
#   -> practic: 1.00
# Prefixo: ('english', 'practic')
#   -> spoken: 1.00
# Prefixo: ('practic', 'spoken')
#   -> english: 1.00
# Prefixo: ('want', 'keep')
#   -> repli: 1.00
# Prefixo: ('keep', 'repli')
#   -> neat: 1.00
# Prefixo: ('repli', 'neat')
#   -> limit: 1.00
# Prefixo: ('neat', 'limit')
#   -> repli: 1.00
# Prefixo: ('limit', 'repli')
#   -> 100: 1.00
# Prefixo: ('repli', '100')
#   -> word: 1.00
# Prefixo: ('100', 'word')
#   -> want: 0.50
#   -> clear: 0.50
# Prefixo: ('word', 'want')
#   -> strictli: 0.50
#   -> act: 0.50
# Prefixo: ('want', 'strictli')
#   -> correct: 1.00
# Prefixo: ('strictli', 'correct')
#   -> grammar: 1.00
# Prefixo: ('correct', 'grammar')
#   -> mistak: 1.00
# Prefixo: ('grammar', 'mistak')
#   -> typo: 1.00
# Prefixo: ('mistak', 'typo')
#   -> factual: 1.00
# Prefixo: ('typo', 'factual')
#   -> error: 1.00
# Prefixo: ('factual', 'error')
#   -> want: 1.00
# Prefixo: ('error', 'want')
#   -> ask: 0.50
#   -> act: 0.50
# Prefixo: ('want', 'ask')
#   -> question: 1.00
# Prefixo: ('question', 'repli')
#   -> let: 0.25
#   -> answer: 0.25
#   -> buddha: 0.25
#   -> ye: 0.25
# Prefixo: ('repli', 'let')
#   -> start: 1.00
# Prefixo: ('let', 'start')
#   -> practic: 1.00
# Prefixo: ('start', 'practic')
#   -> could: 1.00
# Prefixo: ('practic', 'could')
#   -> ask: 1.00
# Prefixo: ('could', 'ask')
#   -> question: 1.00
# Prefixo: ('question', 'first')
#   -> rememb: 1.00
# Prefixo: ('first', 'rememb')
#   -> want: 1.00
# Prefixo: ('rememb', 'want')
#   -> strictli: 1.00
# Prefixo: ('act', 'travel')
#   -> guid: 1.00
# Prefixo: ('travel', 'guid')
#   -> write: 0.50
#   -> provid: 0.50
# Prefixo: ('guid', 'write')
#   -> locat: 1.00
# Prefixo: ('write', 'locat')
#   -> suggest: 1.00
# Prefixo: ('locat', 'suggest')
#   -> place: 1.00
# Prefixo: ('suggest', 'place')
#   -> visit: 0.50
#   -> similar: 0.50
# Prefixo: ('place', 'visit')
#   -> near: 0.50
#   -> also: 0.50
# Prefixo: ('visit', 'near')
#   -> locat: 1.00
# Prefixo: ('near', 'locat')
#   -> case: 1.00
# Prefixo: ('locat', 'case')
#   -> also: 1.00
# Prefixo: ('case', 'also')
#   -> give: 1.00
# Prefixo: ('also', 'give')
#   -> type: 0.33
#   -> list: 0.33
#   -> name: 0.33
# Prefixo: ('give', 'type')
#   -> place: 1.00
# Prefixo: ('type', 'place')
#   -> visit: 1.00
# Prefixo: ('visit', 'also')
#   -> suggest: 1.00
# Prefixo: ('also', 'suggest')
#   -> place: 0.25
#   -> music: 0.25
#   -> idea: 0.25
#   -> way: 0.25
# Prefixo: ('place', 'similar')
#   -> type: 1.00
# Prefixo: ('similar', 'type')
#   -> close: 1.00
# Prefixo: ('type', 'close')
#   -> first: 1.00
# Prefixo: ('close', 'first')
#   -> locat: 1.00
# Prefixo: ('first', 'locat')
#   -> first: 1.00
# Prefixo: ('locat', 'first')
#   -> suggest: 1.00
# Prefixo: ('first', 'suggest')
#   -> request: 1.00
# Prefixo: ('suggest', 'request')
#   -> istanbul: 0.03
#   -> need: 0.78
#   -> come: 0.06
#   -> creat: 0.03
#   -> review: 0.03
#   -> shampoo: 0.03
#   -> dataset: 0.03
# Prefixo: ('request', 'istanbul')
#   -> beyoğlu: 1.00
# Prefixo: ('istanbul', 'beyoğlu')
#   -> want: 1.00
# Prefixo: ('beyoğlu', 'want')
#   -> visit: 1.00
# Prefixo: ('want', 'visit')
#   -> museum: 0.33
#   -> suggest: 0.33
#   -> renaiss: 0.33
# Prefixo: ('visit', 'museum')
#   -> want: 1.00
# Prefixo: ('museum', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'plagiar')
#   -> checker: 1.00
# Prefixo: ('plagiar', 'checker')
#   -> write: 1.00
# Prefixo: ('checker', 'write')
#   -> sentenc: 1.00
# Prefixo: ('sentenc', 'repli')
#   -> undetect: 1.00
# Prefixo: ('repli', 'undetect')
#   -> plagiar: 1.00
# Prefixo: ('undetect', 'plagiar')
#   -> check: 1.00
# Prefixo: ('plagiar', 'check')
#   -> languag: 1.00
# Prefixo: ('check', 'languag')
#   -> given: 1.00
# Prefixo: ('languag', 'given')
#   -> sentenc: 1.00
# Prefixo: ('given', 'sentenc')
#   -> noth: 1.00
# Prefixo: ('sentenc', 'noth')
#   -> els: 1.00
# Prefixo: ('sentenc', 'comput')
#   -> behav: 1.00
# Prefixo: ('comput', 'behav')
#   -> like: 1.00
# Prefixo: ('behav', 'like')
#   -> human: 1.00
# Prefixo: ('like', 'human')
#   -> speech: 1.00
# Prefixo: ('human', 'speech')
#   -> recognit: 1.00
# Prefixo: ('speech', 'recognit')
#   -> system: 1.00
# Prefixo: ('recognit', 'system')
#   -> must: 1.00
# Prefixo: ('system', 'must')
#   -> abl: 1.00
# Prefixo: ('must', 'abl')
#   -> process: 1.00
# Prefixo: ('abl', 'process')
#   -> nonverb: 1.00
# Prefixo: ('process', 'nonverb')
#   -> inform: 1.00
# Prefixo: ('nonverb', 'inform')
#   -> emot: 1.00
# Prefixo: ('inform', 'emot')
#   -> state: 1.00
# Prefixo: ('emot', 'state')
#   -> speaker: 1.00
# Prefixo: ('state', 'speaker')
#   -> want: 1.00
# Prefixo: ('speaker', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'like')
#   -> charact: 0.20
#   -> python: 0.20
#   -> mathematician: 0.20
#   -> php: 0.20
#   -> linkedin: 0.20
# Prefixo: ('like', 'charact')
#   -> seri: 0.33
#   -> use: 0.33
#   -> must: 0.33
# Prefixo: ('charact', 'seri')
#   -> want: 1.00
# Prefixo: ('seri', 'want')
#   -> respond: 1.00
# Prefixo: ('want', 'respond')
#   -> answer: 1.00
# Prefixo: ('respond', 'answer')
#   -> like: 1.00
# Prefixo: ('answer', 'like')
#   -> charact: 0.67
#   -> drunk: 0.33
# Prefixo: ('charact', 'use')
#   -> tone: 1.00
# Prefixo: ('use', 'tone')
#   -> manner: 1.00
# Prefixo: ('tone', 'manner')
#   -> vocabulari: 1.00
# Prefixo: ('manner', 'vocabulari')
#   -> charact: 1.00
# Prefixo: ('vocabulari', 'charact')
#   -> would: 1.00
# Prefixo: ('charact', 'would')
#   -> use: 1.00
# Prefixo: ('would', 'use')
#   -> write: 1.00
# Prefixo: ('use', 'write')
#   -> explan: 0.50
#   -> style: 0.50
# Prefixo: ('explan', 'answer')
#   -> like: 0.50
#   -> first: 0.50
# Prefixo: ('charact', 'must')
#   -> know: 1.00
# Prefixo: ('must', 'know')
#   -> knowledg: 1.00
# Prefixo: ('know', 'knowledg')
#   -> charact: 1.00
# Prefixo: ('knowledg', 'charact')
#   -> first: 1.00
# Prefixo: ('charact', 'first')
#   -> sentenc: 1.00
# Prefixo: ('hi', 'charact')
#   -> want: 1.00
# Prefixo: ('charact', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'advertis')
#   -> creat: 1.00
# Prefixo: ('advertis', 'creat')
#   -> campaign: 1.00
# Prefixo: ('creat', 'campaign')
#   -> promot: 1.00
# Prefixo: ('campaign', 'promot')
#   -> product: 1.00
# Prefixo: ('promot', 'product')
#   -> servic: 1.00
# Prefixo: ('product', 'servic')
#   -> choic: 0.50
#   -> first: 0.50
# Prefixo: ('servic', 'choic')
#   -> choos: 1.00
# Prefixo: ('choic', 'choos')
#   -> target: 1.00
# Prefixo: ('choos', 'target')
#   -> audienc: 1.00
# Prefixo: ('target', 'audienc')
#   -> develop: 0.33
#   -> may: 0.33
#   -> industri: 0.33
# Prefixo: ('audienc', 'develop')
#   -> key: 1.00
# Prefixo: ('develop', 'key')
#   -> messag: 1.00
# Prefixo: ('key', 'messag')
#   -> slogan: 1.00
# Prefixo: ('messag', 'slogan')
#   -> select: 1.00
# Prefixo: ('slogan', 'select')
#   -> media: 1.00
# Prefixo: ('select', 'media')
#   -> channel: 1.00
# Prefixo: ('media', 'channel')
#   -> promot: 1.00
# Prefixo: ('channel', 'promot')
#   -> decid: 1.00
# Prefixo: ('promot', 'decid')
#   -> addit: 1.00
# Prefixo: ('decid', 'addit')
#   -> activ: 1.00
# Prefixo: ('addit', 'activ')
#   -> need: 1.00
# Prefixo: ('activ', 'need')
#   -> reach: 1.00
# Prefixo: ('need', 'reach')
#   -> goal: 1.00
# Prefixo: ('reach', 'goal')
#   -> first: 1.00
# Prefixo: ('goal', 'first')
#   -> suggest: 0.50
#   -> request: 0.50
# Prefixo: ('request', 'need')
#   -> help: 0.81
#   -> interest: 0.02
#   -> write: 0.06
#   -> poem: 0.02
#   -> rap: 0.02
#   -> speech: 0.02
#   -> somebodi: 0.02
#   -> someon: 0.02
#   -> guidanc: 0.02
# Prefixo: ('need', 'help')
#   -> creat: 0.17
#   -> motiv: 0.02
#   -> solv: 0.02
#   -> understand: 0.04
#   -> develop: 0.09
#   -> improv: 0.04
#   -> design: 0.07
#   -> manag: 0.04
#   -> find: 0.02
#   -> organ: 0.02
#   -> address: 0.02
#   -> diagnos: 0.02
#   -> stay: 0.02
#   -> calcul: 0.02
#   -> write: 0.07
#   -> integr: 0.02
#   -> review: 0.04
#   -> explor: 0.02
#   -> teach: 0.02
#   -> deliv: 0.04
#   -> facilit: 0.02
#   -> uncov: 0.02
#   -> provid: 0.02
#   -> compos: 0.02
#   -> coach: 0.02
#   -> look: 0.02
#   -> choos: 0.02
# Prefixo: ('help', 'creat')
#   -> advertis: 0.12
#   -> e: 0.12
#   -> lunat: 0.12
#   -> outdoor: 0.12
#   -> engag: 0.12
#   -> impact: 0.12
#   -> rout: 0.12
#   -> age: 0.12
# Prefixo: ('creat', 'advertis')
#   -> campaign: 1.00
# Prefixo: ('advertis', 'campaign')
#   -> new: 1.00
# Prefixo: ('campaign', 'new')
#   -> type: 1.00
# Prefixo: ('new', 'type')
#   -> energi: 1.00
# Prefixo: ('type', 'energi')
#   -> drink: 1.00
# Prefixo: ('energi', 'drink')
#   -> target: 1.00
# Prefixo: ('drink', 'target')
#   -> young: 1.00
# Prefixo: ('target', 'young')
#   -> adult: 1.00
# Prefixo: ('young', 'adult')
#   -> age: 0.50
#   -> male: 0.50
# Prefixo: ('adult', 'age')
#   -> 18: 1.00
# Prefixo: ('age', '18')
#   -> 30: 0.50
#   -> 25: 0.50
# Prefixo: ('18', '30')
#   -> want: 1.00
# Prefixo: ('30', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'storytel')
#   -> come: 1.00
# Prefixo: ('storytel', 'come')
#   -> entertain: 1.00
# Prefixo: ('come', 'entertain')
#   -> stori: 1.00
# Prefixo: ('entertain', 'stori')
#   -> engag: 1.00
# Prefixo: ('stori', 'engag')
#   -> imagin: 0.50
#   -> reader: 0.50
# Prefixo: ('engag', 'imagin')
#   -> captiv: 1.00
# Prefixo: ('imagin', 'captiv')
#   -> audienc: 1.00
# Prefixo: ('captiv', 'audienc')
#   -> fairi: 1.00
# Prefixo: ('audienc', 'fairi')
#   -> tale: 1.00
# Prefixo: ('fairi', 'tale')
#   -> educ: 1.00
# Prefixo: ('tale', 'educ')
#   -> stori: 1.00
# Prefixo: ('educ', 'stori')
#   -> type: 1.00
# Prefixo: ('stori', 'type')
#   -> stori: 1.00
# Prefixo: ('type', 'stori')
#   -> potenti: 1.00
# Prefixo: ('stori', 'potenti')
#   -> captur: 1.00
# Prefixo: ('potenti', 'captur')
#   -> peopl: 1.00
# Prefixo: ('captur', 'peopl')
#   -> attent: 1.00
# Prefixo: ('peopl', 'attent')
#   -> imagin: 1.00
# Prefixo: ('attent', 'imagin')
#   -> depend: 1.00
# Prefixo: ('imagin', 'depend')
#   -> target: 1.00
# Prefixo: ('depend', 'target')
#   -> audienc: 1.00
# Prefixo: ('audienc', 'may')
#   -> choos: 1.00
# Prefixo: ('may', 'choos')
#   -> specif: 0.50
#   -> genr: 0.50
# Prefixo: ('choos', 'specif')
#   -> theme: 1.00
# Prefixo: ('specif', 'theme')
#   -> topic: 1.00
# Prefixo: ('theme', 'topic')
#   -> storytel: 1.00
# Prefixo: ('topic', 'storytel')
#   -> session: 1.00
# Prefixo: ('storytel', 'session')
#   -> e: 1.00
# Prefixo: ('session', 'e')
#   -> g: 1.00
# Prefixo: ('e', 'g')
#   -> children: 1.00
# Prefixo: ('g', 'children')
#   -> talk: 1.00
# Prefixo: ('children', 'talk')
#   -> anim: 1.00
# Prefixo: ('talk', 'anim')
#   -> adult: 1.00
# Prefixo: ('anim', 'adult')
#   -> histori: 1.00
# Prefixo: ('adult', 'histori')
#   -> base: 1.00
# Prefixo: ('histori', 'base')
#   -> tale: 1.00
# Prefixo: ('base', 'tale')
#   -> might: 1.00
# Prefixo: ('tale', 'might')
#   -> engag: 1.00
# Prefixo: ('might', 'engag')
#   -> better: 1.00
# Prefixo: ('engag', 'better')
#   -> etc: 1.00
# Prefixo: ('better', 'etc')
#   -> first: 1.00
# Prefixo: ('etc', 'first')
#   -> request: 0.33
#   -> inquiri: 0.33
#   -> suggest: 0.33
# Prefixo: ('first', 'request')
#   -> need: 0.47
#   -> watch: 0.02
#   -> want: 0.17
#   -> written: 0.02
#   -> aggress: 0.02
#   -> someth: 0.02
#   -> make: 0.02
#   -> design: 0.02
#   -> look: 0.02
#   -> express: 0.02
#   -> gaslight: 0.02
#   -> budget: 0.02
#   -> visit: 0.02
#   -> experienc: 0.02
#   -> vegetarian: 0.02
#   -> involv: 0.02
#   -> formal: 0.02
#   -> give: 0.02
#   -> toddler: 0.02
#   -> creat: 0.02
#   -> becom: 0.02
#   -> work: 0.02
#   -> question: 0.02
#   -> experi: 0.02
# Prefixo: ('need', 'interest')
#   -> stori: 1.00
# Prefixo: ('interest', 'stori')
#   -> persever: 1.00
# Prefixo: ('stori', 'persever')
#   -> want: 1.00
# Prefixo: ('persever', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'footbal')
#   -> comment: 1.00
# Prefixo: ('footbal', 'comment')
#   -> give: 1.00
# Prefixo: ('comment', 'give')
#   -> descript: 1.00
# Prefixo: ('give', 'descript')
#   -> footbal: 0.50
#   -> dream: 0.50
# Prefixo: ('descript', 'footbal')
#   -> match: 1.00
# Prefixo: ('footbal', 'match')
#   -> progress: 1.00
# Prefixo: ('match', 'progress')
#   -> comment: 1.00
# Prefixo: ('progress', 'comment')
#   -> match: 1.00
# Prefixo: ('comment', 'match')
#   -> provid: 1.00
# Prefixo: ('match', 'provid')
#   -> analysi: 1.00
# Prefixo: ('provid', 'analysi')
#   -> happen: 1.00
# Prefixo: ('analysi', 'happen')
#   -> thu: 1.00
# Prefixo: ('happen', 'thu')
#   -> far: 1.00
# Prefixo: ('thu', 'far')
#   -> predict: 1.00
# Prefixo: ('far', 'predict')
#   -> game: 1.00
# Prefixo: ('predict', 'game')
#   -> may: 1.00
# Prefixo: ('game', 'may')
#   -> end: 1.00
# Prefixo: ('may', 'end')
#   -> knowledg: 1.00
# Prefixo: ('end', 'knowledg')
#   -> footbal: 1.00
# Prefixo: ('knowledg', 'footbal')
#   -> terminolog: 1.00
# Prefixo: ('footbal', 'terminolog')
#   -> tactic: 1.00
# Prefixo: ('terminolog', 'tactic')
#   -> player: 1.00
# Prefixo: ('tactic', 'player')
#   -> team: 1.00
# Prefixo: ('player', 'team')
#   -> involv: 1.00
# Prefixo: ('team', 'involv')
#   -> match: 1.00
# Prefixo: ('involv', 'match')
#   -> focu: 1.00
# Prefixo: ('match', 'focu')
#   -> primarili: 1.00
# Prefixo: ('focu', 'primarili')
#   -> provid: 1.00
# Prefixo: ('primarili', 'provid')
#   -> intellig: 1.00
# Prefixo: ('provid', 'intellig')
#   -> commentari: 1.00
# Prefixo: ('intellig', 'commentari')
#   -> rather: 1.00
# Prefixo: ('commentari', 'rather')
#   -> narrat: 1.00
# Prefixo: ('rather', 'narrat')
#   -> play: 1.00
# Prefixo: ('narrat', 'play')
#   -> play: 1.00
# Prefixo: ('play', 'play')
#   -> first: 1.00
# Prefixo: ('play', 'first')
#   -> request: 1.00
# Prefixo: ('request', 'watch')
#   -> manchest: 1.00
# Prefixo: ('watch', 'manchest')
#   -> unit: 1.00
# Prefixo: ('manchest', 'unit')
#   -> vs: 1.00
# Prefixo: ('unit', 'vs')
#   -> chelsea: 1.00
# Prefixo: ('vs', 'chelsea')
#   -> provid: 1.00
# Prefixo: ('chelsea', 'provid')
#   -> commentari: 1.00
# Prefixo: ('provid', 'commentari')
#   -> match: 1.00
# Prefixo: ('commentari', 'match')
#   -> want: 1.00
# Prefixo: ('match', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'stand')
#   -> comedian: 1.00
# Prefixo: ('stand', 'comedian')
#   -> provid: 1.00
# Prefixo: ('comedian', 'provid')
#   -> topic: 1.00
# Prefixo: ('provid', 'topic')
#   -> relat: 0.60
#   -> question: 0.20
#   -> key: 0.20
# Prefixo: ('topic', 'relat')
#   -> current: 0.67
#   -> studi: 0.33
# Prefixo: ('relat', 'current')
#   -> event: 1.00
# Prefixo: ('current', 'event')
#   -> use: 0.50
#   -> task: 0.50
# Prefixo: ('event', 'use')
#   -> wit: 1.00
# Prefixo: ('use', 'wit')
#   -> creativ: 1.00
# Prefixo: ('wit', 'creativ')
#   -> observ: 1.00
# Prefixo: ('creativ', 'observ')
#   -> skill: 1.00
# Prefixo: ('observ', 'skill')
#   -> creat: 1.00
# Prefixo: ('skill', 'creat')
#   -> routin: 1.00
# Prefixo: ('creat', 'routin')
#   -> base: 1.00
# Prefixo: ('routin', 'base')
#   -> topic: 1.00
# Prefixo: ('base', 'topic')
#   -> also: 1.00
# Prefixo: ('topic', 'also')
#   -> sure: 1.00
# Prefixo: ('also', 'sure')
#   -> incorpor: 1.00
# Prefixo: ('sure', 'incorpor')
#   -> person: 1.00
# Prefixo: ('incorpor', 'person')
#   -> anecdot: 1.00
# Prefixo: ('person', 'anecdot')
#   -> experi: 1.00
# Prefixo: ('anecdot', 'experi')
#   -> routin: 1.00
# Prefixo: ('experi', 'routin')
#   -> order: 1.00
# Prefixo: ('routin', 'order')
#   -> make: 1.00
# Prefixo: ('order', 'make')
#   -> relat: 1.00
# Prefixo: ('make', 'relat')
#   -> engag: 1.00
# Prefixo: ('relat', 'engag')
#   -> audienc: 1.00
# Prefixo: ('engag', 'audienc')
#   -> first: 0.50
#   -> respond: 0.50
# Prefixo: ('audienc', 'first')
#   -> request: 0.50
#   -> suggest: 0.50
# Prefixo: ('request', 'want')
#   -> humor: 0.10
#   -> opinion: 0.10
#   -> team: 0.10
#   -> trace: 0.10
#   -> write: 0.10
#   -> make: 0.10
#   -> advis: 0.10
#   -> system: 0.10
#   -> visit: 0.10
#   -> fork: 0.10
# Prefixo: ('want', 'humor')
#   -> take: 1.00
# Prefixo: ('humor', 'take')
#   -> polit: 1.00
# Prefixo: ('take', 'polit')
#   -> want: 1.00
# Prefixo: ('polit', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'motiv')
#   -> coach: 0.50
#   -> speaker: 0.50
# Prefixo: ('motiv', 'coach')
#   -> provid: 1.00
# Prefixo: ('coach', 'provid')
#   -> inform: 0.20
#   -> team: 0.20
#   -> detail: 0.60
# Prefixo: ('provid', 'inform')
#   -> someon: 0.12
#   -> job: 0.12
#   -> mean: 0.12
#   -> need: 0.25
#   -> task: 0.12
#   -> histor: 0.12
#   -> solv: 0.12
# Prefixo: ('inform', 'someon')
#   -> goal: 1.00
# Prefixo: ('someon', 'goal')
#   -> challeng: 1.00
# Prefixo: ('goal', 'challeng')
#   -> job: 1.00
# Prefixo: ('challeng', 'job')
#   -> come: 1.00
# Prefixo: ('job', 'come')
#   -> strategi: 0.50
#   -> suggest: 0.12
#   -> creativ: 0.12
#   -> way: 0.12
#   -> architectur: 0.12
# Prefixo: ('come', 'strategi')
#   -> help: 0.50
#   -> protect: 0.17
#   -> sourc: 0.17
#   -> mitig: 0.17
# Prefixo: ('strategi', 'help')
#   -> person: 0.33
#   -> make: 0.33
#   -> pet: 0.33
# Prefixo: ('help', 'person')
#   -> achiev: 1.00
# Prefixo: ('person', 'achiev')
#   -> goal: 1.00
# Prefixo: ('achiev', 'goal')
#   -> could: 1.00
# Prefixo: ('goal', 'could')
#   -> involv: 1.00
# Prefixo: ('could', 'involv')
#   -> provid: 0.20
#   -> conduct: 0.20
#   -> creat: 0.20
#   -> offer: 0.20
#   -> analyz: 0.20
# Prefixo: ('involv', 'provid')
#   -> posit: 1.00
# Prefixo: ('provid', 'posit')
#   -> affirm: 0.50
#   -> neg: 0.50
# Prefixo: ('posit', 'affirm')
#   -> give: 1.00
# Prefixo: ('affirm', 'give')
#   -> help: 1.00
# Prefixo: ('give', 'help')
#   -> advic: 1.00
# Prefixo: ('help', 'advic')
#   -> suggest: 1.00
# Prefixo: ('advic', 'suggest')
#   -> activ: 1.00
# Prefixo: ('suggest', 'activ')
#   -> reach: 1.00
# Prefixo: ('activ', 'reach')
#   -> end: 1.00
# Prefixo: ('reach', 'end')
#   -> goal: 1.00
# Prefixo: ('end', 'goal')
#   -> first: 1.00
# Prefixo: ('help', 'motiv')
#   -> stay: 1.00
# Prefixo: ('motiv', 'stay')
#   -> disciplin: 1.00
# Prefixo: ('stay', 'disciplin')
#   -> studi: 1.00
# Prefixo: ('disciplin', 'studi')
#   -> upcom: 1.00
# Prefixo: ('studi', 'upcom')
#   -> exam: 1.00
# Prefixo: ('upcom', 'exam')
#   -> want: 1.00
# Prefixo: ('exam', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'compos')
#   -> provid: 1.00
# Prefixo: ('compos', 'provid')
#   -> lyric: 0.50
#   -> initi: 0.50
# Prefixo: ('provid', 'lyric')
#   -> song: 1.00
# Prefixo: ('lyric', 'song')
#   -> creat: 1.00
# Prefixo: ('song', 'creat')
#   -> music: 0.50
#   -> playlist: 0.50
# Prefixo: ('creat', 'music')
#   -> could: 1.00
# Prefixo: ('music', 'could')
#   -> includ: 1.00
# Prefixo: ('could', 'includ')
#   -> use: 0.17
#   -> advic: 0.17
#   -> provid: 0.33
#   -> suggest: 0.17
#   -> reach: 0.17
# Prefixo: ('includ', 'use')
#   -> variou: 1.00
# Prefixo: ('use', 'variou')
#   -> instrument: 1.00
# Prefixo: ('variou', 'instrument')
#   -> tool: 1.00
# Prefixo: ('instrument', 'tool')
#   -> synthes: 1.00
# Prefixo: ('tool', 'synthes')
#   -> sampler: 1.00
# Prefixo: ('synthes', 'sampler')
#   -> order: 1.00
# Prefixo: ('sampler', 'order')
#   -> creat: 1.00
# Prefixo: ('order', 'creat')
#   -> melodi: 0.33
#   -> plan: 0.33
#   -> strategi: 0.33
# Prefixo: ('creat', 'melodi')
#   -> harmoni: 1.00
# Prefixo: ('melodi', 'harmoni')
#   -> bring: 1.00
# Prefixo: ('harmoni', 'bring')
#   -> lyric: 1.00
# Prefixo: ('bring', 'lyric')
#   -> life: 1.00
# Prefixo: ('lyric', 'life')
#   -> first: 1.00
# Prefixo: ('life', 'first')
#   -> request: 1.00
# Prefixo: ('request', 'written')
#   -> poem: 1.00
# Prefixo: ('written', 'poem')
#   -> name: 1.00
# Prefixo: ('poem', 'name')
#   -> hayalet: 1.00
# Prefixo: ('name', 'hayalet')
#   -> sevgilim: 1.00
# Prefixo: ('hayalet', 'sevgilim')
#   -> need: 1.00
# Prefixo: ('sevgilim', 'need')
#   -> music: 1.00
# Prefixo: ('need', 'music')
#   -> go: 1.00
# Prefixo: ('music', 'go')
#   -> want: 1.00
# Prefixo: ('go', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'debat')
#   -> provid: 0.50
#   -> coach: 0.50
# Prefixo: ('debat', 'provid')
#   -> topic: 1.00
# Prefixo: ('event', 'task')
#   -> research: 1.00
# Prefixo: ('task', 'research')
#   -> side: 1.00
# Prefixo: ('research', 'side')
#   -> debat: 1.00
# Prefixo: ('side', 'debat')
#   -> present: 1.00
# Prefixo: ('debat', 'present')
#   -> valid: 1.00
# Prefixo: ('present', 'valid')
#   -> argument: 1.00
# Prefixo: ('valid', 'argument')
#   -> side: 1.00
# Prefixo: ('argument', 'side')
#   -> refut: 1.00
# Prefixo: ('side', 'refut')
#   -> oppos: 1.00
# Prefixo: ('refut', 'oppos')
#   -> point: 0.50
#   -> argument: 0.50
# Prefixo: ('oppos', 'point')
#   -> view: 1.00
# Prefixo: ('point', 'view')
#   -> draw: 1.00
# Prefixo: ('view', 'draw')
#   -> persuas: 1.00
# Prefixo: ('draw', 'persuas')
#   -> conclus: 1.00
# Prefixo: ('persuas', 'conclus')
#   -> base: 1.00
# Prefixo: ('conclus', 'base')
#   -> evid: 1.00
# Prefixo: ('base', 'evid')
#   -> goal: 1.00
# Prefixo: ('evid', 'goal')
#   -> help: 1.00
# Prefixo: ('goal', 'help')
#   -> peopl: 0.50
#   -> owner: 0.50
# Prefixo: ('help', 'peopl')
#   -> come: 1.00
# Prefixo: ('peopl', 'come')
#   -> away: 1.00
# Prefixo: ('come', 'away')
#   -> discuss: 1.00
# Prefixo: ('away', 'discuss')
#   -> increas: 1.00
# Prefixo: ('discuss', 'increas')
#   -> knowledg: 1.00
# Prefixo: ('increas', 'knowledg')
#   -> insight: 1.00
# Prefixo: ('knowledg', 'insight')
#   -> topic: 1.00
# Prefixo: ('insight', 'topic')
#   -> hand: 1.00
# Prefixo: ('topic', 'hand')
#   -> first: 0.50
#   -> use: 0.50
# Prefixo: ('hand', 'first')
#   -> request: 1.00
# Prefixo: ('want', 'opinion')
#   -> piec: 1.00
# Prefixo: ('opinion', 'piec')
#   -> deno: 0.25
#   -> provid: 0.25
#   -> climat: 0.25
#   -> develop: 0.25
# Prefixo: ('piec', 'deno')
#   -> want: 1.00
# Prefixo: ('deno', 'want')
#   -> act: 1.00
# Prefixo: ('debat', 'coach')
#   -> provid: 1.00
# Prefixo: ('provid', 'team')
#   -> debat: 1.00
# Prefixo: ('team', 'debat')
#   -> motion: 1.00
# Prefixo: ('debat', 'motion')
#   -> upcom: 1.00
# Prefixo: ('motion', 'upcom')
#   -> debat: 1.00
# Prefixo: ('upcom', 'debat')
#   -> goal: 0.50
#   -> whether: 0.50
# Prefixo: ('debat', 'goal')
#   -> prepar: 1.00
# Prefixo: ('goal', 'prepar')
#   -> team: 1.00
# Prefixo: ('prepar', 'team')
#   -> success: 1.00
# Prefixo: ('team', 'success')
#   -> organ: 1.00
# Prefixo: ('success', 'organ')
#   -> practic: 1.00
# Prefixo: ('organ', 'practic')
#   -> round: 1.00
# Prefixo: ('practic', 'round')
#   -> focu: 1.00
# Prefixo: ('round', 'focu')
#   -> persuas: 1.00
# Prefixo: ('focu', 'persuas')
#   -> speech: 1.00
# Prefixo: ('persuas', 'speech')
#   -> effect: 1.00
# Prefixo: ('speech', 'effect')
#   -> time: 1.00
# Prefixo: ('effect', 'time')
#   -> strategi: 1.00
# Prefixo: ('time', 'strategi')
#   -> refut: 1.00
# Prefixo: ('strategi', 'refut')
#   -> oppos: 1.00
# Prefixo: ('oppos', 'argument')
#   -> draw: 1.00
# Prefixo: ('argument', 'draw')
#   -> depth: 1.00
# Prefixo: ('draw', 'depth')
#   -> conclus: 1.00
# Prefixo: ('depth', 'conclus')
#   -> evid: 1.00
# Prefixo: ('conclus', 'evid')
#   -> provid: 1.00
# Prefixo: ('evid', 'provid')
#   -> first: 1.00
# Prefixo: ('provid', 'first')
#   -> request: 1.00
# Prefixo: ('want', 'team')
#   -> prepar: 1.00
# Prefixo: ('team', 'prepar')
#   -> upcom: 1.00
# Prefixo: ('prepar', 'upcom')
#   -> debat: 1.00
# Prefixo: ('debat', 'whether')
#   -> front: 1.00
# Prefixo: ('whether', 'front')
#   -> end: 1.00
# Prefixo: ('front', 'end')
#   -> develop: 1.00
# Prefixo: ('end', 'develop')
#   -> easi: 0.50
#   -> give: 0.50
# Prefixo: ('develop', 'easi')
#   -> want: 1.00
# Prefixo: ('easi', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'screenwrit')
#   -> develop: 1.00
# Prefixo: ('screenwrit', 'develop')
#   -> engag: 1.00
# Prefixo: ('develop', 'engag')
#   -> creativ: 1.00
# Prefixo: ('engag', 'creativ')
#   -> script: 0.50
#   -> movi: 0.50
# Prefixo: ('creativ', 'script')
#   -> either: 1.00
# Prefixo: ('script', 'either')
#   -> featur: 1.00
# Prefixo: ('either', 'featur')
#   -> length: 1.00
# Prefixo: ('featur', 'length')
#   -> film: 1.00
# Prefixo: ('length', 'film')
#   -> web: 1.00
# Prefixo: ('film', 'web')
#   -> seri: 1.00
# Prefixo: ('web', 'seri')
#   -> captiv: 1.00
# Prefixo: ('seri', 'captiv')
#   -> viewer: 1.00
# Prefixo: ('captiv', 'viewer')
#   -> start: 1.00
# Prefixo: ('viewer', 'start')
#   -> come: 1.00
# Prefixo: ('start', 'come')
#   -> interest: 1.00
# Prefixo: ('come', 'interest')
#   -> charact: 1.00
# Prefixo: ('interest', 'charact')
#   -> set: 1.00
# Prefixo: ('charact', 'set')
#   -> stori: 1.00
# Prefixo: ('set', 'stori')
#   -> dialogu: 1.00
# Prefixo: ('stori', 'dialogu')
#   -> charact: 1.00
# Prefixo: ('dialogu', 'charact')
#   -> etc: 1.00
# Prefixo: ('charact', 'etc')
#   -> charact: 1.00
# Prefixo: ('etc', 'charact')
#   -> develop: 1.00
# Prefixo: ('charact', 'develop')
#   -> complet: 1.00
# Prefixo: ('develop', 'complet')
#   -> creat: 1.00
# Prefixo: ('complet', 'creat')
#   -> excit: 1.00
# Prefixo: ('creat', 'excit')
#   -> storylin: 1.00
# Prefixo: ('excit', 'storylin')
#   -> fill: 1.00
# Prefixo: ('storylin', 'fill')
#   -> twist: 1.00
# Prefixo: ('fill', 'twist')
#   -> turn: 1.00
# Prefixo: ('twist', 'turn')
#   -> keep: 1.00
# Prefixo: ('turn', 'keep')
#   -> viewer: 1.00
# Prefixo: ('keep', 'viewer')
#   -> suspens: 1.00
# Prefixo: ('viewer', 'suspens')
#   -> end: 1.00
# Prefixo: ('suspens', 'end')
#   -> first: 1.00
# Prefixo: ('end', 'first')
#   -> request: 0.50
#   -> suggest: 0.50
# Prefixo: ('need', 'write')
#   -> romant: 0.25
#   -> scienc: 0.25
#   -> movi: 0.25
#   -> detail: 0.25
# Prefixo: ('write', 'romant')
#   -> drama: 1.00
# Prefixo: ('romant', 'drama')
#   -> movi: 1.00
# Prefixo: ('drama', 'movi')
#   -> set: 1.00
# Prefixo: ('movi', 'set')
#   -> pari: 1.00
# Prefixo: ('set', 'pari')
#   -> want: 1.00
# Prefixo: ('pari', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'novelist')
#   -> come: 1.00
# Prefixo: ('novelist', 'come')
#   -> creativ: 1.00
# Prefixo: ('come', 'creativ')
#   -> captiv: 0.25
#   -> way: 0.50
#   -> treatment: 0.25
# Prefixo: ('creativ', 'captiv')
#   -> stori: 1.00
# Prefixo: ('captiv', 'stori')
#   -> engag: 1.00
# Prefixo: ('engag', 'reader')
#   -> long: 1.00
# Prefixo: ('reader', 'long')
#   -> period: 1.00
# Prefixo: ('long', 'period')
#   -> time: 1.00
# Prefixo: ('period', 'time')
#   -> may: 1.00
# Prefixo: ('time', 'may')
#   -> choos: 1.00
# Prefixo: ('choos', 'genr')
#   -> fantasi: 1.00
# Prefixo: ('genr', 'fantasi')
#   -> romanc: 1.00
# Prefixo: ('fantasi', 'romanc')
#   -> histor: 1.00
# Prefixo: ('romanc', 'histor')
#   -> fiction: 1.00
# Prefixo: ('histor', 'fiction')
#   -> aim: 1.00
# Prefixo: ('fiction', 'aim')
#   -> write: 1.00
# Prefixo: ('aim', 'write')
#   -> someth: 1.00
# Prefixo: ('write', 'someth')
#   -> outstand: 1.00
# Prefixo: ('someth', 'outstand')
#   -> plotlin: 1.00
# Prefixo: ('outstand', 'plotlin')
#   -> engag: 1.00
# Prefixo: ('plotlin', 'engag')
#   -> charact: 1.00
# Prefixo: ('engag', 'charact')
#   -> unexpect: 1.00
# Prefixo: ('charact', 'unexpect')
#   -> climax: 1.00
# Prefixo: ('unexpect', 'climax')
#   -> first: 1.00
# Prefixo: ('climax', 'first')
#   -> request: 1.00
# Prefixo: ('write', 'scienc')
#   -> fiction: 1.00
# Prefixo: ('scienc', 'fiction')
#   -> novel: 1.00
# Prefixo: ('fiction', 'novel')
#   -> set: 1.00
# Prefixo: ('novel', 'set')
#   -> futur: 1.00
# Prefixo: ('set', 'futur')
#   -> want: 1.00
# Prefixo: ('futur', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'movi')
#   -> critic: 1.00
# Prefixo: ('movi', 'critic')
#   -> develop: 1.00
# Prefixo: ('critic', 'develop')
#   -> engag: 1.00
# Prefixo: ('creativ', 'movi')
#   -> review: 1.00
# Prefixo: ('movi', 'review')
#   -> cover: 0.33
#   -> movi: 0.33
#   -> articul: 0.33
# Prefixo: ('review', 'cover')
#   -> topic: 1.00
# Prefixo: ('cover', 'topic')
#   -> like: 1.00
# Prefixo: ('topic', 'like')
#   -> plot: 1.00
# Prefixo: ('like', 'plot')
#   -> theme: 1.00
# Prefixo: ('plot', 'theme')
#   -> tone: 1.00
# Prefixo: ('theme', 'tone')
#   -> act: 1.00
# Prefixo: ('tone', 'act')
#   -> charact: 1.00
# Prefixo: ('act', 'charact')
#   -> direct: 1.00
# Prefixo: ('charact', 'direct')
#   -> score: 1.00
# Prefixo: ('direct', 'score')
#   -> cinematographi: 1.00
# Prefixo: ('score', 'cinematographi')
#   -> product: 1.00
# Prefixo: ('cinematographi', 'product')
#   -> design: 1.00
# Prefixo: ('product', 'design')
#   -> special: 1.00
# Prefixo: ('design', 'special')
#   -> effect: 1.00
# Prefixo: ('special', 'effect')
#   -> edit: 1.00
# Prefixo: ('effect', 'edit')
#   -> pace: 1.00
# Prefixo: ('edit', 'pace')
#   -> dialog: 1.00
# Prefixo: ('pace', 'dialog')
#   -> import: 1.00
# Prefixo: ('dialog', 'import')
#   -> aspect: 1.00
# Prefixo: ('import', 'aspect')
#   -> though: 0.33
#   -> ip: 0.33
#   -> topic: 0.33
# Prefixo: ('aspect', 'though')
#   -> emphas: 1.00
# Prefixo: ('though', 'emphas')
#   -> movi: 1.00
# Prefixo: ('emphas', 'movi')
#   -> made: 1.00
# Prefixo: ('movi', 'made')
#   -> feel: 1.00
# Prefixo: ('made', 'feel')
#   -> realli: 1.00
# Prefixo: ('feel', 'realli')
#   -> reson: 1.00
# Prefixo: ('realli', 'reson')
#   -> also: 1.00
# Prefixo: ('reson', 'also')
#   -> critic: 1.00
# Prefixo: ('also', 'critic')
#   -> movi: 1.00
# Prefixo: ('critic', 'movi')
#   -> pleas: 1.00
# Prefixo: ('movi', 'pleas')
#   -> avoid: 1.00
# Prefixo: ('pleas', 'avoid')
#   -> spoiler: 1.00
# Prefixo: ('avoid', 'spoiler')
#   -> first: 1.00
# Prefixo: ('spoiler', 'first')
#   -> request: 1.00
# Prefixo: ('write', 'movi')
#   -> review: 1.00
# Prefixo: ('review', 'movi')
#   -> interstellar: 1.00
# Prefixo: ('movi', 'interstellar')
#   -> want: 1.00
# Prefixo: ('interstellar', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'relationship')
#   -> coach: 1.00
# Prefixo: ('relationship', 'coach')
#   -> provid: 1.00
# Prefixo: ('provid', 'detail')
#   -> two: 0.06
#   -> design: 0.06
#   -> current: 0.06
#   -> individu: 0.11
#   -> upcom: 0.06
#   -> relat: 0.11
#   -> patient: 0.06
#   -> function: 0.06
#   -> updat: 0.06
#   -> creativ: 0.06
#   -> note: 0.11
#   -> profession: 0.06
#   -> proof: 0.06
#   -> respons: 0.06
#   -> summari: 0.06
# Prefixo: ('detail', 'two')
#   -> peopl: 1.00
# Prefixo: ('two', 'peopl')
#   -> involv: 1.00
# Prefixo: ('peopl', 'involv')
#   -> conflict: 1.00
# Prefixo: ('involv', 'conflict')
#   -> job: 1.00
# Prefixo: ('conflict', 'job')
#   -> come: 1.00
# Prefixo: ('come', 'suggest')
#   -> work: 1.00
# Prefixo: ('suggest', 'work')
#   -> issu: 1.00
# Prefixo: ('work', 'issu')
#   -> separ: 1.00
# Prefixo: ('issu', 'separ')
#   -> could: 1.00
# Prefixo: ('separ', 'could')
# ...
# Prefixo: ('togeth', 'follow')
#   -> strategi: 1.00
# Prefixo: ('follow', 'strategi')
#   -> outlin: 1.00
# Prefixo: ('strategi', 'outlin')
#   -> prompt: 1.00
# Prefixo: ('outlin', 'prompt')
#   -> engin: 1.00
# Prefixo: ('prompt', 'engin')
#   -> guid: 0.33
#   -> seek: 0.33
#   -> document: 0.33
# Prefixo: ('engin', 'guid')
#   -> http: 1.00
# Prefixo: ('guid', 'http')
#   -> platform: 1.00
# Prefixo: ('http', 'platform')
#   -> openai: 1.00
# Prefixo: ('platform', 'openai')
#   -> com: 1.00
# Prefixo: ('openai', 'com')
#   -> doc: 1.00
# Prefixo: ('com', 'doc')
#   -> guid: 1.00
# Prefixo: ('doc', 'guid')
#   -> prompt: 1.00
# Prefixo: ('guid', 'prompt')
#   -> engin: 1.00
# Prefixo: ('engin', 'seek')
#   -> assist: 1.00
# Prefixo: ('seek', 'assist')
#   -> craft: 1.00
# Prefixo: ('assist', 'craft')
#   -> prompt: 1.00
# Prefixo: ('craft', 'prompt')
#   -> ensur: 0.33
#   -> 6: 0.33
#   -> would: 0.33
# Prefixo: ('prompt', 'ensur')
#   -> accur: 1.00
# Prefixo: ('accur', 'relev')
#   -> respons: 1.00
# Prefixo: ('relev', 'respons')
#   -> proceed: 1.00
# Prefixo: ('respons', 'proceed')
#   -> 1: 1.00
# Prefixo: ('proceed', '1')
#   -> request: 1.00
# Prefixo: ('1', 'request')
#   -> input: 1.00
# Prefixo: ('request', 'input')
#   -> could: 1.00
# Prefixo: ('input', 'could')
#   -> pleas: 1.00
# Prefixo: ('could', 'pleas')
#   -> ask: 1.00
# Prefixo: ('pleas', 'ask')
#   -> specif: 1.00
# Prefixo: ('ask', 'specif')
#   -> natur: 1.00
# Prefixo: ('specif', 'natur')
#   -> languag: 1.00
# Prefixo: ('languag', 'statement')
#   -> want: 0.50
#   -> structur: 0.50
# Prefixo: ('statement', 'want')
#   -> transform: 1.00
# Prefixo: ('want', 'transform')
#   -> optim: 1.00
# Prefixo: ('transform', 'optim')
#   -> prompt: 1.00
# Prefixo: ('optim', 'prompt')
#   -> 2: 1.00
# Prefixo: ('prompt', '2')
#   -> refer: 1.00
# Prefixo: ('2', 'refer')
#   -> best: 1.00
# Prefixo: ('refer', 'best')
#   -> practic: 1.00
# Prefixo: ('best', 'practic')
#   -> make: 0.50
#   -> 3: 0.50
# Prefixo: ('use', 'guidelin')
#   -> prompt: 1.00
# Prefixo: ('guidelin', 'prompt')
#   -> engin: 1.00
# Prefixo: ('engin', 'document')
#   -> align: 1.00
# Prefixo: ('document', 'align')
#   -> understand: 1.00
# Prefixo: ('align', 'understand')
#   -> establish: 1.00
# Prefixo: ('understand', 'establish')
#   -> best: 1.00
# Prefixo: ('establish', 'best')
#   -> practic: 1.00
# Prefixo: ('practic', '3')
#   -> task: 1.00
# Prefixo: ('3', 'task')
#   -> breakdown: 1.00
# Prefixo: ('task', 'breakdown')
#   -> explain: 1.00
# Prefixo: ('breakdown', 'explain')
#   -> step: 1.00
# Prefixo: ('explain', 'step')
#   -> involv: 1.00
# Prefixo: ('step', 'involv')
#   -> convert: 1.00
# Prefixo: ('involv', 'convert')
#   -> natur: 1.00
# Prefixo: ('convert', 'natur')
#   -> languag: 1.00
# Prefixo: ('statement', 'structur')
#   -> prompt: 1.00
# Prefixo: ('structur', 'prompt')
#   -> 4: 1.00
# Prefixo: ('prompt', '4')
#   -> thought: 1.00
# Prefixo: ('4', 'thought')
#   -> applic: 1.00
# Prefixo: ('thought', 'applic')
#   -> share: 1.00
# Prefixo: ('applic', 'share')
#   -> would: 1.00
# Prefixo: ('share', 'would')
#   -> appli: 1.00
# Prefixo: ('would', 'appli')
#   -> six: 1.00
# Prefixo: ('appli', 'six')
#   -> strateg: 1.00
# Prefixo: ('six', 'strateg')
#   -> principl: 1.00
# Prefixo: ('strateg', 'principl')
#   -> statement: 1.00
# Prefixo: ('principl', 'statement')
#   -> provid: 1.00
# Prefixo: ('statement', 'provid')
#   -> 5: 1.00
# Prefixo: ('provid', '5')
#   -> tool: 1.00
# Prefixo: ('5', 'tool')
#   -> util: 1.00
# Prefixo: ('tool', 'util')
#   -> indic: 1.00
# Prefixo: ('util', 'indic')
#   -> addit: 1.00
# Prefixo: ('indic', 'addit')
#   -> resourc: 1.00
# Prefixo: ('addit', 'resourc')
#   -> tool: 1.00
# Prefixo: ('resourc', 'tool')
#   -> might: 1.00
# Prefixo: ('tool', 'might')
#   -> employ: 1.00
# Prefixo: ('might', 'employ')
#   -> enhanc: 1.00
# Prefixo: ('employ', 'enhanc')
#   -> craft: 1.00
# Prefixo: ('enhanc', 'craft')
#   -> prompt: 1.00
# Prefixo: ('prompt', '6')
#   -> test: 1.00
# Prefixo: ('6', 'test')
#   -> refin: 1.00
# Prefixo: ('test', 'refin')
#   -> plan: 1.00
# Prefixo: ('refin', 'plan')
#   -> outlin: 1.00
# Prefixo: ('plan', 'outlin')
#   -> craft: 1.00
# Prefixo: ('outlin', 'craft')
#   -> prompt: 1.00
# Prefixo: ('prompt', 'would')
#   -> test: 1.00
# Prefixo: ('would', 'test')
#   -> iter: 1.00
# Prefixo: ('test', 'iter')
#   -> refin: 1.00
# Prefixo: ('refin', 'might')
#   -> necessari: 1.00
# Prefixo: ('might', 'necessari')
#   -> consid: 1.00
# Prefixo: ('necessari', 'consid')
#   -> point: 1.00
# Prefixo: ('consid', 'point')
#   -> pleas: 1.00
# Prefixo: ('point', 'pleas')
#   -> prompt: 1.00
# Prefixo: ('pleas', 'prompt')
#   -> suppli: 1.00
# Prefixo: ('prompt', 'suppli')
#   -> natur: 1.00
# Prefixo: ('suppli', 'natur')
#   -> languag: 1.00
# Prefixo: ('languag', 'input')
#   -> prompt: 1.00
# Prefixo: ('prompt', 'optim')
#   -> task: 1.00
# Prefixo: ('optim', 'task')
#   -> want: 1.00
# Prefixo: ('task', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'children')
#   -> book: 1.00
# Prefixo: ('children', 'book')
#   -> creator: 1.00
# Prefixo: ('book', 'creator')
#   -> excel: 1.00
# Prefixo: ('creator', 'excel')
#   -> write: 1.00
# Prefixo: ('excel', 'write')
#   -> stori: 1.00
# Prefixo: ('write', 'stori')
#   -> way: 1.00
# Prefixo: ('stori', 'way')
#   -> children: 1.00
# Prefixo: ('way', 'children')
#   -> easili: 1.00
# Prefixo: ('children', 'easili')
#   -> understand: 1.00
# Prefixo: ('easili', 'understand')
#   -> stori: 1.00
# Prefixo: ('understand', 'stori')
#   -> also: 1.00
# Prefixo: ('stori', 'also')
#   -> make: 1.00
# Prefixo: ('also', 'make')
#   -> peopl: 1.00
# Prefixo: ('peopl', 'reflect')
#   -> end: 1.00
# Prefixo: ('reflect', 'end')
#   -> first: 1.00
# Prefixo: ('deliv', 'children')
#   -> stori: 1.00
# Prefixo: ('children', 'stori')
#   -> dog: 1.00
# Prefixo: ('stori', 'dog')
#   -> cat: 1.00
# Prefixo: ('dog', 'cat')
#   -> stori: 1.00
# Prefixo: ('cat', 'stori')
#   -> stori: 1.00
# Prefixo: ('stori', 'stori')
#   -> friendship: 1.00
# Prefixo: ('stori', 'friendship')
#   -> anim: 1.00
# Prefixo: ('friendship', 'anim')
#   -> pleas: 1.00
# Prefixo: ('anim', 'pleas')
#   -> give: 1.00
# Prefixo: ('pleas', 'give')
#   -> 5: 1.00
# Prefixo: ('give', '5')
#   -> idea: 1.00
# Prefixo: ('5', 'idea')
#   -> book: 1.00
# Prefixo: ('idea', 'book')
#   -> pretend: 1.00
# Prefixo: ('book', 'pretend')
#   -> non: 1.00
# Prefixo: ('pretend', 'non')
#   -> tech: 1.00
# Prefixo: ('non', 'tech')
#   -> savvi: 1.00
# Prefixo: ('tech', 'savvi')
#   -> custom: 1.00
# Prefixo: ('savvi', 'custom')
#   -> call: 1.00
# Prefixo: ('custom', 'call')
#   -> help: 1.00
# Prefixo: ('call', 'help')
#   -> desk: 1.00
# Prefixo: ('help', 'desk')
#   -> specif: 1.00
# Prefixo: ('desk', 'specif')
#   -> issu: 1.00
# Prefixo: ('specif', 'issu')
#   -> internet: 1.00
# Prefixo: ('issu', 'internet')
#   -> connect: 1.00
# Prefixo: ('internet', 'connect')
#   -> problem: 1.00
# Prefixo: ('connect', 'problem')
#   -> softwar: 1.00
# Prefixo: ('problem', 'softwar')
#   -> glitch: 1.00
# Prefixo: ('softwar', 'glitch')
#   -> hardwar: 1.00
# Prefixo: ('glitch', 'hardwar')
#   -> malfunct: 1.00
# Prefixo: ('hardwar', 'malfunct')
#   -> custom: 1.00
# Prefixo: ('malfunct', 'custom')
#   -> ask: 1.00
# Prefixo: ('custom', 'ask')
#   -> question: 1.00
# Prefixo: ('describ', 'problem')
#   -> detail: 1.00
# Prefixo: ('problem', 'detail')
#   -> goal: 1.00
# Prefixo: ('detail', 'goal')
#   -> interact: 1.00
# Prefixo: ('goal', 'interact')
#   -> tech: 1.00
# Prefixo: ('interact', 'tech')
#   -> support: 1.00
# Prefixo: ('tech', 'support')
#   -> agent: 1.00
# Prefixo: ('support', 'agent')
#   -> assist: 1.00
# Prefixo: ('agent', 'assist')
#   -> best: 1.00
# Prefixo: ('assist', 'best')
#   -> abil: 1.00
# Prefixo: ('best', 'abil')
#   -> convers: 1.00
# Prefixo: ('abil', 'convers')
#   -> detail: 1.00
# Prefixo: ('convers', 'detail')
#   -> go: 1.00
# Prefixo: ('detail', 'go')
#   -> back: 1.00
# Prefixo: ('back', 'forth')
#   -> enter: 1.00
# Prefixo: ('forth', 'enter')
#   -> keyword: 1.00
# Prefixo: ('enter', 'keyword')
#   -> review: 1.00
# Prefixo: ('keyword', 'review')
#   -> roleplay: 1.00
# Prefixo: ('review', 'roleplay')
#   -> end: 1.00
# Prefixo: ('roleplay', 'end')
#   -> provid: 1.00
# Prefixo: ('end', 'provid')
#   -> honest: 1.00
# Prefixo: ('provid', 'honest')
#   -> feedback: 1.00
# Prefixo: ('honest', 'feedback')
#   -> problem: 1.00
# Prefixo: ('feedback', 'problem')
#   -> solv: 1.00
# Prefixo: ('solv', 'commun')
#   -> skill: 1.00
# Prefixo: ('commun', 'skill')
#   -> base: 1.00
# Prefixo: ('skill', 'base')
#   -> clariti: 1.00
# Prefixo: ('base', 'clariti')
#   -> respons: 1.00
# Prefixo: ('clariti', 'respons')
#   -> effect: 1.00
# Prefixo: ('respons', 'effect')
#   -> feel: 1.00
# Prefixo: ('effect', 'feel')
#   -> free: 1.00
# Prefixo: ('free', 'confirm')
#   -> issu: 1.00
# Prefixo: ('confirm', 'issu')
#   -> address: 1.00
# Prefixo: ('issu', 'address')
#   -> end: 1.00
# Prefixo: ('address', 'end')
#   -> session: 1.00
# Prefixo: ('end', 'session')
#   -> creativ: 1.00
# Prefixo: ('session', 'creativ')
#   -> brand: 1.00
# Prefixo: ('creativ', 'brand')
#   -> strategist: 1.00
# Prefixo: ('brand', 'strategist')
#   -> special: 1.00
# Prefixo: ('strategist', 'special')
#   -> help: 1.00
# Prefixo: ('special', 'help')
#   -> small: 1.00
# Prefixo: ('help', 'small')
#   -> busi: 1.00
# Prefixo: ('busi', 'establish')
#   -> strong: 1.00
# Prefixo: ('establish', 'strong')
#   -> memor: 1.00
# Prefixo: ('strong', 'memor')
#   -> brand: 1.00
# Prefixo: ('memor', 'brand')
#   -> ident: 1.00
# Prefixo: ('brand', 'ident')
#   -> given: 1.00
# Prefixo: ('ident', 'given')
#   -> inform: 1.00
# Prefixo: ('given', 'inform')
#   -> busi: 1.00
# Prefixo: ('inform', 'busi')
#   -> valu: 1.00
# Prefixo: ('busi', 'valu')
#   -> target: 1.00
# Prefixo: ('valu', 'target')
#   -> audienc: 1.00
# Prefixo: ('audienc', 'industri')
#   -> gener: 1.00
# Prefixo: ('industri', 'gener')
#   -> brand: 1.00
# Prefixo: ('gener', 'brand')
#   -> idea: 1.00
# Prefixo: ('brand', 'idea')
#   -> includ: 1.00
# Prefixo: ('idea', 'includ')
#   -> logo: 1.00
# Prefixo: ('includ', 'logo')
#   -> concept: 1.00
# Prefixo: ('logo', 'concept')
#   -> color: 1.00
# Prefixo: ('concept', 'color')
#   -> palett: 1.00
# Prefixo: ('color', 'palett')
#   -> tone: 1.00
# Prefixo: ('palett', 'tone')
#   -> voic: 1.00
# Prefixo: ('tone', 'voic')
#   -> market: 1.00
# Prefixo: ('voic', 'market')
#   -> strategi: 1.00
# Prefixo: ('market', 'strategi')
#   -> also: 1.00
# Prefixo: ('strategi', 'also')
#   -> suggest: 1.00
# Prefixo: ('way', 'differenti')
#   -> brand: 1.00
# Prefixo: ('differenti', 'brand')
#   -> competitor: 1.00
# Prefixo: ('brand', 'competitor')
#   -> build: 1.00
# Prefixo: ('competitor', 'build')
#   -> loyal: 1.00
# Prefixo: ('build', 'loyal')
#   -> custom: 1.00
# Prefixo: ('loyal', 'custom')
#   -> base: 1.00
# Prefixo: ('custom', 'base')
#   -> consist: 1.00
# Prefixo: ('base', 'consist')
#   -> innov: 1.00
# Prefixo: ('consist', 'innov')
#   -> brand: 1.00
# Prefixo: ('innov', 'brand')
#   -> effort: 1.00
# Prefixo: ('brand', 'effort')
#   -> want: 1.00
# Prefixo: ('effort', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'book')
#   -> summar: 1.00
# Prefixo: ('book', 'summar')
#   -> provid: 1.00
# Prefixo: ('summar', 'provid')
#   -> detail: 1.00
# Prefixo: ('detail', 'summari')
#   -> booknam: 1.00
# Prefixo: ('summari', 'booknam')
#   -> includ: 1.00
# Prefixo: ('booknam', 'includ')
#   -> major: 1.00
# Prefixo: ('includ', 'major')
#   -> topic: 1.00
# Prefixo: ('major', 'topic')
#   -> discuss: 1.00
# Prefixo: ('topic', 'discuss')
#   -> book: 1.00
# Prefixo: ('discuss', 'book')
#   -> major: 1.00
# Prefixo: ('book', 'major')
#   -> concept: 1.00
# Prefixo: ('major', 'concept')
#   -> discuss: 1.00
# Prefixo: ('concept', 'discuss')
#   -> includ: 1.00
# Prefixo: ('discuss', 'includ')
#   -> topic: 1.00
# Prefixo: ('includ', 'topic')
#   -> overview: 1.00
# Prefixo: ('topic', 'overview')
#   -> exampl: 1.00
# Prefixo: ('overview', 'exampl')
#   -> applic: 1.00
# Prefixo: ('exampl', 'applic')
#   -> key: 1.00
# Prefixo: ('applic', 'key')
#   -> takeaway: 1.00
# Prefixo: ('key', 'takeaway')
#   -> structur: 1.00
# Prefixo: ('takeaway', 'structur')
#   -> respons: 1.00
# Prefixo: ('structur', 'respons')
#   -> head: 1.00
# Prefixo: ('respons', 'head')
#   -> topic: 1.00
# Prefixo: ('head', 'topic')
#   -> subhead: 1.00
# Prefixo: ('topic', 'subhead')
#   -> exampl: 1.00
# Prefixo: ('subhead', 'exampl')
#   -> keep: 1.00
# Prefixo: ('exampl', 'keep')
#   -> summari: 1.00
# Prefixo: ('keep', 'summari')
#   -> around: 1.00
# Prefixo: ('summari', 'around')
#   -> 800: 1.00
# Prefixo: ('around', '800')
#   -> word: 1.00
# Prefixo: ('800', 'word')
#   -> want: 1.00
# Prefixo: ('act', 'advanc')
#   -> studi: 1.00
# Prefixo: ('advanc', 'studi')
#   -> plan: 1.00
# Prefixo: ('studi', 'plan')
#   -> gener: 0.33
#   -> student: 0.33
#   -> contribut: 0.33
# Prefixo: ('plan', 'gener')
#   -> imagin: 1.00
# Prefixo: ('gener', 'imagin')
#   -> expert: 1.00
# Prefixo: ('imagin', 'expert')
#   -> educ: 1.00
# Prefixo: ('expert', 'educ')
#   -> mental: 1.00
# Prefixo: ('educ', 'mental')
#   -> health: 1.00
# Prefixo: ('health', 'task')
#   -> develop: 1.00
# Prefixo: ('task', 'develop')
#   -> person: 1.00
# Prefixo: ('develop', 'person')
#   -> studi: 1.00
# Prefixo: ('person', 'studi')
#   -> plan: 1.00
# Prefixo: ('plan', 'student')
#   -> help: 1.00
# Prefixo: ('student', 'help')
#   -> improv: 1.00
# Prefixo: ('improv', 'academ')
#   -> perform: 1.00
# Prefixo: ('academ', 'perform')
#   -> overal: 1.00
# Prefixo: ('perform', 'overal')
#   -> well: 1.00
# Prefixo: ('overal', 'well')
#   -> take: 1.00
# Prefixo: ('well', 'take')
#   -> account: 1.00
# Prefixo: ('account', 'student')
#   -> cours: 1.00
# Prefixo: ('student', 'cours')
#   -> avail: 1.00
# Prefixo: ('cours', 'avail')
#   -> time: 1.00
# Prefixo: ('avail', 'time')
#   -> respons: 1.00
# Prefixo: ('time', 'respons')
#   -> deadlin: 1.00
# Prefixo: ('respons', 'deadlin')
#   -> gener: 1.00
# Prefixo: ('deadlin', 'gener')
#   -> studi: 1.00
# Prefixo: ('gener', 'studi')
#   -> plan: 1.00
# Prefixo: ('plan', 'contribut')
#   -> suhailroushan13: 1.00
# Prefixo: ('contribut', 'suhailroushan13')
#   -> http: 1.00
# Prefixo: ('suhailroushan13', 'http')
#   -> github: 1.00
# Prefixo: ('http', 'github')
#   -> com: 1.00
# Prefixo: ('github', 'com')
#   -> suhailroushan13: 1.00
# Prefixo: ('com', 'suhailroushan13')
#   -> want: 1.00
# Prefixo: ('suhailroushan13', 'want')
#   -> act: 1.00
# Prefixo: ('act', 'seo')
#   -> specialist: 1.00
# Prefixo: ('seo', 'specialist')
#   -> provid: 1.00
# Prefixo: ('provid', 'search')
#   -> engin: 1.00
# Prefixo: ('engin', 'optim')
#   -> relat: 1.00
# Prefixo: ('optim', 'relat')
#   -> queri: 1.00
# Prefixo: ('relat', 'queri')
#   -> scenario: 1.00
# Prefixo: ('queri', 'scenario')
#   -> respond: 1.00
# Prefixo: ('scenario', 'respond')
#   -> relev: 1.00
# Prefixo: ('respond', 'relev')
#   -> seo: 1.00
# Prefixo: ('relev', 'seo')
#   -> advic: 1.00
# Prefixo: ('seo', 'advic')
#   -> recommend: 1.00
# Prefixo: ('advic', 'recommend')
#   -> respons: 1.00
# Prefixo: ('recommend', 'respons')
#   -> focu: 1.00
# Prefixo: ('respons', 'focu')
#   -> sole: 1.00
# Prefixo: ('focu', 'sole')
#   -> seo: 1.00
# Prefixo: ('sole', 'seo')
#   -> strategi: 1.00
# Prefixo: ('seo', 'strategi')
#   -> techniqu: 1.00
# Prefixo: ('strategi', 'techniqu')
#   -> insight: 1.00
# Prefixo: ('techniqu', 'insight')
#   -> provid: 1.00
# Prefixo: ('gener', 'market')
#   -> advic: 1.00
# Prefixo: ('market', 'advic')
#   -> explan: 1.00
# Prefixo: ('advic', 'explan')
#   -> repli: 1.00
# Prefixo: ('repli', 'seo')
#   -> prompt: 1.00
# Prefixo: ('anoth', 'separ')
#   -> list: 1.00
# Prefixo: ('read', 'act')
#   -> nutritionist: 1.00
# Prefixo: ('act', 'nutritionist')
#   -> creat: 1.00
# Prefixo: ('nutritionist', 'creat')
#   -> healthi: 1.00
# Prefixo: ('creat', 'healthi')
#   -> recip: 1.00
# Prefixo: ('healthi', 'recip')
#   -> vegan: 1.00
# Prefixo: ('recip', 'vegan')
#   -> dinner: 1.00
# Prefixo: ('vegan', 'dinner')
#   -> includ: 1.00
# Prefixo: ('dinner', 'includ')
#   -> ingredi: 1.00
# Prefixo: ('includ', 'ingredi')
#   -> step: 1.00
# Prefixo: ('ingredi', 'step')
#   -> step: 1.00
# Prefixo: ('instruct', 'nutrit')
#   -> inform: 1.00
# Prefixo: ('nutrit', 'inform')
#   -> calori: 1.00
# Prefixo: ('inform', 'calori')
#   -> macro: 1.00
# Prefixo: ('calori', 'macro')
#   -> want: 1.00
# Prefixo: ('macro', 'want')
#   -> repli: 1.00
# Prefixo: ('repli', 'question')
#   -> repli: 1.00
# Prefixo: ('repli', 'ye')
#   -> write: 0.50
#   -> noth: 0.50
# Prefixo: ('ye', 'write')
#   -> anyth: 1.00
# Prefixo: ('write', 'anyth')
#   -> els: 1.00
# Prefixo: ('anyth', 'els')
#   -> repli: 1.00
# Prefixo: ('ye', 'noth')
#   -> els: 1.00
# Prefixo: ('els', 'structur')
#   -> follow: 1.00
# Prefixo: ('structur', 'follow')
#   -> want: 1.00
# Prefixo: ('follow', 'want')
#   -> output: 1.00
# Prefixo: ('want', 'output')
#   -> bool: 1.00
# Prefixo: ('output', 'bool')
#   -> question: 1.00
# Prefixo: ('bool', 'question')
#   -> 3: 1.00
# Prefixo: ('3', '3')
#   -> equal: 1.00
# Prefixo: ('3', 'equal')
#   -> 6: 1.00

# %% [markdown]
# ## 📝 Geração de texto com o modelo
# 1. Cada palavra gerada tem uma chance baseada na probabilidade condicional calculada anteriormente.

# %%
def generate_text(language_model, size):
    prefix = random.choice(list(language_model.keys()))
    result = [prefix[0], prefix[1]]

    for _ in range(size):
        continuations = language_model.get(prefix, None)
        if not continuations:
            break
        words = list(continuations.keys())
        probabilities = list(continuations.values())
        next_word = random.choices(words, weights=probabilities, k=1)[0]
        result.append(next_word)
        prefix = (prefix[1], next_word)

    return " ".join(result)

generated_text = generate_text(language_model, 10)
print("\nTexto gerado:")
print(generated_text)
# Out:
# Texto gerado:
# come need help provid depth review includ pro con featur comparison technolog
